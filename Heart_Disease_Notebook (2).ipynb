# %% [markdown]
# ## Libraries utilisées

# %%
# Imports pour la manipulation des données
import io
import requests
import numpy as np
import pandas as pd

# Imports pour la visualisation des données
import matplotlib.pyplot as plt
import seaborn as sns

# Imports pour les tests statistiques et les mesures de performance
from scipy.stats import chi2_contingency, spearmanr, stats, ttest_ind, pointbiserialr
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

# Imports pour la prétraitement des données
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, MinMaxScaler, StandardScaler
from sklearn.feature_selection import SelectKBest, chi2, VarianceThreshold
from imblearn.under_sampling import RandomUnderSampler

# Imports pour la sélection du modèle et l'évaluation
from sklearn.model_selection import (
    learning_curve, train_test_split, cross_val_score, GridSearchCV
)

# Imports pour les modèles classificateurs
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import LinearSVC, SVC
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier

# Imports spécifiques à TensorFlow et Keras
import tensorflow as tf
from tensorflow import keras
from keras.wrappers.scikit_learn import KerasRegressor
from scikeras.wrappers import KerasClassifier, KerasRegressor

# %% [markdown]
# ## Importation des données

# %%
url = "https://raw.githubusercontent.com/ElieCht/SVM-RN-Lou-Ann-Elie/main/heart_2020_cleaned.csv"
download = requests.get(url).content
df = pd.read_csv(io.StringIO(download.decode('utf-8')), sep=',')
df.sample(10)
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 130360           No  21.53     Yes              No     No            10.0
# 60177            No  33.00      No              No     No             0.0
# 295717           No  31.32      No              No     No             8.0
# 240609           No  21.46      No              No     No             0.0
# 266235           No  34.70      No              No     No             0.0
# 96492            No  29.05      No              No     No             0.0
# 86224            No  27.44      No              No     No             0.0
# 303280           No  27.02      No              No     No             2.0
# 73633            No  35.26      No              No     No             0.0
# 15603            No  32.89      No              No     No            30.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race  \
# 130360          30.0          No  Female        75-79     White
# 60177            2.0          No    Male        30-34     White
# 295717          10.0          No    Male        18-24     White
# 240609           0.0          No  Female  80 or older     White
# 266235           0.0          No    Male        45-49  Hispanic
# 96492            2.0          No  Female        50-54     White
# 86224            0.0          No  Female        50-54     White
# 303280           1.0          No  Female        55-59     White
# 73633            0.0          No    Male        60-64     White
# 15603           30.0         Yes    Male        60-64     White
#
#                        Diabetic PhysicalActivity  GenHealth  SleepTime Asthma  \
# 130360                       No              Yes       Good        7.0     No
# 60177                        No              Yes  Very good        7.0    Yes
# 295717                       No              Yes  Very good        7.0     No
# 240609                       No              Yes  Very good        8.0     No
# 266235                       No              Yes  Excellent        9.0     No
# 96492                        No              Yes  Very good        7.0     No
# 86224                        No               No  Very good        7.0     No
# 303280                       No              Yes  Very good        7.0     No
# 73633   No, borderline diabetes              Yes  Very good        7.0    Yes
# 15603                        No               No       Fair        6.0     No
#
#        KidneyDisease SkinCancer
# 130360            No        Yes
# 60177             No         No
# 295717            No         No
# 240609            No         No
# 266235            No         No
# 96492             No         No
# 86224             No         No
# 303280            No         No
# 73633             No         No
# 15603             No         No

# %% [markdown]
# On constate déjà que le nom des variables est correcte puisqu'ils sont assez explicits et ne contiennent pas d'espaces ou d'apostrophes : nous n'aurons pas à les renommer.

# %% [markdown]
# ### I - Analyse exploratoire

# %% [markdown]
# #### I.1 - Statistiques univariées

# %%
# Compter le nombre d'occurrences de chaque catégorie
counts = df['HeartDisease'].value_counts()

# Calculer les pourcentages pour chaque catégorie
percentage_values = counts / counts.sum() * 100

# Créer un graphique en secteurs (pie plot) avec des pourcentages et le nombre d'occurrences
plt.figure(figsize=(8, 8))
plt.pie(percentage_values, labels=[f'Non ({counts["No"]})', f'Oui ({counts["Yes"]})'], autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
plt.title('Répartition de la variable Maladie cardiaque (avant sous-échantillonage)')
plt.show()

# %% [markdown]
# On constate que la variable est très déséquilibrée. La classe minoritaire correspond aux personnes ont fait une attaque cardiaque. Autrement dit, le dataset est constitué d'une majorité de personnes n'ayant pas subies de maladies cardiaques. Il faudra effecter un ré-échantillonage par la suite.

# %% [markdown]
# #### I.1 - Statistiques descriptives

# %%
df.describe(include='all')
# Out:
#        HeartDisease            BMI Smoking AlcoholDrinking  Stroke  \
# count        319795  319795.000000  319795          319795  319795
# unique            2            NaN       2               2       2
# top              No            NaN      No              No      No
# freq         292422            NaN  187887          298018  307726
# mean            NaN      28.325399     NaN             NaN     NaN
# std             NaN       6.356100     NaN             NaN     NaN
# min             NaN      12.020000     NaN             NaN     NaN
# 25%             NaN      24.030000     NaN             NaN     NaN
# 50%             NaN      27.340000     NaN             NaN     NaN
# 75%             NaN      31.420000     NaN             NaN     NaN
# max             NaN      94.850000     NaN             NaN     NaN
#
#         PhysicalHealth   MentalHealth DiffWalking     Sex AgeCategory    Race  \
# count     319795.00000  319795.000000      319795  319795      319795  319795
# unique             NaN            NaN           2       2          13       6
# top                NaN            NaN          No  Female       65-69   White
# freq               NaN            NaN      275385  167805       34151  245212
# mean           3.37171       3.898366         NaN     NaN         NaN     NaN
# std            7.95085       7.955235         NaN     NaN         NaN     NaN
# min            0.00000       0.000000         NaN     NaN         NaN     NaN
# 25%            0.00000       0.000000         NaN     NaN         NaN     NaN
# 50%            0.00000       0.000000         NaN     NaN         NaN     NaN
# 75%            2.00000       3.000000         NaN     NaN         NaN     NaN
# max           30.00000      30.000000         NaN     NaN         NaN     NaN
#
#        Diabetic PhysicalActivity  GenHealth      SleepTime  Asthma  \
# count    319795           319795     319795  319795.000000  319795
# unique        4                2          5            NaN       2
# top          No              Yes  Very good            NaN      No
# freq     269653           247957     113858            NaN  276923
# mean        NaN              NaN        NaN       7.097075     NaN
# std         NaN              NaN        NaN       1.436007     NaN
# min         NaN              NaN        NaN       1.000000     NaN
# 25%         NaN              NaN        NaN       6.000000     NaN
# 50%         NaN              NaN        NaN       7.000000     NaN
# 75%         NaN              NaN        NaN       8.000000     NaN
# max         NaN              NaN        NaN      24.000000     NaN
#
#        KidneyDisease SkinCancer
# count         319795     319795
# unique             2          2
# top               No         No
# freq          308016     289976
# mean             NaN        NaN
# std              NaN        NaN
# min              NaN        NaN
# 25%              NaN        NaN
# 50%              NaN        NaN
# 75%              NaN        NaN
# max              NaN        NaN

# %% [markdown]
# #### I.2 - Statistiques bivariées

# %%
# Créer une figure avec 2 lignes et 2 colonnes
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# Graphique en fonction de "Sex"
df.groupby('Sex')['HeartDisease'].value_counts().unstack(0).plot(kind='bar', stacked=True, ax=axs[0, 0])
axs[0, 0].set_title('Heart Disease distribution by Sex')
axs[0, 0].set_xlabel('Heart Disease')
axs[0, 0].set_ylabel('Count')
axs[0, 0].legend(title='Sex', loc='upper right')

# Graphique en fonction de "Stroke"
df.groupby('Stroke')['HeartDisease'].value_counts().unstack(0).plot(kind='bar', stacked=True, ax=axs[0, 1])
axs[0, 1].set_title('Heart Disease distribution by Stroke')
axs[0, 1].set_xlabel('Heart Disease')
axs[0, 1].set_ylabel('Count')
axs[0, 1].legend(title='Stroke', loc='upper right')

# Graphique en fonction de "AlcoholDrinking"
df.groupby('AlcoholDrinking')['HeartDisease'].value_counts().unstack(0).plot(kind='bar', stacked=True, ax=axs[1, 0])
axs[1, 0].set_title('Heart Disease distribution by Alcohol Drinking')
axs[1, 0].set_xlabel('Heart Disease')
axs[1, 0].set_ylabel('Count')
axs[1, 0].legend(title='Alcohol Drinking', loc='upper right')

# Graphique en fonction de "Smoking"
df.groupby('Smoking')['HeartDisease'].value_counts().unstack(0).plot(kind='bar', stacked=True, ax=axs[1, 1])
axs[1, 1].set_title('Heart Disease distribution by Smoking')
axs[1, 1].set_xlabel('Heart Disease')
axs[1, 1].set_ylabel('Count')
axs[1, 1].legend(title='Smoking', loc='upper right')

# Ajuster l'espacement entre les graphiques
plt.tight_layout()

# Afficher les graphiques
plt.show()

# %% [markdown]
# * Les hommes ont l'air d'être plus sujets aux maladies cardiaques
# * La proportion de personnes ayant fait un AVC est plus élevée chez les gens ayant subi une maladie cardiaque
# * En ce qui concerne l'alcool, la proportion est plus élevée chez les gens n'ayant pas fait de maladie cardiaque (paradoxal ?)
# * La proportion de gens qui fument est plus élevé chez les gens qui fument

# %% [markdown]
# ### II - Pré-traitement des données

# %% [markdown]
# #### II.1 - Valeurs manquantes

# %%
missing_values = df.isnull().sum()

# Affichez les résultats
print("Nombre de valeurs manquantes par colonne :")
print(missing_values)
# Out:
# Nombre de valeurs manquantes par colonne :
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %% [markdown]
# Le dataset a déjà été nettoyé et par conséquent ne contient pas valeurs manquantes

# %% [markdown]
# #### II.2 - Types des variables

# %%
types = df.dtypes
print(types)
# Out:
# HeartDisease         object
# BMI                 float64
# Smoking              object
# AlcoholDrinking      object
# Stroke               object
# PhysicalHealth      float64
# MentalHealth        float64
# DiffWalking          object
# Sex                  object
# AgeCategory          object
# Race                 object
# Diabetic             object
# PhysicalActivity     object
# GenHealth            object
# SleepTime           float64
# Asthma               object
# KidneyDisease        object
# SkinCancer           object
# dtype: object

# %% [markdown]
# On constate qu'un certain nombre de variables (en particulier les variables qui peuvent prendre les valeurs 0 ou 1) ne sont pas au bon format

# %%
# Afficher les valeurs de la variable "HeartDisease" pour les observations 1, 501, 2700, 11 et 21000
observations_indices = [1, 501, 2700, 11, 21000]

for index in observations_indices:
    value_heart_disease = df.iloc[index]['HeartDisease']
    print(f'Observation {index}, HeartDisease: {value_heart_disease}')
# Out:
# Observation 1, HeartDisease: No
# Observation 501, HeartDisease: No
# Observation 2700, HeartDisease: No
# Observation 11, HeartDisease: No
# Observation 21000, HeartDisease: No

# %% [markdown]
# On utilise cette fonction pour pouvoir s'assurer que les 0 ont bien remplacés "No" et les 1 "Yes"

# %%
# Création d'un objet LabelEncoder
label_encoder = LabelEncoder()

# Appliquer le LabelEncoder à la colonne HeartDisease
df['HeartDisease'] = label_encoder.fit_transform(df['HeartDisease'])

# Afficher le résultat
print(df['HeartDisease'])
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 319790    1
# 319791    0
# 319792    0
# 319793    0
# 319794    0
# Name: HeartDisease, Length: 319795, dtype: int32

# %% [markdown]
# On utilise le label encoder pour transformer les 0 en "No" et les 1 en "Yes"

# %%
# Afficher les valeurs de la variable "HeartDisease" pour les observations 1, 501, 2700, 11 et 21000
observations_indices = [1, 501, 2700, 11, 21000]

for index in observations_indices:
    value_heart_disease = df.iloc[index]['HeartDisease']
    print(f'Observation {index}, HeartDisease: {value_heart_disease}')
# Out:
# Observation 1, HeartDisease: 0
# Observation 501, HeartDisease: 0
# Observation 2700, HeartDisease: 0
# Observation 11, HeartDisease: 0
# Observation 21000, HeartDisease: 0

# %% [markdown]
# On constate que les 0 correspondent bien à "No"

# %%
df['Smoking'] = label_encoder.fit_transform(df['Smoking'])
df['AlcoholDrinking'] = label_encoder.fit_transform(df['AlcoholDrinking'])
df['Stroke'] = label_encoder.fit_transform(df['Stroke'])
df['DiffWalking'] = label_encoder.fit_transform(df['DiffWalking'])
df['Sex'] = label_encoder.fit_transform(df['Sex'])
df['PhysicalActivity'] = label_encoder.fit_transform(df['PhysicalActivity'])
df['Asthma'] = label_encoder.fit_transform(df['Asthma'])
df['KidneyDisease'] = label_encoder.fit_transform(df['KidneyDisease'])
df['SkinCancer'] = label_encoder.fit_transform(df['SkinCancer'])

# %% [markdown]
# On fait pareil pour toutes les variables binaires

# %% [markdown]
# Maintenant il faut s'occuper des variables pouvant prendre plusieurs modalités, pour ce faire, nous allons utiliser OneHotEncoder

# %%
# Afficher les différentes modalités de la variable 'GenHealth'
print("Modalités de GenHealth :", df['GenHealth'].unique())

# Afficher les différentes modalités de la variable 'AgeCategory'
print("Modalités de AgeCategory :", df['AgeCategory'].unique())

# Afficher les différentes modalités de la variable 'Race'
print("Modalités de Race :", df['Race'].unique())

# Afficher les différentes modalités de la variable 'Diabetic'
print("Modalités de Diabetic :", df['Diabetic'].unique())
# Out:
# Modalités de GenHealth : ['Very good' 'Fair' 'Good' 'Poor' 'Excellent']
# Modalités de AgeCategory : ['55-59' '80 or older' '65-69' '75-79' '40-44' '70-74' '60-64' '50-54'
#  '45-49' '18-24' '35-39' '30-34' '25-29']
# Modalités de Race : ['White' 'Black' 'Asian' 'American Indian/Alaskan Native' 'Other'
#  'Hispanic']
# Modalités de Diabetic : ['Yes' 'No' 'No, borderline diabetes' 'Yes (during pregnancy)']

# %% [markdown]
# On pourrait se dire qu'on pourrait regrouper certaines modalités notamment pour le diabète, mais nous faisons le choix de ne pas le faire puisqu'être diabétique parce qu'on est enceinte est relativement différent d'être diabétique sans cette composante.

# %% [markdown]
# **Variable GenHealth**

# %% [markdown]
# D'abord, on affiche les modalités pour voir lesquelles elles peuvent prendre

# %%
df.GenHealth.value_counts()
# Out:
# Very good    113858
# Good          93129
# Excellent     66842
# Fair          34677
# Poor          11289
# Name: GenHealth, dtype: int64

# %% [markdown]
# Ensuite, on applique le OneHotEncoder

# %%
#Sk one hot encoder
ohe = OneHotEncoder()
transformed = ohe.fit_transform(df[['GenHealth']])

# %%
one_hot_names = ['Excellent','Fair','Good', 'Poor', 'VeryGood']
ohe_df = pd.DataFrame(transformed.toarray(), columns=one_hot_names)

# %% [markdown]
# On renomme dans cette ordre là puisque la fonction fait par ordre alphabétique

# %%
#On joint l'encoding puis on supprime le feature de base
df_to_train = df.join(ohe_df).drop('GenHealth',axis=1).dropna(axis=0)

# %% [markdown]
# On enlève la variable de base pour qu'elle en soit pas redondante

# %%
# Compte des occurrences de la catégorie 'VeryGood'
print(df_to_train['VeryGood'].value_counts())

# Compte des occurrences de la catégorie 'Good'
print(df_to_train['Good'].value_counts())

# Compte des occurrences de la catégorie 'Excellent'
print(df_to_train['Excellent'].value_counts())

# Compte des occurrences de la catégorie 'Fair'
print(df_to_train['Fair'].value_counts())

# Compte des occurrences de la catégorie 'Poor'
print(df_to_train['Poor'].value_counts())
# Out:
# 0.0    205937
# 1.0    113858
# Name: VeryGood, dtype: int64
# 0.0    226666
# 1.0     93129
# Name: Good, dtype: int64
# 0.0    252953
# 1.0     66842
# Name: Excellent, dtype: int64
# 0.0    285118
# 1.0     34677
# Name: Fair, dtype: int64
# 0.0    308506
# 1.0     11289
# Name: Poor, dtype: int64

# %% [markdown]
# Ca correspond bien à ce que nous avions, nous pouvons donc continuer avec les autres variables

# %% [markdown]
# **Variable AgeCategory**

# %% [markdown]
# On fait pareil pour la variable AgeCategory

# %%
df.AgeCategory.value_counts()
# Out:
# 65-69          34151
# 60-64          33686
# 70-74          31065
# 55-59          29757
# 50-54          25382
# 80 or older    24153
# 45-49          21791
# 75-79          21482
# 18-24          21064
# 40-44          21006
# 35-39          20550
# 30-34          18753
# 25-29          16955
# Name: AgeCategory, dtype: int64

# %%
#Sk one hot encoder
ohe = OneHotEncoder()
transformed = ohe.fit_transform(df_to_train[['AgeCategory']])

# %%
one_hot_names = ['18-24', '25-29', '30-34', '35-39', '40-44', '45-49', '50-54', '55-59','60-64','65-69','70-74','75-79','80+']
ohe_df = pd.DataFrame(transformed.toarray(), columns=one_hot_names)

# %% [markdown]
# On renomme dans l'ordre croissant

# %%
#On joint l'encoding puis on supprime le feature de base
df_to_train = df_to_train.join(ohe_df).drop('AgeCategory',axis=1).dropna(axis=0)

# %%
# Compte des occurrences de la catégorie '65-69'
print(df_to_train['65-69'].value_counts())

# Compte des occurrences de la catégorie '30-34'
print(df_to_train['30-34'].value_counts())

# Compte des occurrences de la catégorie '30-34'
print(df_to_train['80+'].value_counts())
# Out:
# 0.0    285644
# 1.0     34151
# Name: 65-69, dtype: int64
# 0.0    301042
# 1.0     18753
# Name: 30-34, dtype: int64
# 0.0    295642
# 1.0     24153
# Name: 80+, dtype: int64

# %% [markdown]
# Les catégorie correspondent bien

# %% [markdown]
# **Variable Race**

# %% [markdown]
# On fait pareil pour la variable Race

# %%
df.Race.value_counts()
# Out:
# White                             245212
# Hispanic                           27446
# Black                              22939
# Other                              10928
# Asian                               8068
# American Indian/Alaskan Native      5202
# Name: Race, dtype: int64

# %%
#Sk one hot encoder
ohe = OneHotEncoder()
transformed = ohe.fit_transform(df_to_train[['Race']])

# %%
one_hot_names = ['American Indian/Alaskan Native', 'Asian', 'Black', 'Hispanic', 'Other', 'White']
ohe_df = pd.DataFrame(transformed.toarray(), columns=one_hot_names)

# %%
#On joint l'encoding puis on supprime le feature de base
df_to_train = df_to_train.join(ohe_df).drop('Race',axis=1).dropna(axis=0)

# %%
# Compte des occurrences de la catégorie 'American Indian'
print(df_to_train['American Indian/Alaskan Native'].value_counts())

# Compte des occurrences de la catégorie 'Asian'
print(df_to_train['Asian'].value_counts())

# Compte des occurrences de la catégorie 'White'
print(df_to_train['White'].value_counts())
# Out:
# 0.0    314593
# 1.0      5202
# Name: American Indian/Alaskan Native, dtype: int64
# 0.0    311727
# 1.0      8068
# Name: Asian, dtype: int64
# 1.0    245212
# 0.0     74583
# Name: White, dtype: int64

# %% [markdown]
# Les catégories correspodent bien

# %% [markdown]
# **Variable Diabetic**

# %% [markdown]
# On fait pareil pour la variable Diabetic

# %%
df.Diabetic.value_counts()
# Out:
# No                         269653
# Yes                         40802
# No, borderline diabetes      6781
# Yes (during pregnancy)       2559
# Name: Diabetic, dtype: int64

# %%
#Sk one hot encoder
ohe = OneHotEncoder()
transformed = ohe.fit_transform(df_to_train[['Diabetic']])

# %%
one_hot_names = ['No_diabetic', 'No_borderline_diabetic', 'Yes_diabetic', 'Yes_pregnancy_diabetic']
ohe_df = pd.DataFrame(transformed.toarray(), columns=one_hot_names)

# %%
#On joint l'encoding puis on supprime le feature de base
df_to_train = df_to_train.join(ohe_df).drop('Diabetic',axis=1).dropna(axis=0)

# %%
# Compte des occurrences de la catégorie 'No'
print(df_to_train['No_diabetic'].value_counts())

# Compte des occurrences de la catégorie 'No_borderline'
print(df_to_train['No_borderline_diabetic'].value_counts())

# Compte des occurrences de la catégorie 'Yes'
print(df_to_train['Yes_diabetic'].value_counts())

# Compte des occurrences de la catégorie 'Yes_pregnancy'
print(df_to_train['Yes_pregnancy_diabetic'].value_counts())
# Out:
# 1.0    269653
# 0.0     50142
# Name: No_diabetic, dtype: int64
# 0.0    313014
# 1.0      6781
# Name: No_borderline_diabetic, dtype: int64
# 0.0    278993
# 1.0     40802
# Name: Yes_diabetic, dtype: int64
# 0.0    317236
# 1.0      2559
# Name: Yes_pregnancy_diabetic, dtype: int64

# %%
types = df_to_train.dtypes
print(types)
# Out:
# HeartDisease                        int32
# BMI                               float64
# Smoking                             int32
# AlcoholDrinking                     int32
# Stroke                              int32
# PhysicalHealth                    float64
# MentalHealth                      float64
# DiffWalking                         int32
# Sex                                 int32
# PhysicalActivity                    int32
# SleepTime                         float64
# Asthma                              int32
# KidneyDisease                       int32
# SkinCancer                          int32
# Excellent                         float64
# Fair                              float64
# Good                              float64
# Poor                              float64
# VeryGood                          float64
# 18-24                             float64
# 25-29                             float64
# 30-34                             float64
# 35-39                             float64
# 40-44                             float64
# 45-49                             float64
# 50-54                             float64
# 55-59                             float64
# 60-64                             float64
# 65-69                             float64
# 70-74                             float64
# 75-79                             float64
# 80+                               float64
# American Indian/Alaskan Native    float64
# Asian                             float64
# Black                             float64
# Hispanic                          float64
# Other                             float64
# White                             float64
# No_diabetic                       float64
# No_borderline_diabetic            float64
# Yes_diabetic                      float64
# Yes_pregnancy_diabetic            float64
# dtype: object

# %% [markdown]
# On met les variables nouvellement créées en format int32

# %%
# Liste des colonnes à convertir
columns_to_convert = ['Excellent', 'Fair', 'Good', 'Poor', 'VeryGood', '18-24', '25-29', '30-34', '35-39', '40-44',
                       '45-49', '50-54', '55-59', '60-64', '65-69', '70-74', '75-79', '80+', 'American Indian/Alaskan Native',
                       'Asian', 'Black', 'Hispanic', 'Other', 'White', 'No_diabetic', 'No_borderline_diabetic', 'Yes_diabetic', 'Yes_pregnancy_diabetic']

# Conversion des colonnes de float64 à int32
df_to_train[columns_to_convert] = df_to_train[columns_to_convert].astype('int32')

# Affichage du nouveau type des colonnes
print(df_to_train.dtypes)
# Out:
# HeartDisease                        int32
# BMI                               float64
# Smoking                             int32
# AlcoholDrinking                     int32
# Stroke                              int32
# PhysicalHealth                    float64
# MentalHealth                      float64
# DiffWalking                         int32
# Sex                                 int32
# PhysicalActivity                    int32
# SleepTime                         float64
# Asthma                              int32
# KidneyDisease                       int32
# SkinCancer                          int32
# Excellent                           int32
# Fair                                int32
# Good                                int32
# Poor                                int32
# VeryGood                            int32
# 18-24                               int32
# 25-29                               int32
# 30-34                               int32
# 35-39                               int32
# 40-44                               int32
# 45-49                               int32
# 50-54                               int32
# 55-59                               int32
# 60-64                               int32
# 65-69                               int32
# 70-74                               int32
# 75-79                               int32
# 80+                                 int32
# American Indian/Alaskan Native      int32
# Asian                               int32
# Black                               int32
# Hispanic                            int32
# Other                               int32
# White                               int32
# No_diabetic                         int32
# No_borderline_diabetic              int32
# Yes_diabetic                        int32
# Yes_pregnancy_diabetic              int32
# dtype: object

# %% [markdown]
# Déjà on aperçoit qu'on a un nombre élevé de variables, par conséquent il faudra surement par la suite réaliser une feature selection

# %%
df_to_train.describe()
# Out:
#         HeartDisease            BMI        Smoking  AlcoholDrinking  \
# count  319795.000000  319795.000000  319795.000000    319795.000000
# mean        0.085595      28.325399       0.412477         0.068097
# std         0.279766       6.356100       0.492281         0.251912
# min         0.000000      12.020000       0.000000         0.000000
# 25%         0.000000      24.030000       0.000000         0.000000
# 50%         0.000000      27.340000       0.000000         0.000000
# 75%         0.000000      31.420000       1.000000         0.000000
# max         1.000000      94.850000       1.000000         1.000000
#
#               Stroke  PhysicalHealth   MentalHealth    DiffWalking  \
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean        0.037740         3.37171       3.898366       0.138870
# std         0.190567         7.95085       7.955235       0.345812
# min         0.000000         0.00000       0.000000       0.000000
# 25%         0.000000         0.00000       0.000000       0.000000
# 50%         0.000000         0.00000       0.000000       0.000000
# 75%         0.000000         2.00000       3.000000       0.000000
# max         1.000000        30.00000      30.000000       1.000000
#
#                  Sex  PhysicalActivity  ...  American Indian/Alaskan Native  \
# count  319795.000000     319795.000000  ...                   319795.000000
# mean        0.475273          0.775362  ...                        0.016267
# std         0.499389          0.417344  ...                        0.126499
# min         0.000000          0.000000  ...                        0.000000
# 25%         0.000000          1.000000  ...                        0.000000
# 50%         0.000000          1.000000  ...                        0.000000
# 75%         1.000000          1.000000  ...                        0.000000
# max         1.000000          1.000000  ...                        1.000000
#
#                Asian          Black       Hispanic          Other  \
# count  319795.000000  319795.000000  319795.000000  319795.000000
# mean        0.025229       0.071730       0.085824       0.034172
# std         0.156819       0.258041       0.280104       0.181671
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#                White    No_diabetic  No_borderline_diabetic   Yes_diabetic  \
# count  319795.000000  319795.000000           319795.000000  319795.000000
# mean        0.766779       0.843206                0.021204       0.127588
# std         0.422883       0.363607                0.144065       0.333631
# min         0.000000       0.000000                0.000000       0.000000
# 25%         1.000000       1.000000                0.000000       0.000000
# 50%         1.000000       1.000000                0.000000       0.000000
# 75%         1.000000       1.000000                0.000000       0.000000
# max         1.000000       1.000000                1.000000       1.000000
#
#        Yes_pregnancy_diabetic
# count           319795.000000
# mean                 0.008002
# std                  0.089095
# min                  0.000000
# 25%                  0.000000
# 50%                  0.000000
# 75%                  0.000000
# max                  1.000000
#
# [8 rows x 42 columns]

# %% [markdown]
# #### II.3 - Outliers

# %% [markdown]
# On créer deux sous-bases qui seront utiles par la suite :
# * Une qui contient uniquement des variables quantitatives
# * Une qui contient uniquement des variables qualitatives

# %%
quantis = df_to_train.select_dtypes(include=['float64'])
qualis = df_to_train.select_dtypes(include=['int32'])

# %%
plt.figure(figsize=(12, 8))

# Utilisation de la palette de couleurs de seaborn
sns.set_palette("Set3")

# Utilisation de la fonction boxplot de seaborn
sns.boxplot(data=quantis, orient='v', width=0.5, fliersize=5)

# Rotation des labels sur l'axe des x pour une meilleure lisibilité
plt.xticks(rotation=45, fontsize=12)

plt.title("Boxplot des variables quantitatives", fontsize=16)
plt.ylabel("Valeurs", fontsize=14)
plt.xlabel("Variables", fontsize=14)

# Ajout d'une grille pour une meilleure lisibilité
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Personnalisation des axes
plt.tick_params(axis='both', which='major', labelsize=12)

plt.show()

# %% [markdown]
# On constate qu'il existe un grand nombre de valeurs potentiellement atypiques pour toutes nos variables quantitatives

# %%
# Calculer les limites des boîtes à moustaches (whiskers)
def find_outliers(data):
    q1 = data.quantile(0.25)
    q3 = data.quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    return (lower_bound, upper_bound)

# Identifier les observations atypiques
outliers = {}
for column in quantis.columns:
    lower_bound, upper_bound = find_outliers(quantis[column])
    outliers[column] = quantis[(quantis[column] < lower_bound) | (quantis[column] > upper_bound)]

# Afficher les observations atypiques
for column, outlier_data in outliers.items():
    print(f"Variable : {column}")
    print(outlier_data)
    print("\n")
# Out:
# Variable : BMI
#           BMI  PhysicalHealth  MentalHealth  SleepTime
# 32      45.35            30.0           0.0        8.0
# 57      46.52            30.0           0.0        8.0
# 90      44.29            30.0          10.0        7.0
# 105     58.54            30.0           0.0        3.0
# 107     45.42             0.0           0.0        7.0
# ...       ...             ...           ...        ...
# 319693  44.29             0.0           0.0        7.0
# 319709  51.46            30.0           0.0        7.0
# 319725  53.16            29.0           0.0        5.0
# 319777  42.57             0.0           0.0        7.0
# 319794  46.56             0.0           0.0        8.0
#
# [10396 rows x 4 columns]
#
#
# Variable : PhysicalHealth
#           BMI  PhysicalHealth  MentalHealth  SleepTime
# 2       26.58            20.0          30.0        8.0
# 4       23.71            28.0           0.0        8.0
# 5       28.87             6.0           0.0       12.0
# 6       21.63            15.0           0.0        4.0
# 10      34.30            30.0           0.0       15.0
# ...       ...             ...           ...        ...
# 319774  20.36            30.0           0.0        8.0
# 319779  23.38            30.0           0.0        5.0
# 319782  31.89            30.0          30.0        4.0
# 319787  36.54             7.0           0.0        9.0
# 319790  27.41             7.0           0.0        6.0
#
# [47146 rows x 4 columns]
#
#
# Variable : MentalHealth
#           BMI  PhysicalHealth  MentalHealth  SleepTime
# 0       16.60             3.0          30.0        5.0
# 2       26.58            20.0          30.0        8.0
# 14      29.29             0.0          30.0        5.0
# 17      22.59             0.0          30.0        8.0
# 22      26.17             0.0          15.0        6.0
# ...       ...             ...           ...        ...
# 319754  26.95             0.0          30.0        4.0
# 319760  24.79            30.0          30.0        8.0
# 319765  38.45            30.0          15.0        6.0
# 319780  30.67             0.0           8.0        7.0
# 319782  31.89            30.0          30.0        4.0
#
# [51576 rows x 4 columns]
#
#
# Variable : SleepTime
#           BMI  PhysicalHealth  MentalHealth  SleepTime
# 5       28.87             6.0           0.0       12.0
# 10      34.30            30.0           0.0       15.0
# 50      26.61             0.0           0.0       12.0
# 206     35.11            20.0           0.0       12.0
# 235     43.54             0.0           0.0        2.0
# ...       ...             ...           ...        ...
# 319373  24.03            12.0           7.0        2.0
# 319394  33.13             0.0           0.0        2.0
# 319408  38.86            30.0          30.0        1.0
# 319702  24.41             0.0           0.0       12.0
# 319793  32.81             0.0           0.0       12.0
#
# [4543 rows x 4 columns]

# %% [markdown]
# * 10396 valeurs atypiques pour la variables BMI
# * 47146 valeurs atypiques pour la variable PhysicalHealth
# * 51576 valeurs atypiques pour la variable MentalHealth
# * 4543 valeurs atypiques pour la variables SleepTime
#
# C'est la variable MentalHealth qui possède le plus de valeurs atypiques

# %%
# Compter les occurrences de chaque observation atypique
outlier_counts = pd.Series(outliers).value_counts()

# Afficher les observations atypiques avec leurs fréquences
print("Observations atypiques et leurs fréquences:")
print(outlier_counts)

# Vous pouvez également afficher le top N des observations les plus fréquentes
# Par exemple, les 5 observations les plus fréquentes
top_n_outliers = outlier_counts.head(100)
print("\nTop 5 observations atypiques les plus fréquentes:")
print(top_n_outliers)
# Out:
# Observations atypiques et leurs fréquences:
# 262144    1
# 154431    1
# 154479    1
# 154475    1
# 154468    1
#          ..
# 51704     1
# 313847    1
# 51702     1
# 51701     1
# 262143    1
# Length: 88775, dtype: int64
#
# Top 5 observations atypiques les plus fréquentes:
# 262144    1
# 154431    1
# 154479    1
# 154475    1
# 154468    1
#          ..
# 154770    1
# 154763    1
# 154758    1
# 154794    1
# 154750    1
# Length: 100, dtype: int64

# %% [markdown]
# Il n'y pas de valeurs atypiques qui reviennent plusieurs fois

# %% [markdown]
# **z-score = 3**

# %%
columns_to_process = ["BMI", "PhysicalHealth", "MentalHealth", "SleepTime"]

# Copier le DataFrame original pour éviter de modifier les données d'origine
df_without_outliers = df_to_train.copy()

# Boucle sur les colonnes spécifiées
for column in columns_to_process:
    # Calcul des Z-scores pour chaque point de données
    z_scores = stats.zscore(df_without_outliers[column])
    
    # Définir un seuil pour considérer un point comme une valeur atypique (par exemple, Z-score > 3)
    threshold = 3
    
    # Filtrer les valeurs atypiques en fonction des Z-scores
    df_without_outliers = df_without_outliers[(z_scores <= threshold) & (z_scores >= -threshold)]

# Afficher le DataFrame sans les valeurs atypiques
print(df_without_outliers)
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 1                  0  20.34        0                0       1             0.0
# 3                  0  24.21        0                0       0             0.0
# 6                  0  21.63        0                0       0            15.0
# 7                  0  31.64        1                0       0             5.0
# 8                  0  26.45        0                0       0             0.0
# ...              ...    ...      ...              ...     ...             ...
# 319789             0  22.22        0                0       0             0.0
# 319790             1  27.41        1                0       0             7.0
# 319791             0  29.84        1                0       0             0.0
# 319792             0  24.24        0                0       0             0.0
# 319794             0  46.56        0                0       0             0.0
#
#         MentalHealth  DiffWalking  Sex  PhysicalActivity  ...  \
# 1                0.0            0    0                 1  ...
# 3                0.0            0    0                 0  ...
# 6                0.0            0    0                 1  ...
# 7                0.0            1    0                 0  ...
# 8                0.0            0    0                 0  ...
# ...              ...          ...  ...               ...  ...
# 319789           0.0            0    0                 1  ...
# 319790           0.0            1    1                 0  ...
# 319791           0.0            0    1                 1  ...
# 319792           0.0            0    0                 1  ...
# 319794           0.0            0    0                 1  ...
#
#         American Indian/Alaskan Native  Asian  Black  Hispanic  Other  White  \
# 1                                    0      0      0         0      0      1
# 3                                    0      0      0         0      0      1
# 6                                    0      0      0         0      0      1
# 7                                    0      0      0         0      0      1
# 8                                    0      0      0         0      0      1
# ...                                ...    ...    ...       ...    ...    ...
# 319789                               0      0      0         1      0      0
# 319790                               0      0      0         1      0      0
# 319791                               0      0      0         1      0      0
# 319792                               0      0      0         1      0      0
# 319794                               0      0      0         1      0      0
#
#         No_diabetic  No_borderline_diabetic  Yes_diabetic  \
# 1                 1                       0             0
# 3                 1                       0             0
# 6                 1                       0             0
# 7                 0                       0             1
# 8                 0                       1             0
# ...             ...                     ...           ...
# 319789            1                       0             0
# 319790            0                       0             1
# 319791            1                       0             0
# 319792            1                       0             0
# 319794            1                       0             0
#
#         Yes_pregnancy_diabetic
# 1                            0
# 3                            0
# 6                            0
# 7                            0
# 8                            0
# ...                        ...
# 319789                       0
# 319790                       0
# 319791                       0
# 319792                       0
# 319794                       0
#
# [278941 rows x 42 columns]

# %% [markdown]
# Il reste 278941 observations

# %%
df_without_outliers = quantis.copy()

sns.boxplot(data=df_without_outliers[columns_to_process])

# Add titles and labels
plt.title("Boxplots for Selected Columns")
plt.xlabel("Columns")
plt.ylabel("Values")

# Calculate the total number of observations
total_observations = sum(len(df_without_outliers[column]) for column in columns_to_process)

# Add text annotation for total observations in the top right corner
plt.text(0.95, 0.95, f'Total Observations: {total_observations}', 
         ha='right', va='top', transform=plt.gca().transAxes)

# Show the plot
plt.show()

# %% [markdown]
# Avec le z-score = 3, il y a de nombreuses valeurs atypiques encore

# %% [markdown]
# **z-score = 1**

# %%
columns_to_process = ["BMI", "PhysicalHealth", "MentalHealth", "SleepTime"]

# Copier le DataFrame original pour éviter de modifier les données d'origine
df_without_outliers1 = df_to_train.copy()

# Boucle sur les colonnes spécifiées
for column in columns_to_process:
    # Calcul des Z-scores pour chaque point de données
    z_scores = stats.zscore(df_without_outliers[column])
    
    # Définir un seuil pour considérer un point comme une valeur atypique 
    threshold = 1
    
    # Filtrer les valeurs atypiques en fonction des Z-scores
    df_without_outliers1 = df_without_outliers1[(z_scores <= threshold) & (z_scores >= -threshold)]

# Afficher le DataFrame sans les valeurs atypiques
print(df_without_outliers1)
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 3                  0  24.21        0                0       0             0.0
# 12                 0  28.37        1                0       0             0.0
# 13                 0  28.15        0                0       0             7.0
# 15                 0  29.18        0                0       0             1.0
# 21                 0  28.90        0                0       0             2.0
# ...              ...    ...      ...              ...     ...             ...
# 319786             1  33.20        1                0       0             0.0
# 319788             0  23.38        0                0       0             0.0
# 319789             0  22.22        0                0       0             0.0
# 319790             1  27.41        1                0       0             7.0
# 319792             0  24.24        0                0       0             0.0
#
#         MentalHealth  DiffWalking  Sex  PhysicalActivity  ...  \
# 3                0.0            0    0                 0  ...
# 12               0.0            1    1                 1  ...
# 13               0.0            1    0                 0  ...
# 15               0.0            0    0                 1  ...
# 21               5.0            0    0                 0  ...
# ...              ...          ...  ...               ...  ...
# 319786           0.0            0    0                 1  ...
# 319788           0.0            0    0                 1  ...
# 319789           0.0            0    0                 1  ...
# 319790           0.0            1    1                 0  ...
# 319792           0.0            0    0                 1  ...
#
#         American Indian/Alaskan Native  Asian  Black  Hispanic  Other  White  \
# 3                                    0      0      0         0      0      1
# 12                                   0      0      0         0      0      1
# 13                                   0      0      0         0      0      1
# 15                                   0      0      0         0      0      1
# 21                                   0      0      0         0      0      1
# ...                                ...    ...    ...       ...    ...    ...
# 319786                               0      0      0         1      0      0
# 319788                               0      0      0         1      0      0
# 319789                               0      0      0         1      0      0
# 319790                               0      0      0         1      0      0
# 319792                               0      0      0         1      0      0
#
#         No_diabetic  No_borderline_diabetic  Yes_diabetic  \
# 3                 1                       0             0
# 12                0                       0             1
# 13                1                       0             0
# 15                1                       0             0
# 21                0                       0             1
# ...             ...                     ...           ...
# 319786            0                       0             1
# 319788            1                       0             0
# 319789            1                       0             0
# 319790            0                       0             1
# 319792            1                       0             0
#
#         Yes_pregnancy_diabetic
# 3                            0
# 12                           0
# 13                           0
# 15                           0
# 21                           0
# ...                        ...
# 319786                       0
# 319788                       0
# 319789                       0
# 319790                       0
# 319792                       0
#
# [166607 rows x 42 columns]
# C:\Users\Chataigner\AppData\Local\Temp\ipykernel_30028\3776043178.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_without_outliers1 = df_without_outliers1[(z_scores <= threshold) & (z_scores >= -threshold)]

# %% [markdown]
# Il reste 166607 observations

# %%
sns.boxplot(data=df_without_outliers1[columns_to_process])

# Add titles and labels
plt.title("Boxplots for Selected Columns")
plt.xlabel("Columns")
plt.ylabel("Values")

# Calculate the total number of observations
total_observations = sum(len(df_without_outliers1[column]) for column in columns_to_process)
# Show the plot
plt.show()

# %% [markdown]
# Avec le z-score = 1 il n'y a plus de valeurs atypiques pour BMI et SleepTime, en revanche il en reste PhysicalHealth et MentalHealth

# %% [markdown]
# **z-score = 0.5**

# %%
columns_to_process = ["BMI", "PhysicalHealth", "MentalHealth", "SleepTime"]

# Copier le DataFrame original pour éviter de modifier les données d'origine
df_without_outliers2 = df_to_train.copy()

# Boucle sur les colonnes spécifiées
for column in columns_to_process:
    # Calcul des Z-scores pour chaque point de données
    z_scores = stats.zscore(df_without_outliers2[column])
    
    # Définir un seuil pour considérer un point comme une valeur atypique (par exemple, Z-score > 3)
    threshold = 0.5
    
    # Filtrer les valeurs atypiques en fonction des Z-scores
    df_without_outliers2 = df_without_outliers2[(z_scores <= threshold) & (z_scores >= -threshold)]

# Afficher le DataFrame sans les valeurs atypiques
print(df_without_outliers2)
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 21                 0  28.90        0                0       0             2.0
# 51                 0  31.09        0                0       0             2.0
# 52                 0  27.12        1                0       0             2.0
# 58                 0  29.55        0                0       0             0.0
# 117                0  26.22        0                0       0             0.0
# ...              ...    ...      ...              ...     ...             ...
# 319749             0  26.57        0                0       0             0.0
# 319758             1  28.32        1                0       0             0.0
# 319762             0  30.41        0                0       0             0.0
# 319769             0  25.25        0                0       0             0.0
# 319772             0  30.90        0                0       0             0.0
#
#         MentalHealth  DiffWalking  Sex  PhysicalActivity  ...  \
# 21               5.0            0    0                 0  ...
# 51               0.0            0    0                 1  ...
# 52               0.0            0    1                 1  ...
# 58               0.0            0    1                 1  ...
# 117              0.0            0    0                 0  ...
# ...              ...          ...  ...               ...  ...
# 319749           0.0            0    0                 0  ...
# 319758           3.0            0    0                 0  ...
# 319762           0.0            0    0                 0  ...
# 319769           0.0            0    1                 1  ...
# 319772           0.0            0    0                 1  ...
#
#         American Indian/Alaskan Native  Asian  Black  Hispanic  Other  White  \
# 21                                   0      0      0         0      0      1
# 51                                   0      0      0         0      0      1
# 52                                   0      0      0         0      0      1
# 58                                   0      0      0         0      0      1
# 117                                  0      0      0         0      0      1
# ...                                ...    ...    ...       ...    ...    ...
# 319749                               0      0      0         1      0      0
# 319758                               0      0      0         1      0      0
# 319762                               0      0      0         1      0      0
# 319769                               0      0      0         1      0      0
# 319772                               0      0      0         1      0      0
#
#         No_diabetic  No_borderline_diabetic  Yes_diabetic  \
# 21                0                       0             1
# 51                1                       0             0
# 52                0                       0             1
# 58                0                       0             1
# 117               1                       0             0
# ...             ...                     ...           ...
# 319749            1                       0             0
# 319758            0                       0             1
# 319762            1                       0             0
# 319769            0                       0             1
# 319772            1                       0             0
#
#         Yes_pregnancy_diabetic
# 21                           0
# 51                           0
# 52                           0
# 58                           0
# 117                          0
# ...                        ...
# 319749                       0
# 319758                       0
# 319762                       0
# 319769                       0
# 319772                       0
#
# [33163 rows x 42 columns]

# %% [markdown]
# Il reste 33163 observations

# %%
sns.boxplot(data=df_without_outliers2[columns_to_process])

# Add titles and labels
plt.title("Boxplots for Selected Columns")
plt.xlabel("Columns")
plt.ylabel("Values")

# Calculate the total number of observations
total_observations = sum(len(df_without_outliers2[column]) for column in columns_to_process)

# Show the plot
plt.show()

# %% [markdown]
# Avec le z-score = 0.5 il n'y a plus de valeurs atypiques pour BMI et SleepTime, en revanche il en reste PhysicalHealth et MentalHealth

# %% [markdown]
# #### II.4 - Relations entre les variables

# %% [markdown]
# ##### II.4.1 - Corrélations

# %%
# Calculer la matrice des corrélations de Spearman
correlation_matrix_spearman, _ = spearmanr(quantis)

# Créer une heatmap avec Seaborn pour la matrice des corrélations de Spearman
plt.figure(figsize=(12, 10))
heatmap = sns.heatmap(correlation_matrix_spearman, annot=True, cmap='coolwarm', linewidths=.5)

# Extraire les noms des colonnes
column_names = quantis.columns

# Ajouter les noms des variables sur les axes
heatmap.set_xticklabels(column_names, rotation=45, horizontalalignment='right')
heatmap.set_yticklabels(column_names, rotation=0, horizontalalignment='right')

plt.title('Matrice des Corrélations (Spearman)')
plt.show()

# %% [markdown]
# * On utilise spearman car pearson suppose que les données suivent une loi normale contrairement à Spearman
# * Pas de corrélation significative, on peut laisser les variables quantitatives puisqu'il n'y en a que 4 et qu'elles ne sont pas corrélées

# %% [markdown]
# ##### II.4.2 - Liens entre les variables qualitatives

# %%
# Calcul des p-values du chi2 pour chaque paire de variables
p_values = pd.DataFrame(index=qualis.columns, columns=qualis.columns)

for col1 in qualis.columns:
    for col2 in qualis.columns:
        contingency_table = pd.crosstab(qualis[col1], qualis[col2])
        _, p_value, _, _ = chi2_contingency(contingency_table)
        p_values.at[col1, col2] = p_value

# Convertir les p-values en valeurs numériques
p_values = p_values.apply(pd.to_numeric)

# Création de la heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(p_values, annot=True, cmap="coolwarm", fmt=".3f", linewidths=.5)
plt.title("Heatmap des p-values du test du chi2")
plt.show()

# %% [markdown]
# Grâce au graphique on constate qu'il y a un grand nombre de couples de variables ayant un lien, on regarde les p-values pour que ça soit plus lisible

# %%
# Calcul des p-values du chi2 pour chaque paire de variables
p_values = pd.DataFrame(index=qualis.columns, columns=qualis.columns)

for col1 in qualis.columns:
    for col2 in qualis.columns:
        contingency_table = pd.crosstab(qualis[col1], qualis[col2])
        _, p_value, _, _ = chi2_contingency(contingency_table)
        p_values.at[col1, col2] = p_value

# Convertir les p-values en valeurs numériques
p_values = p_values.apply(pd.to_numeric)

# Définir le seuil de signification (alpha)
alpha = 0.05

# Vérifier chaque p-value et imprimer un message
for col1 in p_values.columns:
    for col2 in p_values.index:
        p_value = p_values.at[col1, col2]
        if p_value > alpha:
            print(f"Il n'y a pas de lien significatif entre {col1} et {col2}. P-value = {p_value:.3f}")
        else:
            print(f"Il y a un lien significatif entre {col1} et {col2}. P-value = {p_value:.3f}")
# Out:
# Il y a un lien significatif entre HeartDisease et HeartDisease. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et Smoking. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et AlcoholDrinking. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et Stroke. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et DiffWalking. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et Sex. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et PhysicalActivity. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et Asthma. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et KidneyDisease. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et SkinCancer. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et Excellent. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et Fair. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et Good. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et Poor. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et VeryGood. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et 18-24. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et 25-29. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et 30-34. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et 35-39. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et 40-44. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et 45-49. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et 50-54. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et 55-59. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et 60-64. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et 65-69. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et 70-74. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et 75-79. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et 80+. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et American Indian/Alaskan Native. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et Asian. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et Black. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et Hispanic. P-value = 0.000
# Il n'y a pas de lien significatif entre HeartDisease et Other. P-value = 0.089
# Il y a un lien significatif entre HeartDisease et White. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et No_diabetic. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et No_borderline_diabetic. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et Yes_diabetic. P-value = 0.000
# Il y a un lien significatif entre HeartDisease et Yes_pregnancy_diabetic. P-value = 0.000
# Il y a un lien significatif entre Smoking et HeartDisease. P-value = 0.000
# Il y a un lien significatif entre Smoking et Smoking. P-value = 0.000
# Il y a un lien significatif entre Smoking et AlcoholDrinking. P-value = 0.000
# Il y a un lien significatif entre Smoking et Stroke. P-value = 0.000
# Il y a un lien significatif entre Smoking et DiffWalking. P-value = 0.000
# Il y a un lien significatif entre Smoking et Sex. P-value = 0.000
# Il y a un lien significatif entre Smoking et PhysicalActivity. P-value = 0.000
# Il y a un lien significatif entre Smoking et Asthma. P-value = 0.000
# Il y a un lien significatif entre Smoking et KidneyDisease. P-value = 0.000
# Il y a un lien significatif entre Smoking et SkinCancer. P-value = 0.000
# Il y a un lien significatif entre Smoking et Excellent. P-value = 0.000
# Il y a un lien significatif entre Smoking et Fair. P-value = 0.000
# Il y a un lien significatif entre Smoking et Good. P-value = 0.000
# Il y a un lien significatif entre Smoking et Poor. P-value = 0.000
# Il y a un lien significatif entre Smoking et VeryGood. P-value = 0.000
# Il y a un lien significatif entre Smoking et 18-24. P-value = 0.000
# Il y a un lien significatif entre Smoking et 25-29. P-value = 0.000
# Il y a un lien significatif entre Smoking et 30-34. P-value = 0.000
# Il y a un lien significatif entre Smoking et 35-39. P-value = 0.016
# Il y a un lien significatif entre Smoking et 40-44. P-value = 0.000
# Il y a un lien significatif entre Smoking et 45-49. P-value = 0.000
# Il y a un lien significatif entre Smoking et 50-54. P-value = 0.000
# Il y a un lien significatif entre Smoking et 55-59. P-value = 0.000
# Il y a un lien significatif entre Smoking et 60-64. P-value = 0.000
# Il y a un lien significatif entre Smoking et 65-69. P-value = 0.000
# Il y a un lien significatif entre Smoking et 70-74. P-value = 0.000
# Il y a un lien significatif entre Smoking et 75-79. P-value = 0.000
# Il y a un lien significatif entre Smoking et 80+. P-value = 0.000
# Il y a un lien significatif entre Smoking et American Indian/Alaskan Native. P-value = 0.000
# Il y a un lien significatif entre Smoking et Asian. P-value = 0.000
# Il y a un lien significatif entre Smoking et Black. P-value = 0.000
# Il y a un lien significatif entre Smoking et Hispanic. P-value = 0.000
# Il y a un lien significatif entre Smoking et Other. P-value = 0.000
# Il y a un lien significatif entre Smoking et White. P-value = 0.000
# Il y a un lien significatif entre Smoking et No_diabetic. P-value = 0.000
# Il y a un lien significatif entre Smoking et No_borderline_diabetic. P-value = 0.000
# Il y a un lien significatif entre Smoking et Yes_diabetic. P-value = 0.000
# Il y a un lien significatif entre Smoking et Yes_pregnancy_diabetic. P-value = 0.002
# Il y a un lien significatif entre AlcoholDrinking et HeartDisease. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et Smoking. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et AlcoholDrinking. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et Stroke. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et DiffWalking. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et Sex. P-value = 0.018
# Il y a un lien significatif entre AlcoholDrinking et PhysicalActivity. P-value = 0.000
# Il n'y a pas de lien significatif entre AlcoholDrinking et Asthma. P-value = 0.217
# Il y a un lien significatif entre AlcoholDrinking et KidneyDisease. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et SkinCancer. P-value = 0.001
# Il y a un lien significatif entre AlcoholDrinking et Excellent. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et Fair. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et Good. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et Poor. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et VeryGood. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et 18-24. P-value = 0.015
# Il y a un lien significatif entre AlcoholDrinking et 25-29. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et 30-34. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et 35-39. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et 40-44. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et 45-49. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et 50-54. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et 55-59. P-value = 0.000
# Il n'y a pas de lien significatif entre AlcoholDrinking et 60-64. P-value = 0.365
# Il y a un lien significatif entre AlcoholDrinking et 65-69. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et 70-74. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et 75-79. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et 80+. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et American Indian/Alaskan Native. P-value = 0.018
# Il y a un lien significatif entre AlcoholDrinking et Asian. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et Black. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et Hispanic. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et Other. P-value = 0.002
# Il y a un lien significatif entre AlcoholDrinking et White. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et No_diabetic. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et No_borderline_diabetic. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et Yes_diabetic. P-value = 0.000
# Il y a un lien significatif entre AlcoholDrinking et Yes_pregnancy_diabetic. P-value = 0.023
# Il y a un lien significatif entre Stroke et HeartDisease. P-value = 0.000
# Il y a un lien significatif entre Stroke et Smoking. P-value = 0.000
# Il y a un lien significatif entre Stroke et AlcoholDrinking. P-value = 0.000
# Il y a un lien significatif entre Stroke et Stroke. P-value = 0.000
# Il y a un lien significatif entre Stroke et DiffWalking. P-value = 0.000
# Il n'y a pas de lien significatif entre Stroke et Sex. P-value = 0.082
# Il y a un lien significatif entre Stroke et PhysicalActivity. P-value = 0.000
# Il y a un lien significatif entre Stroke et Asthma. P-value = 0.000
# Il y a un lien significatif entre Stroke et KidneyDisease. P-value = 0.000
# Il y a un lien significatif entre Stroke et SkinCancer. P-value = 0.000
# Il y a un lien significatif entre Stroke et Excellent. P-value = 0.000
# Il y a un lien significatif entre Stroke et Fair. P-value = 0.000
# Il y a un lien significatif entre Stroke et Good. P-value = 0.000
# Il y a un lien significatif entre Stroke et Poor. P-value = 0.000
# Il y a un lien significatif entre Stroke et VeryGood. P-value = 0.000
# Il y a un lien significatif entre Stroke et 18-24. P-value = 0.000
# Il y a un lien significatif entre Stroke et 25-29. P-value = 0.000
# Il y a un lien significatif entre Stroke et 30-34. P-value = 0.000
# Il y a un lien significatif entre Stroke et 35-39. P-value = 0.000
# Il y a un lien significatif entre Stroke et 40-44. P-value = 0.000
# Il y a un lien significatif entre Stroke et 45-49. P-value = 0.000
# Il y a un lien significatif entre Stroke et 50-54. P-value = 0.000
# Il n'y a pas de lien significatif entre Stroke et 55-59. P-value = 0.492
# Il y a un lien significatif entre Stroke et 60-64. P-value = 0.000
# Il y a un lien significatif entre Stroke et 65-69. P-value = 0.000
# Il y a un lien significatif entre Stroke et 70-74. P-value = 0.000
# Il y a un lien significatif entre Stroke et 75-79. P-value = 0.000
# Il y a un lien significatif entre Stroke et 80+. P-value = 0.000
# Il y a un lien significatif entre Stroke et American Indian/Alaskan Native. P-value = 0.000
# Il y a un lien significatif entre Stroke et Asian. P-value = 0.000
# Il y a un lien significatif entre Stroke et Black. P-value = 0.000
# Il y a un lien significatif entre Stroke et Hispanic. P-value = 0.000
# Il y a un lien significatif entre Stroke et Other. P-value = 0.001
# Il n'y a pas de lien significatif entre Stroke et White. P-value = 0.521
# Il y a un lien significatif entre Stroke et No_diabetic. P-value = 0.000
# Il y a un lien significatif entre Stroke et No_borderline_diabetic. P-value = 0.000
# Il y a un lien significatif entre Stroke et Yes_diabetic. P-value = 0.000
# Il y a un lien significatif entre Stroke et Yes_pregnancy_diabetic. P-value = 0.012
# Il y a un lien significatif entre DiffWalking et HeartDisease. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et Smoking. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et AlcoholDrinking. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et Stroke. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et DiffWalking. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et Sex. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et PhysicalActivity. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et Asthma. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et KidneyDisease. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et SkinCancer. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et Excellent. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et Fair. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et Good. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et Poor. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et VeryGood. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et 18-24. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et 25-29. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et 30-34. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et 35-39. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et 40-44. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et 45-49. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et 50-54. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et 55-59. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et 60-64. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et 65-69. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et 70-74. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et 75-79. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et 80+. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et American Indian/Alaskan Native. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et Asian. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et Black. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et Hispanic. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et Other. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et White. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et No_diabetic. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et No_borderline_diabetic. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et Yes_diabetic. P-value = 0.000
# Il y a un lien significatif entre DiffWalking et Yes_pregnancy_diabetic. P-value = 0.000
# Il y a un lien significatif entre Sex et HeartDisease. P-value = 0.000
# Il y a un lien significatif entre Sex et Smoking. P-value = 0.000
# Il y a un lien significatif entre Sex et AlcoholDrinking. P-value = 0.018
# Il n'y a pas de lien significatif entre Sex et Stroke. P-value = 0.082
# Il y a un lien significatif entre Sex et DiffWalking. P-value = 0.000
# Il y a un lien significatif entre Sex et Sex. P-value = 0.000
# Il y a un lien significatif entre Sex et PhysicalActivity. P-value = 0.000
# Il y a un lien significatif entre Sex et Asthma. P-value = 0.000
# Il y a un lien significatif entre Sex et KidneyDisease. P-value = 0.000
# Il y a un lien significatif entre Sex et SkinCancer. P-value = 0.000
# Il y a un lien significatif entre Sex et Excellent. P-value = 0.000
# Il y a un lien significatif entre Sex et Fair. P-value = 0.000
# Il y a un lien significatif entre Sex et Good. P-value = 0.040
# Il y a un lien significatif entre Sex et Poor. P-value = 0.000
# Il n'y a pas de lien significatif entre Sex et VeryGood. P-value = 0.068
# Il y a un lien significatif entre Sex et 18-24. P-value = 0.000
# Il y a un lien significatif entre Sex et 25-29. P-value = 0.000
# Il y a un lien significatif entre Sex et 30-34. P-value = 0.000
# Il y a un lien significatif entre Sex et 35-39. P-value = 0.000
# Il n'y a pas de lien significatif entre Sex et 40-44. P-value = 0.318
# Il n'y a pas de lien significatif entre Sex et 45-49. P-value = 0.964
# Il n'y a pas de lien significatif entre Sex et 50-54. P-value = 0.835
# Il n'y a pas de lien significatif entre Sex et 55-59. P-value = 0.122
# Il n'y a pas de lien significatif entre Sex et 60-64. P-value = 0.233
# Il n'y a pas de lien significatif entre Sex et 65-69. P-value = 0.144
# Il y a un lien significatif entre Sex et 70-74. P-value = 0.000
# Il y a un lien significatif entre Sex et 75-79. P-value = 0.000
# Il y a un lien significatif entre Sex et 80+. P-value = 0.000
# Il n'y a pas de lien significatif entre Sex et American Indian/Alaskan Native. P-value = 0.054
# Il y a un lien significatif entre Sex et Asian. P-value = 0.000
# Il y a un lien significatif entre Sex et Black. P-value = 0.000
# Il y a un lien significatif entre Sex et Hispanic. P-value = 0.042
# Il y a un lien significatif entre Sex et Other. P-value = 0.000
# Il y a un lien significatif entre Sex et White. P-value = 0.000
# Il y a un lien significatif entre Sex et No_diabetic. P-value = 0.040
# Il y a un lien significatif entre Sex et No_borderline_diabetic. P-value = 0.016
# Il y a un lien significatif entre Sex et Yes_diabetic. P-value = 0.000
# Il y a un lien significatif entre Sex et Yes_pregnancy_diabetic. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et HeartDisease. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et Smoking. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et AlcoholDrinking. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et Stroke. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et DiffWalking. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et Sex. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et PhysicalActivity. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et Asthma. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et KidneyDisease. P-value = 0.000
# Il n'y a pas de lien significatif entre PhysicalActivity et SkinCancer. P-value = 0.457
# Il y a un lien significatif entre PhysicalActivity et Excellent. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et Fair. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et Good. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et Poor. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et VeryGood. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et 18-24. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et 25-29. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et 30-34. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et 35-39. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et 40-44. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et 45-49. P-value = 0.000
# Il n'y a pas de lien significatif entre PhysicalActivity et 50-54. P-value = 0.321
# Il n'y a pas de lien significatif entre PhysicalActivity et 55-59. P-value = 0.145
# Il y a un lien significatif entre PhysicalActivity et 60-64. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et 65-69. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et 70-74. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et 75-79. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et 80+. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et American Indian/Alaskan Native. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et Asian. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et Black. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et Hispanic. P-value = 0.000
# Il n'y a pas de lien significatif entre PhysicalActivity et Other. P-value = 0.312
# Il y a un lien significatif entre PhysicalActivity et White. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et No_diabetic. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et No_borderline_diabetic. P-value = 0.000
# Il y a un lien significatif entre PhysicalActivity et Yes_diabetic. P-value = 0.000
# Il n'y a pas de lien significatif entre PhysicalActivity et Yes_pregnancy_diabetic. P-value = 0.409
# Il y a un lien significatif entre Asthma et HeartDisease. P-value = 0.000
# Il y a un lien significatif entre Asthma et Smoking. P-value = 0.000
# Il n'y a pas de lien significatif entre Asthma et AlcoholDrinking. P-value = 0.217
# Il y a un lien significatif entre Asthma et Stroke. P-value = 0.000
# Il y a un lien significatif entre Asthma et DiffWalking. P-value = 0.000
# Il y a un lien significatif entre Asthma et Sex. P-value = 0.000
# Il y a un lien significatif entre Asthma et PhysicalActivity. P-value = 0.000
# Il y a un lien significatif entre Asthma et Asthma. P-value = 0.000
# Il y a un lien significatif entre Asthma et KidneyDisease. P-value = 0.000
# Il n'y a pas de lien significatif entre Asthma et SkinCancer. P-value = 0.830
# Il y a un lien significatif entre Asthma et Excellent. P-value = 0.000
# Il y a un lien significatif entre Asthma et Fair. P-value = 0.000
# Il y a un lien significatif entre Asthma et Good. P-value = 0.000
# Il y a un lien significatif entre Asthma et Poor. P-value = 0.000
# Il y a un lien significatif entre Asthma et VeryGood. P-value = 0.000
# Il y a un lien significatif entre Asthma et 18-24. P-value = 0.000
# Il y a un lien significatif entre Asthma et 25-29. P-value = 0.000
# Il y a un lien significatif entre Asthma et 30-34. P-value = 0.000
# Il y a un lien significatif entre Asthma et 35-39. P-value = 0.009
# Il y a un lien significatif entre Asthma et 40-44. P-value = 0.000
# Il y a un lien significatif entre Asthma et 45-49. P-value = 0.000
# Il n'y a pas de lien significatif entre Asthma et 50-54. P-value = 0.187
# Il n'y a pas de lien significatif entre Asthma et 55-59. P-value = 0.414
# Il n'y a pas de lien significatif entre Asthma et 60-64. P-value = 0.768
# Il y a un lien significatif entre Asthma et 65-69. P-value = 0.000
# Il y a un lien significatif entre Asthma et 70-74. P-value = 0.000
# Il y a un lien significatif entre Asthma et 75-79. P-value = 0.000
# Il y a un lien significatif entre Asthma et 80+. P-value = 0.000
# Il y a un lien significatif entre Asthma et American Indian/Alaskan Native. P-value = 0.000
# Il y a un lien significatif entre Asthma et Asian. P-value = 0.000
# Il y a un lien significatif entre Asthma et Black. P-value = 0.000
# Il y a un lien significatif entre Asthma et Hispanic. P-value = 0.029
# Il y a un lien significatif entre Asthma et Other. P-value = 0.000
# Il y a un lien significatif entre Asthma et White. P-value = 0.000
# Il y a un lien significatif entre Asthma et No_diabetic. P-value = 0.000
# Il y a un lien significatif entre Asthma et No_borderline_diabetic. P-value = 0.000
# Il y a un lien significatif entre Asthma et Yes_diabetic. P-value = 0.000
# Il y a un lien significatif entre Asthma et Yes_pregnancy_diabetic. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et HeartDisease. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et Smoking. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et AlcoholDrinking. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et Stroke. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et DiffWalking. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et Sex. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et PhysicalActivity. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et Asthma. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et KidneyDisease. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et SkinCancer. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et Excellent. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et Fair. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et Good. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et Poor. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et VeryGood. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et 18-24. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et 25-29. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et 30-34. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et 35-39. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et 40-44. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et 45-49. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et 50-54. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et 55-59. P-value = 0.002
# Il y a un lien significatif entre KidneyDisease et 60-64. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et 65-69. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et 70-74. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et 75-79. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et 80+. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et American Indian/Alaskan Native. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et Asian. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et Black. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et Hispanic. P-value = 0.000
# Il n'y a pas de lien significatif entre KidneyDisease et Other. P-value = 0.255
# Il y a un lien significatif entre KidneyDisease et White. P-value = 0.001
# Il y a un lien significatif entre KidneyDisease et No_diabetic. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et No_borderline_diabetic. P-value = 0.005
# Il y a un lien significatif entre KidneyDisease et Yes_diabetic. P-value = 0.000
# Il y a un lien significatif entre KidneyDisease et Yes_pregnancy_diabetic. P-value = 0.009
# Il y a un lien significatif entre SkinCancer et HeartDisease. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et Smoking. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et AlcoholDrinking. P-value = 0.001
# Il y a un lien significatif entre SkinCancer et Stroke. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et DiffWalking. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et Sex. P-value = 0.000
# Il n'y a pas de lien significatif entre SkinCancer et PhysicalActivity. P-value = 0.457
# Il n'y a pas de lien significatif entre SkinCancer et Asthma. P-value = 0.830
# Il y a un lien significatif entre SkinCancer et KidneyDisease. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et SkinCancer. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et Excellent. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et Fair. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et Good. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et Poor. P-value = 0.000
# Il n'y a pas de lien significatif entre SkinCancer et VeryGood. P-value = 0.263
# Il y a un lien significatif entre SkinCancer et 18-24. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et 25-29. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et 30-34. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et 35-39. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et 40-44. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et 45-49. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et 50-54. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et 55-59. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et 60-64. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et 65-69. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et 70-74. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et 75-79. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et 80+. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et American Indian/Alaskan Native. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et Asian. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et Black. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et Hispanic. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et Other. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et White. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et No_diabetic. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et No_borderline_diabetic. P-value = 0.001
# Il y a un lien significatif entre SkinCancer et Yes_diabetic. P-value = 0.000
# Il y a un lien significatif entre SkinCancer et Yes_pregnancy_diabetic. P-value = 0.000
# Il y a un lien significatif entre Excellent et HeartDisease. P-value = 0.000
# Il y a un lien significatif entre Excellent et Smoking. P-value = 0.000
# Il y a un lien significatif entre Excellent et AlcoholDrinking. P-value = 0.000
# Il y a un lien significatif entre Excellent et Stroke. P-value = 0.000
# Il y a un lien significatif entre Excellent et DiffWalking. P-value = 0.000
# Il y a un lien significatif entre Excellent et Sex. P-value = 0.000
# Il y a un lien significatif entre Excellent et PhysicalActivity. P-value = 0.000
# Il y a un lien significatif entre Excellent et Asthma. P-value = 0.000
# Il y a un lien significatif entre Excellent et KidneyDisease. P-value = 0.000
# Il y a un lien significatif entre Excellent et SkinCancer. P-value = 0.000
# Il y a un lien significatif entre Excellent et Excellent. P-value = 0.000
# Il y a un lien significatif entre Excellent et Fair. P-value = 0.000
# Il y a un lien significatif entre Excellent et Good. P-value = 0.000
# Il y a un lien significatif entre Excellent et Poor. P-value = 0.000
# Il y a un lien significatif entre Excellent et VeryGood. P-value = 0.000
# Il y a un lien significatif entre Excellent et 18-24. P-value = 0.000
# Il y a un lien significatif entre Excellent et 25-29. P-value = 0.000
# Il y a un lien significatif entre Excellent et 30-34. P-value = 0.000
# Il y a un lien significatif entre Excellent et 35-39. P-value = 0.000
# Il y a un lien significatif entre Excellent et 40-44. P-value = 0.000
# Il y a un lien significatif entre Excellent et 45-49. P-value = 0.000
# Il y a un lien significatif entre Excellent et 50-54. P-value = 0.000
# Il y a un lien significatif entre Excellent et 55-59. P-value = 0.050
# Il y a un lien significatif entre Excellent et 60-64. P-value = 0.000
# Il y a un lien significatif entre Excellent et 65-69. P-value = 0.000
# Il y a un lien significatif entre Excellent et 70-74. P-value = 0.000
# Il y a un lien significatif entre Excellent et 75-79. P-value = 0.000
# Il y a un lien significatif entre Excellent et 80+. P-value = 0.000
# Il y a un lien significatif entre Excellent et American Indian/Alaskan Native. P-value = 0.000
# Il y a un lien significatif entre Excellent et Asian. P-value = 0.000
# Il y a un lien significatif entre Excellent et Black. P-value = 0.000
# Il y a un lien significatif entre Excellent et Hispanic. P-value = 0.000
# Il n'y a pas de lien significatif entre Excellent et Other. P-value = 0.974
# Il y a un lien significatif entre Excellent et White. P-value = 0.004
# Il y a un lien significatif entre Excellent et No_diabetic. P-value = 0.000
# Il y a un lien significatif entre Excellent et No_borderline_diabetic. P-value = 0.000
# Il y a un lien significatif entre Excellent et Yes_diabetic. P-value = 0.000
# Il n'y a pas de lien significatif entre Excellent et Yes_pregnancy_diabetic. P-value = 0.093
# Il y a un lien significatif entre Fair et HeartDisease. P-value = 0.000
# Il y a un lien significatif entre Fair et Smoking. P-value = 0.000
# Il y a un lien significatif entre Fair et AlcoholDrinking. P-value = 0.000
# Il y a un lien significatif entre Fair et Stroke. P-value = 0.000
# Il y a un lien significatif entre Fair et DiffWalking. P-value = 0.000
# Il y a un lien significatif entre Fair et Sex. P-value = 0.000
# Il y a un lien significatif entre Fair et PhysicalActivity. P-value = 0.000
# Il y a un lien significatif entre Fair et Asthma. P-value = 0.000
# Il y a un lien significatif entre Fair et KidneyDisease. P-value = 0.000
# Il y a un lien significatif entre Fair et SkinCancer. P-value = 0.000
# Il y a un lien significatif entre Fair et Excellent. P-value = 0.000
# Il y a un lien significatif entre Fair et Fair. P-value = 0.000
# Il y a un lien significatif entre Fair et Good. P-value = 0.000
# Il y a un lien significatif entre Fair et Poor. P-value = 0.000
# Il y a un lien significatif entre Fair et VeryGood. P-value = 0.000
# Il y a un lien significatif entre Fair et 18-24. P-value = 0.000
# Il y a un lien significatif entre Fair et 25-29. P-value = 0.000
# Il y a un lien significatif entre Fair et 30-34. P-value = 0.000
# Il y a un lien significatif entre Fair et 35-39. P-value = 0.000
# Il y a un lien significatif entre Fair et 40-44. P-value = 0.000
# Il y a un lien significatif entre Fair et 45-49. P-value = 0.000
# Il y a un lien significatif entre Fair et 50-54. P-value = 0.001
# Il y a un lien significatif entre Fair et 55-59. P-value = 0.000
# Il y a un lien significatif entre Fair et 60-64. P-value = 0.000
# Il y a un lien significatif entre Fair et 65-69. P-value = 0.000
# Il y a un lien significatif entre Fair et 70-74. P-value = 0.000
# Il y a un lien significatif entre Fair et 75-79. P-value = 0.000
# Il y a un lien significatif entre Fair et 80+. P-value = 0.000
# Il y a un lien significatif entre Fair et American Indian/Alaskan Native. P-value = 0.000
# Il y a un lien significatif entre Fair et Asian. P-value = 0.000
# Il y a un lien significatif entre Fair et Black. P-value = 0.000
# Il y a un lien significatif entre Fair et Hispanic. P-value = 0.000
# Il y a un lien significatif entre Fair et Other. P-value = 0.000
# Il y a un lien significatif entre Fair et White. P-value = 0.000
# Il y a un lien significatif entre Fair et No_diabetic. P-value = 0.000
# Il y a un lien significatif entre Fair et No_borderline_diabetic. P-value = 0.000
# Il y a un lien significatif entre Fair et Yes_diabetic. P-value = 0.000
# Il n'y a pas de lien significatif entre Fair et Yes_pregnancy_diabetic. P-value = 0.701
# Il y a un lien significatif entre Good et HeartDisease. P-value = 0.000
# Il y a un lien significatif entre Good et Smoking. P-value = 0.000
# Il y a un lien significatif entre Good et AlcoholDrinking. P-value = 0.000
# Il y a un lien significatif entre Good et Stroke. P-value = 0.000
# Il y a un lien significatif entre Good et DiffWalking. P-value = 0.000
# Il y a un lien significatif entre Good et Sex. P-value = 0.040
# Il y a un lien significatif entre Good et PhysicalActivity. P-value = 0.000
# Il y a un lien significatif entre Good et Asthma. P-value = 0.000
# Il y a un lien significatif entre Good et KidneyDisease. P-value = 0.000
# Il y a un lien significatif entre Good et SkinCancer. P-value = 0.000
# Il y a un lien significatif entre Good et Excellent. P-value = 0.000
# Il y a un lien significatif entre Good et Fair. P-value = 0.000
# Il y a un lien significatif entre Good et Good. P-value = 0.000
# Il y a un lien significatif entre Good et Poor. P-value = 0.000
# Il y a un lien significatif entre Good et VeryGood. P-value = 0.000
# Il y a un lien significatif entre Good et 18-24. P-value = 0.000
# Il y a un lien significatif entre Good et 25-29. P-value = 0.000
# Il y a un lien significatif entre Good et 30-34. P-value = 0.000
# Il y a un lien significatif entre Good et 35-39. P-value = 0.000
# Il y a un lien significatif entre Good et 40-44. P-value = 0.000
# Il y a un lien significatif entre Good et 45-49. P-value = 0.000
# Il y a un lien significatif entre Good et 50-54. P-value = 0.002
# Il y a un lien significatif entre Good et 55-59. P-value = 0.000
# Il n'y a pas de lien significatif entre Good et 60-64. P-value = 0.123
# Il y a un lien significatif entre Good et 65-69. P-value = 0.000
# Il y a un lien significatif entre Good et 70-74. P-value = 0.000
# Il y a un lien significatif entre Good et 75-79. P-value = 0.000
# Il y a un lien significatif entre Good et 80+. P-value = 0.000
# Il y a un lien significatif entre Good et American Indian/Alaskan Native. P-value = 0.000
# Il y a un lien significatif entre Good et Asian. P-value = 0.035
# Il y a un lien significatif entre Good et Black. P-value = 0.000
# Il y a un lien significatif entre Good et Hispanic. P-value = 0.000
# Il y a un lien significatif entre Good et Other. P-value = 0.000
# Il y a un lien significatif entre Good et White. P-value = 0.000
# Il y a un lien significatif entre Good et No_diabetic. P-value = 0.000
# Il y a un lien significatif entre Good et No_borderline_diabetic. P-value = 0.000
# Il y a un lien significatif entre Good et Yes_diabetic. P-value = 0.000
# Il y a un lien significatif entre Good et Yes_pregnancy_diabetic. P-value = 0.018
# Il y a un lien significatif entre Poor et HeartDisease. P-value = 0.000
# Il y a un lien significatif entre Poor et Smoking. P-value = 0.000
# Il y a un lien significatif entre Poor et AlcoholDrinking. P-value = 0.000
# Il y a un lien significatif entre Poor et Stroke. P-value = 0.000
# Il y a un lien significatif entre Poor et DiffWalking. P-value = 0.000
# Il y a un lien significatif entre Poor et Sex. P-value = 0.000
# Il y a un lien significatif entre Poor et PhysicalActivity. P-value = 0.000
# Il y a un lien significatif entre Poor et Asthma. P-value = 0.000
# Il y a un lien significatif entre Poor et KidneyDisease. P-value = 0.000
# Il y a un lien significatif entre Poor et SkinCancer. P-value = 0.000
# Il y a un lien significatif entre Poor et Excellent. P-value = 0.000
# Il y a un lien significatif entre Poor et Fair. P-value = 0.000
# Il y a un lien significatif entre Poor et Good. P-value = 0.000
# Il y a un lien significatif entre Poor et Poor. P-value = 0.000
# Il y a un lien significatif entre Poor et VeryGood. P-value = 0.000
# Il y a un lien significatif entre Poor et 18-24. P-value = 0.000
# Il y a un lien significatif entre Poor et 25-29. P-value = 0.000
# Il y a un lien significatif entre Poor et 30-34. P-value = 0.000
# Il y a un lien significatif entre Poor et 35-39. P-value = 0.000
# Il y a un lien significatif entre Poor et 40-44. P-value = 0.000
# Il y a un lien significatif entre Poor et 45-49. P-value = 0.000
# Il y a un lien significatif entre Poor et 50-54. P-value = 0.011
# Il y a un lien significatif entre Poor et 55-59. P-value = 0.000
# Il y a un lien significatif entre Poor et 60-64. P-value = 0.000
# Il y a un lien significatif entre Poor et 65-69. P-value = 0.000
# Il y a un lien significatif entre Poor et 70-74. P-value = 0.000
# Il y a un lien significatif entre Poor et 75-79. P-value = 0.000
# Il y a un lien significatif entre Poor et 80+. P-value = 0.000
# Il y a un lien significatif entre Poor et American Indian/Alaskan Native. P-value = 0.000
# Il y a un lien significatif entre Poor et Asian. P-value = 0.000
# Il y a un lien significatif entre Poor et Black. P-value = 0.000
# Il y a un lien significatif entre Poor et Hispanic. P-value = 0.025
# Il y a un lien significatif entre Poor et Other. P-value = 0.000
# Il y a un lien significatif entre Poor et White. P-value = 0.000
# Il y a un lien significatif entre Poor et No_diabetic. P-value = 0.000
# Il y a un lien significatif entre Poor et No_borderline_diabetic. P-value = 0.000
# Il y a un lien significatif entre Poor et Yes_diabetic. P-value = 0.000
# Il y a un lien significatif entre Poor et Yes_pregnancy_diabetic. P-value = 0.019
# Il y a un lien significatif entre VeryGood et HeartDisease. P-value = 0.000
# Il y a un lien significatif entre VeryGood et Smoking. P-value = 0.000
# Il y a un lien significatif entre VeryGood et AlcoholDrinking. P-value = 0.000
# Il y a un lien significatif entre VeryGood et Stroke. P-value = 0.000
# Il y a un lien significatif entre VeryGood et DiffWalking. P-value = 0.000
# Il n'y a pas de lien significatif entre VeryGood et Sex. P-value = 0.068
# Il y a un lien significatif entre VeryGood et PhysicalActivity. P-value = 0.000
# Il y a un lien significatif entre VeryGood et Asthma. P-value = 0.000
# Il y a un lien significatif entre VeryGood et KidneyDisease. P-value = 0.000
# Il n'y a pas de lien significatif entre VeryGood et SkinCancer. P-value = 0.263
# Il y a un lien significatif entre VeryGood et Excellent. P-value = 0.000
# Il y a un lien significatif entre VeryGood et Fair. P-value = 0.000
# Il y a un lien significatif entre VeryGood et Good. P-value = 0.000
# Il y a un lien significatif entre VeryGood et Poor. P-value = 0.000
# Il y a un lien significatif entre VeryGood et VeryGood. P-value = 0.000
# Il y a un lien significatif entre VeryGood et 18-24. P-value = 0.000
# Il y a un lien significatif entre VeryGood et 25-29. P-value = 0.000
# Il y a un lien significatif entre VeryGood et 30-34. P-value = 0.000
# Il y a un lien significatif entre VeryGood et 35-39. P-value = 0.001
# Il y a un lien significatif entre VeryGood et 40-44. P-value = 0.004
# Il n'y a pas de lien significatif entre VeryGood et 45-49. P-value = 0.311
# Il n'y a pas de lien significatif entre VeryGood et 50-54. P-value = 0.509
# Il n'y a pas de lien significatif entre VeryGood et 55-59. P-value = 0.147
# Il y a un lien significatif entre VeryGood et 60-64. P-value = 0.000
# Il n'y a pas de lien significatif entre VeryGood et 65-69. P-value = 0.815
# Il n'y a pas de lien significatif entre VeryGood et 70-74. P-value = 0.314
# Il y a un lien significatif entre VeryGood et 75-79. P-value = 0.000
# Il y a un lien significatif entre VeryGood et 80+. P-value = 0.000
# Il y a un lien significatif entre VeryGood et American Indian/Alaskan Native. P-value = 0.000
# Il n'y a pas de lien significatif entre VeryGood et Asian. P-value = 0.081
# Il y a un lien significatif entre VeryGood et Black. P-value = 0.000
# Il y a un lien significatif entre VeryGood et Hispanic. P-value = 0.000
# Il y a un lien significatif entre VeryGood et Other. P-value = 0.000
# Il y a un lien significatif entre VeryGood et White. P-value = 0.000
# Il y a un lien significatif entre VeryGood et No_diabetic. P-value = 0.000
# Il y a un lien significatif entre VeryGood et No_borderline_diabetic. P-value = 0.000
# Il y a un lien significatif entre VeryGood et Yes_diabetic. P-value = 0.000
# Il n'y a pas de lien significatif entre VeryGood et Yes_pregnancy_diabetic. P-value = 0.882
# Il y a un lien significatif entre 18-24 et HeartDisease. P-value = 0.000
# Il y a un lien significatif entre 18-24 et Smoking. P-value = 0.000
# Il y a un lien significatif entre 18-24 et AlcoholDrinking. P-value = 0.015
# Il y a un lien significatif entre 18-24 et Stroke. P-value = 0.000
# Il y a un lien significatif entre 18-24 et DiffWalking. P-value = 0.000
# Il y a un lien significatif entre 18-24 et Sex. P-value = 0.000
# Il y a un lien significatif entre 18-24 et PhysicalActivity. P-value = 0.000
# Il y a un lien significatif entre 18-24 et Asthma. P-value = 0.000
# Il y a un lien significatif entre 18-24 et KidneyDisease. P-value = 0.000
# Il y a un lien significatif entre 18-24 et SkinCancer. P-value = 0.000
# Il y a un lien significatif entre 18-24 et Excellent. P-value = 0.000
# Il y a un lien significatif entre 18-24 et Fair. P-value = 0.000
# Il y a un lien significatif entre 18-24 et Good. P-value = 0.000
# Il y a un lien significatif entre 18-24 et Poor. P-value = 0.000
# Il y a un lien significatif entre 18-24 et VeryGood. P-value = 0.000
# Il y a un lien significatif entre 18-24 et 18-24. P-value = 0.000
# Il y a un lien significatif entre 18-24 et 25-29. P-value = 0.000
# Il y a un lien significatif entre 18-24 et 30-34. P-value = 0.000
# Il y a un lien significatif entre 18-24 et 35-39. P-value = 0.000
# Il y a un lien significatif entre 18-24 et 40-44. P-value = 0.000
# Il y a un lien significatif entre 18-24 et 45-49. P-value = 0.000
# Il y a un lien significatif entre 18-24 et 50-54. P-value = 0.000
# Il y a un lien significatif entre 18-24 et 55-59. P-value = 0.000
# Il y a un lien significatif entre 18-24 et 60-64. P-value = 0.000
# Il y a un lien significatif entre 18-24 et 65-69. P-value = 0.000
# Il y a un lien significatif entre 18-24 et 70-74. P-value = 0.000
# Il y a un lien significatif entre 18-24 et 75-79. P-value = 0.000
# Il y a un lien significatif entre 18-24 et 80+. P-value = 0.000
# Il n'y a pas de lien significatif entre 18-24 et American Indian/Alaskan Native. P-value = 0.130
# Il y a un lien significatif entre 18-24 et Asian. P-value = 0.000
# Il n'y a pas de lien significatif entre 18-24 et Black. P-value = 0.229
# Il y a un lien significatif entre 18-24 et Hispanic. P-value = 0.000
# Il y a un lien significatif entre 18-24 et Other. P-value = 0.000
# Il y a un lien significatif entre 18-24 et White. P-value = 0.000
# Il y a un lien significatif entre 18-24 et No_diabetic. P-value = 0.000
# Il y a un lien significatif entre 18-24 et No_borderline_diabetic. P-value = 0.000
# Il y a un lien significatif entre 18-24 et Yes_diabetic. P-value = 0.000
# Il y a un lien significatif entre 18-24 et Yes_pregnancy_diabetic. P-value = 0.000
# Il y a un lien significatif entre 25-29 et HeartDisease. P-value = 0.000
# Il y a un lien significatif entre 25-29 et Smoking. P-value = 0.000
# Il y a un lien significatif entre 25-29 et AlcoholDrinking. P-value = 0.000
# Il y a un lien significatif entre 25-29 et Stroke. P-value = 0.000
# Il y a un lien significatif entre 25-29 et DiffWalking. P-value = 0.000
# Il y a un lien significatif entre 25-29 et Sex. P-value = 0.000
# Il y a un lien significatif entre 25-29 et PhysicalActivity. P-value = 0.000
# Il y a un lien significatif entre 25-29 et Asthma. P-value = 0.000
# Il y a un lien significatif entre 25-29 et KidneyDisease. P-value = 0.000
# Il y a un lien significatif entre 25-29 et SkinCancer. P-value = 0.000
# Il y a un lien significatif entre 25-29 et Excellent. P-value = 0.000
# Il y a un lien significatif entre 25-29 et Fair. P-value = 0.000
# Il y a un lien significatif entre 25-29 et Good. P-value = 0.000
# Il y a un lien significatif entre 25-29 et Poor. P-value = 0.000
# Il y a un lien significatif entre 25-29 et VeryGood. P-value = 0.000
# Il y a un lien significatif entre 25-29 et 18-24. P-value = 0.000
# Il y a un lien significatif entre 25-29 et 25-29. P-value = 0.000
# Il y a un lien significatif entre 25-29 et 30-34. P-value = 0.000
# Il y a un lien significatif entre 25-29 et 35-39. P-value = 0.000
# Il y a un lien significatif entre 25-29 et 40-44. P-value = 0.000
# Il y a un lien significatif entre 25-29 et 45-49. P-value = 0.000
# Il y a un lien significatif entre 25-29 et 50-54. P-value = 0.000
# Il y a un lien significatif entre 25-29 et 55-59. P-value = 0.000
# Il y a un lien significatif entre 25-29 et 60-64. P-value = 0.000
# Il y a un lien significatif entre 25-29 et 65-69. P-value = 0.000
# Il y a un lien significatif entre 25-29 et 70-74. P-value = 0.000
# Il y a un lien significatif entre 25-29 et 75-79. P-value = 0.000
# Il y a un lien significatif entre 25-29 et 80+. P-value = 0.000
# Il y a un lien significatif entre 25-29 et American Indian/Alaskan Native. P-value = 0.004
# Il y a un lien significatif entre 25-29 et Asian. P-value = 0.000
# Il y a un lien significatif entre 25-29 et Black. P-value = 0.000
# Il y a un lien significatif entre 25-29 et Hispanic. P-value = 0.000
# Il y a un lien significatif entre 25-29 et Other. P-value = 0.000
# Il y a un lien significatif entre 25-29 et White. P-value = 0.000
# Il y a un lien significatif entre 25-29 et No_diabetic. P-value = 0.000
# Il y a un lien significatif entre 25-29 et No_borderline_diabetic. P-value = 0.000
# Il y a un lien significatif entre 25-29 et Yes_diabetic. P-value = 0.000
# Il n'y a pas de lien significatif entre 25-29 et Yes_pregnancy_diabetic. P-value = 0.488
# Il y a un lien significatif entre 30-34 et HeartDisease. P-value = 0.000
# Il y a un lien significatif entre 30-34 et Smoking. P-value = 0.000
# Il y a un lien significatif entre 30-34 et AlcoholDrinking. P-value = 0.000
# Il y a un lien significatif entre 30-34 et Stroke. P-value = 0.000
# Il y a un lien significatif entre 30-34 et DiffWalking. P-value = 0.000
# Il y a un lien significatif entre 30-34 et Sex. P-value = 0.000
# Il y a un lien significatif entre 30-34 et PhysicalActivity. P-value = 0.000
# Il y a un lien significatif entre 30-34 et Asthma. P-value = 0.000
# Il y a un lien significatif entre 30-34 et KidneyDisease. P-value = 0.000
# Il y a un lien significatif entre 30-34 et SkinCancer. P-value = 0.000
# Il y a un lien significatif entre 30-34 et Excellent. P-value = 0.000
# Il y a un lien significatif entre 30-34 et Fair. P-value = 0.000
# Il y a un lien significatif entre 30-34 et Good. P-value = 0.000
# ...
# Il y a un lien significatif entre Other et 70-74. P-value = 0.000
# Il y a un lien significatif entre Other et 75-79. P-value = 0.000
# Il y a un lien significatif entre Other et 80+. P-value = 0.000
# Il y a un lien significatif entre Other et American Indian/Alaskan Native. P-value = 0.000
# Il y a un lien significatif entre Other et Asian. P-value = 0.000
# Il y a un lien significatif entre Other et Black. P-value = 0.000
# Il y a un lien significatif entre Other et Hispanic. P-value = 0.000
# Il y a un lien significatif entre Other et Other. P-value = 0.000
# Il y a un lien significatif entre Other et White. P-value = 0.000
# Il y a un lien significatif entre Other et No_diabetic. P-value = 0.000
# Il y a un lien significatif entre Other et No_borderline_diabetic. P-value = 0.000
# Il y a un lien significatif entre Other et Yes_diabetic. P-value = 0.028
# Il y a un lien significatif entre Other et Yes_pregnancy_diabetic. P-value = 0.000
# Il y a un lien significatif entre White et HeartDisease. P-value = 0.000
# Il y a un lien significatif entre White et Smoking. P-value = 0.000
# Il y a un lien significatif entre White et AlcoholDrinking. P-value = 0.000
# Il n'y a pas de lien significatif entre White et Stroke. P-value = 0.521
# Il y a un lien significatif entre White et DiffWalking. P-value = 0.000
# Il y a un lien significatif entre White et Sex. P-value = 0.000
# Il y a un lien significatif entre White et PhysicalActivity. P-value = 0.000
# Il y a un lien significatif entre White et Asthma. P-value = 0.000
# Il y a un lien significatif entre White et KidneyDisease. P-value = 0.001
# Il y a un lien significatif entre White et SkinCancer. P-value = 0.000
# Il y a un lien significatif entre White et Excellent. P-value = 0.004
# Il y a un lien significatif entre White et Fair. P-value = 0.000
# Il y a un lien significatif entre White et Good. P-value = 0.000
# Il y a un lien significatif entre White et Poor. P-value = 0.000
# Il y a un lien significatif entre White et VeryGood. P-value = 0.000
# Il y a un lien significatif entre White et 18-24. P-value = 0.000
# Il y a un lien significatif entre White et 25-29. P-value = 0.000
# Il y a un lien significatif entre White et 30-34. P-value = 0.000
# Il y a un lien significatif entre White et 35-39. P-value = 0.000
# Il y a un lien significatif entre White et 40-44. P-value = 0.000
# Il y a un lien significatif entre White et 45-49. P-value = 0.000
# Il y a un lien significatif entre White et 50-54. P-value = 0.000
# Il y a un lien significatif entre White et 55-59. P-value = 0.000
# Il y a un lien significatif entre White et 60-64. P-value = 0.000
# Il y a un lien significatif entre White et 65-69. P-value = 0.000
# Il y a un lien significatif entre White et 70-74. P-value = 0.000
# Il y a un lien significatif entre White et 75-79. P-value = 0.000
# Il y a un lien significatif entre White et 80+. P-value = 0.000
# Il y a un lien significatif entre White et American Indian/Alaskan Native. P-value = 0.000
# Il y a un lien significatif entre White et Asian. P-value = 0.000
# Il y a un lien significatif entre White et Black. P-value = 0.000
# Il y a un lien significatif entre White et Hispanic. P-value = 0.000
# Il y a un lien significatif entre White et Other. P-value = 0.000
# Il y a un lien significatif entre White et White. P-value = 0.000
# Il y a un lien significatif entre White et No_diabetic. P-value = 0.000
# Il y a un lien significatif entre White et No_borderline_diabetic. P-value = 0.000
# Il y a un lien significatif entre White et Yes_diabetic. P-value = 0.000
# Il y a un lien significatif entre White et Yes_pregnancy_diabetic. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et HeartDisease. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et Smoking. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et AlcoholDrinking. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et Stroke. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et DiffWalking. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et Sex. P-value = 0.040
# Il y a un lien significatif entre No_diabetic et PhysicalActivity. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et Asthma. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et KidneyDisease. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et SkinCancer. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et Excellent. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et Fair. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et Good. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et Poor. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et VeryGood. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et 18-24. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et 25-29. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et 30-34. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et 35-39. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et 40-44. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et 45-49. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et 50-54. P-value = 0.007
# Il y a un lien significatif entre No_diabetic et 55-59. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et 60-64. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et 65-69. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et 70-74. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et 75-79. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et 80+. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et American Indian/Alaskan Native. P-value = 0.000
# Il n'y a pas de lien significatif entre No_diabetic et Asian. P-value = 0.149
# Il y a un lien significatif entre No_diabetic et Black. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et Hispanic. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et Other. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et White. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et No_diabetic. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et No_borderline_diabetic. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et Yes_diabetic. P-value = 0.000
# Il y a un lien significatif entre No_diabetic et Yes_pregnancy_diabetic. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et HeartDisease. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et Smoking. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et AlcoholDrinking. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et Stroke. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et DiffWalking. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et Sex. P-value = 0.016
# Il y a un lien significatif entre No_borderline_diabetic et PhysicalActivity. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et Asthma. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et KidneyDisease. P-value = 0.005
# Il y a un lien significatif entre No_borderline_diabetic et SkinCancer. P-value = 0.001
# Il y a un lien significatif entre No_borderline_diabetic et Excellent. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et Fair. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et Good. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et Poor. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et VeryGood. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et 18-24. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et 25-29. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et 30-34. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et 35-39. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et 40-44. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et 45-49. P-value = 0.002
# Il n'y a pas de lien significatif entre No_borderline_diabetic et 50-54. P-value = 0.595
# Il y a un lien significatif entre No_borderline_diabetic et 55-59. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et 60-64. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et 65-69. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et 70-74. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et 75-79. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et 80+. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et American Indian/Alaskan Native. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et Asian. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et Black. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et Hispanic. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et Other. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et White. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et No_diabetic. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et No_borderline_diabetic. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et Yes_diabetic. P-value = 0.000
# Il y a un lien significatif entre No_borderline_diabetic et Yes_pregnancy_diabetic. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et HeartDisease. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et Smoking. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et AlcoholDrinking. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et Stroke. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et DiffWalking. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et Sex. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et PhysicalActivity. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et Asthma. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et KidneyDisease. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et SkinCancer. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et Excellent. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et Fair. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et Good. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et Poor. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et VeryGood. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et 18-24. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et 25-29. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et 30-34. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et 35-39. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et 40-44. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et 45-49. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et 50-54. P-value = 0.001
# Il y a un lien significatif entre Yes_diabetic et 55-59. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et 60-64. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et 65-69. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et 70-74. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et 75-79. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et 80+. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et American Indian/Alaskan Native. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et Asian. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et Black. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et Hispanic. P-value = 0.022
# Il y a un lien significatif entre Yes_diabetic et Other. P-value = 0.028
# Il y a un lien significatif entre Yes_diabetic et White. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et No_diabetic. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et No_borderline_diabetic. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et Yes_diabetic. P-value = 0.000
# Il y a un lien significatif entre Yes_diabetic et Yes_pregnancy_diabetic. P-value = 0.000
# Il y a un lien significatif entre Yes_pregnancy_diabetic et HeartDisease. P-value = 0.000
# Il y a un lien significatif entre Yes_pregnancy_diabetic et Smoking. P-value = 0.002
# Il y a un lien significatif entre Yes_pregnancy_diabetic et AlcoholDrinking. P-value = 0.023
# Il y a un lien significatif entre Yes_pregnancy_diabetic et Stroke. P-value = 0.012
# Il y a un lien significatif entre Yes_pregnancy_diabetic et DiffWalking. P-value = 0.000
# Il y a un lien significatif entre Yes_pregnancy_diabetic et Sex. P-value = 0.000
# Il n'y a pas de lien significatif entre Yes_pregnancy_diabetic et PhysicalActivity. P-value = 0.409
# Il y a un lien significatif entre Yes_pregnancy_diabetic et Asthma. P-value = 0.000
# Il y a un lien significatif entre Yes_pregnancy_diabetic et KidneyDisease. P-value = 0.009
# Il y a un lien significatif entre Yes_pregnancy_diabetic et SkinCancer. P-value = 0.000
# Il n'y a pas de lien significatif entre Yes_pregnancy_diabetic et Excellent. P-value = 0.093
# Il n'y a pas de lien significatif entre Yes_pregnancy_diabetic et Fair. P-value = 0.701
# Il y a un lien significatif entre Yes_pregnancy_diabetic et Good. P-value = 0.018
# Il y a un lien significatif entre Yes_pregnancy_diabetic et Poor. P-value = 0.019
# Il n'y a pas de lien significatif entre Yes_pregnancy_diabetic et VeryGood. P-value = 0.882
# Il y a un lien significatif entre Yes_pregnancy_diabetic et 18-24. P-value = 0.000
# Il n'y a pas de lien significatif entre Yes_pregnancy_diabetic et 25-29. P-value = 0.488
# Il y a un lien significatif entre Yes_pregnancy_diabetic et 30-34. P-value = 0.000
# Il y a un lien significatif entre Yes_pregnancy_diabetic et 35-39. P-value = 0.000
# Il y a un lien significatif entre Yes_pregnancy_diabetic et 40-44. P-value = 0.000
# Il y a un lien significatif entre Yes_pregnancy_diabetic et 45-49. P-value = 0.000
# Il y a un lien significatif entre Yes_pregnancy_diabetic et 50-54. P-value = 0.037
# Il y a un lien significatif entre Yes_pregnancy_diabetic et 55-59. P-value = 0.002
# Il y a un lien significatif entre Yes_pregnancy_diabetic et 60-64. P-value = 0.000
# Il y a un lien significatif entre Yes_pregnancy_diabetic et 65-69. P-value = 0.000
# Il y a un lien significatif entre Yes_pregnancy_diabetic et 70-74. P-value = 0.000
# Il y a un lien significatif entre Yes_pregnancy_diabetic et 75-79. P-value = 0.000
# Il y a un lien significatif entre Yes_pregnancy_diabetic et 80+. P-value = 0.000
# Il n'y a pas de lien significatif entre Yes_pregnancy_diabetic et American Indian/Alaskan Native. P-value = 0.062
# Il y a un lien significatif entre Yes_pregnancy_diabetic et Asian. P-value = 0.000
# Il n'y a pas de lien significatif entre Yes_pregnancy_diabetic et Black. P-value = 0.641
# Il y a un lien significatif entre Yes_pregnancy_diabetic et Hispanic. P-value = 0.000
# Il y a un lien significatif entre Yes_pregnancy_diabetic et Other. P-value = 0.000
# Il y a un lien significatif entre Yes_pregnancy_diabetic et White. P-value = 0.000
# Il y a un lien significatif entre Yes_pregnancy_diabetic et No_diabetic. P-value = 0.000
# Il y a un lien significatif entre Yes_pregnancy_diabetic et No_borderline_diabetic. P-value = 0.000
# Il y a un lien significatif entre Yes_pregnancy_diabetic et Yes_diabetic. P-value = 0.000
# Il y a un lien significatif entre Yes_pregnancy_diabetic et Yes_pregnancy_diabetic. P-value = 0.000

# %% [markdown]
# Au seuil de 5%, il existe de nombreux couples de variables qualitatives qui ont des liens entre elles. En particulier avec la variable target.

# %% [markdown]
# ##### II.4.3 - Liens entre les variables quantitatives & qualitatives

# %%
# Affichez les moyennes pour chaque groupe
print(df_to_train.groupby('HeartDisease')['BMI'].mean())
print(df_to_train.groupby('HeartDisease')['MentalHealth'].mean())
print(df_to_train.groupby('HeartDisease')['PhysicalHealth'].mean())
print(df_to_train.groupby('HeartDisease')['SleepTime'].mean())

# Effectuez le test t de Student pour chaque variable
def perform_t_test(grouped_df, variable_name):
    group1 = grouped_df.get_group(0)  # Remplacez 0 par la catégorie de référence
    group2 = grouped_df.get_group(1)  # Remplacez 1 par l'autre catégorie
    t_statistic, p_value = ttest_ind(group1[variable_name], group2[variable_name], equal_var=False)
    print(f"\nTest t-statistic ({variable_name}):", t_statistic)
    print(f"P-value ({variable_name}):", p_value)

# Effectuez le test t de Student pour chaque variable
grouped_df = df_to_train.groupby('HeartDisease')
perform_t_test(grouped_df, 'BMI')
perform_t_test(grouped_df, 'MentalHealth')
perform_t_test(grouped_df, 'PhysicalHealth')
perform_t_test(grouped_df, 'SleepTime')
# Out:
# HeartDisease
# 0    28.224658
# 1    29.401592
# Name: BMI, dtype: float64
# HeartDisease
# 0    3.828778
# 1    4.641764
# Name: MentalHealth, dtype: float64
# HeartDisease
# 0    2.956416
# 1    7.808242
# Name: PhysicalHealth, dtype: float64
# HeartDisease
# 0    7.093416
# 1    7.136156
# Name: SleepTime, dtype: float64
#
# Test t-statistic (BMI): -28.401634262333364
# P-value (BMI): 2.7721495948880634e-175
#
# Test t-statistic (MentalHealth): -14.18925411954749
# P-value (MentalHealth): 1.4801017749729575e-45
#
# Test t-statistic (PhysicalHealth): -68.55723076591224
# P-value (PhysicalHealth): 0.0
#
# Test t-statistic (SleepTime): -3.8606587009234725
# P-value (SleepTime): 0.00011331398017915307

# %% [markdown]
# Conclusions :
# * Il y a une différence significative d'IMC entre le groupe des personnes n'ayant pas de maladie cardiaque (HeartDisease = 0) et le groupe des personnes ayant une maladie cardiaque (HeartDisease = 1)
# * Il y a une différence significative dans la santé mentale entre les deux groupes
# * Il y a une différence significative dans la santé physique entre les deux groupes
# * Il y a une différence significative dans le temps de sommeil entre les deux groupes

# %% [markdown]
# #### II.5 - Feature Selection

# %%
# Séparer les caractéristiques (X) de la variable cible (y)
X = qualis.drop("HeartDisease", axis=1)
y = qualis["HeartDisease"]

# Appliquer le test du Chi2 pour sélectionner les caractéristiques les plus importantes
# Toutes les caractéristiques seront conservées par défaut, SelectKBest pour séléctionner K optimal
#k = 6  # Pour changer k
#chi2_selector = SelectKBest(chi2, k=k)
chi2_selector = SelectKBest(chi2)
X_kbest = chi2_selector.fit_transform(X, y)

# Afficher les noms des caractéristiques sélectionnées
selected_features = X.columns[chi2_selector.get_support()]
print("Caractéristiques sélectionnées:", selected_features.tolist())
# Out:
# Caractéristiques sélectionnées: ['Stroke', 'DiffWalking', 'KidneyDisease', 'SkinCancer', 'Excellent', 'Fair', 'Poor', '75-79', '80+', 'Yes_diabetic']

# %% [markdown]
# Nous réalisons un Chi2 Feature Selection. On utilise le Chi2 comme méthode de sélection en fonction d'un test statistique. `SelectKBest` sélectionne les meilleures caractéristiques en fonction d'une mesure spécifique fournie en tant que paramètre.

# %% [markdown]
# On obtient le dataframe suivant :

# %%
# Liste des variables à conserver
selected_variables = ['HeartDisease', 'BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime',
                       'Stroke', 'DiffWalking', 'KidneyDisease', 'SkinCancer', 
                       'Excellent', 'Fair', 'Poor', '75-79', '80+', 'Yes_diabetic']

# Sélectionner les colonnes spécifiées dans un nouveau DataFrame
df_model = df_without_outliers1[selected_variables].copy()

# %%
df_model.sample(5)
# Out:
#         HeartDisease    BMI  PhysicalHealth  MentalHealth  SleepTime  Stroke  \
# 280015             1  25.39             0.0           0.0        7.0       0
# 157215             0  27.40             0.0           0.0        6.0       0
# 131270             0  31.64             2.0           2.0        7.0       0
# 84645              0  31.20             0.0           0.0        7.0       0
# 180385             0  26.50             0.0           2.0        6.0       0
#
#         DiffWalking  KidneyDisease  SkinCancer  Excellent  Fair  Poor  75-79  \
# 280015            0              0           0          0     0     0      0
# 157215            0              0           0          0     0     0      0
# 131270            0              1           0          0     0     0      0
# 84645             0              0           0          0     0     0      0
# 180385            0              0           0          0     0     0      0
#
#         80+  Yes_diabetic
# 280015    0             0
# 157215    0             0
# 131270    1             0
# 84645     0             0
# 180385    0             0

# %% [markdown]
# Nous avons alors 14 variables explicatives, il serait intéressant de diminuer la valeur de k par la suite.

# %% [markdown]
# Deuxième feature selection basée sur la variance

# %%
# Supprimer les caractéristiques avec une variance inférieure à un seuil
selector = VarianceThreshold(threshold=0.1)
X_selected = selector.fit_transform(qualis.drop("HeartDisease", axis=1), qualis["HeartDisease"])

# Récupérer les noms des caractéristiques sélectionnées
selected_feature_names = qualis.drop("HeartDisease", axis=1).columns[selector.get_support()]

# Afficher les noms des caractéristiques sélectionnées
print("Caractéristiques sélectionnées:", selected_feature_names.tolist())
# Out:
# Caractéristiques sélectionnées: ['Smoking', 'DiffWalking', 'Sex', 'PhysicalActivity', 'Asthma', 'Excellent', 'Good', 'VeryGood', 'White', 'No_diabetic', 'Yes_diabetic']

# %%
# Liste des variables à conserver
selected_variables = ['HeartDisease', 'BMI', 'SleepTime', 'PhysicalHealth', 'MentalHealth',
                      'Smoking', 'DiffWalking', 'Sex', 'PhysicalActivity', 'Asthma', 'Excellent', 'Good', 'VeryGood', 'White', 'No_diabetic', 'Yes_diabetic']

# Sélectionner les colonnes spécifiées dans un nouveau DataFrame
df_model_15 = df_without_outliers1[selected_variables].copy()

# %% [markdown]
# Certaines variables sont communes mais nous en obtenons pas mal de différentes donc ça peut être intéressant

# %% [markdown]
# ### III - Préparation des données

# %% [markdown]
# #### III.1 - Split du jeu de données

# %%
#Train and test
X_train , X_test, y_train, y_test = train_test_split(df_model.iloc[:,1:],
                                                     df_model.HeartDisease,
                                                     test_size=0.2)

# %%
#Target déséquilibrée
y_train.value_counts()
# Out:
# 0    124204
# 1      9081
# Name: HeartDisease, dtype: int64

# %% [markdown]
# Comme nous l'avions constaté, la target est déséquilibré : nous procédons à un sous-échantillonage sur les données d'entraînement

# %%
# Appliquer l'échantillonnage stratifié uniquement sur l'ensemble d'entraînement
sampler = RandomUnderSampler(sampling_strategy='auto', random_state=42)
X_train_resampled, y_train_resampled = sampler.fit_resample(X_train, y_train)

# %%
#Target équilibrée
y_train_resampled.value_counts()
# Out:
# 0    9081
# 1    9081
# Name: HeartDisease, dtype: int64

# %% [markdown]
# Désormais elle est équilibrée

# %%
# Mapping des classes à des labels plus explicites
class_labels = {0: "Non", 1: "Oui"}

# Remplacement des labels dans y_train_resampled
y_train_resampled_labels = y_train_resampled.map(class_labels)

# Création du pie plot
plt.figure(figsize=(6, 6))
y_train_resampled_labels.value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
plt.title('Répartition des classes après sous-échantillonnage')
plt.ylabel('')  # Supprime l'étiquette du côté y
plt.show()

# %% [markdown]
# Le rééchantillonnage est souvent appliqué dans des ensembles de données déséquilibrés pour équilibrer la représentation des classes. Il est généralement recommandé de rééchantillonner uniquement l'ensemble d'entraînement pour plusieurs raisons :
#
# 1. **Préservation de la réalité du problème :** Le modèle doit généraliser à de nouvelles données qui reflètent la distribution réelle du problème.
#
# 2. **Évaluation sur des données non modifiées :** En conservant l'ensemble de test inchangé, l'évaluation du modèle reste représentative des conditions réelles.
#
# 3. **Éviter la fuite d'informations :** Rééchantillonner l'ensemble de test peut conduire à une fuite d'informations, biaisant l'évaluation du modèle.
#
# 4. **Considérations pratiques :** Souvent, l'ensemble d'entraînement est beaucoup plus grand, justifiant le rééchantillonnage pour compenser le déséquilibre de classe.

# %% [markdown]
# #### III.2 - Standardisation

# %% [markdown]
# On standardise uniquement sur les variables quantitatives

# %%
# Sélection des variables à scaler
selected_features = ["BMI", "PhysicalHealth", "MentalHealth", "SleepTime"]

# Création d'un scaler
scaler = StandardScaler()

# Calcul de la moyenne et de l'écart type sur X_train_resampled pour les variables sélectionnées
scaler.fit(X_train_resampled[selected_features])
# Out:
# StandardScaler()

# %% [markdown]
# On rajoute les variables qualitatives au dataframe où les variables quantitatives ont été standardisées

# %%
# Transformation des variables sélectionnées dans X_train_resampled
X_train_resampled[selected_features] = scaler.transform(X_train_resampled[selected_features])

# Transformation des variables sélectionnées dans X_test
X_test[selected_features] = scaler.transform(X_test[selected_features])

# Renommer les DataFrames
X_train_resampled_sc = X_train_resampled.copy()
X_test_sc = X_test.copy()

# %% [markdown]
# | Bases                  | Description                              |
# |------------------------|------------------------------------------|
# | X_train_resampled_sc | X train ré-échantillonné 1ere analyse    |
# | X_test_sc            | X test 1ere analyse                       |
# | y_train_resampled    | y train ré-échantillonné 1ere analyse    |
# | y_test              | y test 1ere analyse                       |

# %%
X_train_resampled_sc.sample(5)
# Out:
#              BMI  SleepTime  Smoking  Sex  PhysicalActivity  Excellent  Good  \
# 238061  0.815257  -1.518730        1    1                 1          0     1
# 281191  1.137604   1.066471        1    1                 1          0     1
# 229369 -0.771915  -1.518730        1    1                 1          0     0
# 241600  1.834486   1.066471        1    0                 1          0     0
# 25883   0.056976   1.066471        1    0                 0          0     0
#
#         VeryGood  White
# 238061         0      0
# 281191         0      1
# 229369         1      1
# 241600         0      0
# 25883          1      0

# %%
X_test_sc.head(5)
# Out:
#              BMI  PhysicalHealth  MentalHealth  SleepTime  Stroke  \
# 298128 -0.977618       -0.402281      1.000572  -0.231153       0
# 88271  -0.808252        0.565545     -0.406040  -0.231153       0
# 15928  -1.467240        4.436848     -0.406040  -1.523152       0
# 104214 -0.038406       -0.402281     -0.406040  -0.231153       0
# 206842 -0.768220       -0.402281     -0.406040  -0.231153       0
#
#         DiffWalking  KidneyDisease  SkinCancer  Excellent  Fair  Poor  75-79  \
# 298128            0              0           1          0     0     0      0
# 88271             0              0           0          0     0     0      0
# 15928             0              0           0          0     1     0      0
# 104214            0              0           1          0     0     0      0
# 206842            0              0           0          0     0     0      0
#
#         80+  Yes_diabetic
# 298128    0             0
# 88271     0             0
# 15928     1             0
# 104214    0             1
# 206842    0             0

# %% [markdown]
# ### IV - Modèles

# %% [markdown]
# #### IV.1 - Modèle ré-échantilloné avec 14 variables

# %% [markdown]
# ##### IV.1.1 - Comparaisons

# %% [markdown]
# On réalise 10 différents modèles

# %%
# Regression logistique
lgr = LogisticRegression(random_state=42)
lgr.fit(X_train_resampled_sc, y_train_resampled)

#Linear SVM
l_SVC = LinearSVC(random_state=42, max_iter=2000)
l_SVC.fit(X_train_resampled_sc, y_train_resampled)

#SVM avec kernel
svc = SVC(kernel='linear',random_state=42)
svc.fit(X_train_resampled_sc,y_train_resampled)

#SVM avec noyau RBF
rbf_svc = SVC(kernel='rbf', random_state=42)
rbf_svc.fit(X_train_resampled_sc, y_train_resampled)

#SGD poly
svc_poly = SVC(kernel='poly',random_state=0)
svc_poly.fit(X_train_resampled_sc, y_train_resampled)

#SGD classifier
sgdc_svm = SGDClassifier(loss='hinge' ,random_state=42)
sgdc_svm.fit(X_train_resampled_sc, y_train_resampled)

#Random Forest
rf_classifier = RandomForestClassifier(random_state=42)
rf_classifier.fit(X_train_resampled_sc, y_train_resampled)

#Gradient Boosting
gb_classifier = GradientBoostingClassifier(random_state=42)
gb_classifier.fit(X_train_resampled_sc, y_train_resampled)

#XGBoost
xgb_classifier = XGBClassifier(random_state=42)
xgb_classifier.fit(X_train_resampled_sc, y_train_resampled)

#K-Nearest Neighbors 
knn_classifier = KNeighborsClassifier()
knn_classifier.fit(X_train_resampled_sc, y_train_resampled)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ##### IV.1.2 - Choix du modèle

# %% [markdown]
# On effectue une validation croisée à 5 folds pour mesurer la performance des différents modèles

# %%
# Get cross_val_score for each function

cvs_lgr = cross_val_score(lgr, X_train_resampled_sc, y_train_resampled, cv=5, scoring='accuracy')

cvs_lsvc = cross_val_score(l_SVC, X_train_resampled_sc, y_train_resampled, cv=5, scoring='accuracy')

cvs_svc = cross_val_score(svc, X_train_resampled_sc, y_train_resampled, cv=5, scoring='accuracy')

cvs_rbf = cross_val_score(rbf_svc, X_train_resampled_sc, y_train_resampled, cv=5, scoring='accuracy')

cvs_poly = cross_val_score(svc_poly, X_train_resampled_sc, y_train_resampled, cv=5, scoring='accuracy')

cvs_sgdc = cross_val_score(sgdc_svm, X_train_resampled_sc, y_train_resampled, cv=5, scoring='accuracy')

cvs_rf = cross_val_score(rf_classifier, X_train_resampled_sc, y_train_resampled, cv=5, scoring='accuracy')

cvs_gb = cross_val_score(gb_classifier, X_train_resampled_sc, y_train_resampled, cv=5, scoring='accuracy')

cvs_xgb = cross_val_score(xgb_classifier, X_train_resampled_sc, y_train_resampled, cv=5, scoring='accuracy')

cvs_knn = cross_val_score(knn_classifier, X_train_resampled_sc, y_train_resampled, cv=5, scoring='accuracy')

# %%
#Get data output from cross_val_score
df_cross = pd.DataFrame(np.transpose(np.c_[cvs_lgr,cvs_lsvc,cvs_svc,cvs_rbf,cvs_poly,cvs_sgdc,cvs_rf,cvs_gb,cvs_xgb,cvs_knn]), 
                        columns=['fold1','fold2','fold3','fold4','fold5'])
#Adding model label
df_cross['model'] = ['lgr','lsvc','svc','rbf', 'poly', 'sgdc', 'rf', 'gb', 'xgb', 'knn']

# %%
df_cross
# Out:
#       fold1     fold2     fold3     fold4     fold5 model
# 0  0.680332  0.699640  0.677196  0.685231  0.681629   lgr
# 1  0.683380  0.700194  0.671931  0.683569  0.679135  lsvc
# 2  0.659003  0.678304  0.650319  0.664450  0.651704   svc
# 3  0.667867  0.697423  0.673040  0.683569  0.677473   rbf
# 4  0.670637  0.696592  0.673871  0.684677  0.677196  poly
# 5  0.659003  0.678304  0.650319  0.664450  0.651704  sgdc
# 6  0.601662  0.608202  0.596010  0.597395  0.601829    rf
# 7  0.674238  0.693821  0.674148  0.682738  0.677750    gb
# 8  0.664266  0.674425  0.656415  0.662787  0.675533   xgb
# 9  0.627978  0.641452  0.620116  0.624550  0.629260   knn

# %%
#Regardons l'évolution des scores pour chaque fold
for row in range(df_cross.shape[0]):
    plt.plot( df_cross.iloc[row,0:4] ,label='Line '+str(df_cross.iloc[row,5]))

plt.legend()
plt.title("Evolution de l'accuracy en fonction des folds")
plt.show()

# %%
for i in range(10):

    mean_model = df_cross.iloc[:,0:5].mean(axis=1)[i]
    std_model = df_cross.iloc[:,0:5].std(axis=1)[i]
    
    print('Le modèle N° '+ str(i) + ' a une accuray de '  + str(mean_model) + ' et un std : ' + str(std_model))
# Out:
# Le modèle N° 0 a une accuray de 0.6848057449481867 et un std : 0.008778390556330588
# Le modèle N° 1 a une accuray de 0.6836418188139992 et un std : 0.010386181999531438
# Le modèle N° 2 a une accuray de 0.660755943321137 et un std : 0.011352706230009082
# Le modèle N° 3 a une accuray de 0.679874321582931 et un std : 0.011382705614966062
# Le modèle N° 4 a une accuray de 0.6805945892424985 et un std : 0.010350008949478125
# Le modèle N° 5 a une accuray de 0.660755943321137 et un std : 0.011352706230009082
# Le modèle N° 6 a une accuray de 0.6010195809337844 et un std : 0.004766588581193413
# Le modèle N° 7 a une accuray de 0.6805389726668248 et un std : 0.008209273270730195
# Le modèle N° 8 a une accuray de 0.6666852720461082 et un std : 0.008135227610601856
# Le modèle N° 9 a une accuray de 0.6286712120898125 et un std : 0.00797411559061412

# %% [markdown]
# Le meilleur modèle en terme d'accuracy est le lgr (même s'il n'a pas le std le plus faible, le modèle en a un assez faible)

# %% [markdown]
# ##### IV.1.3 - Grid Search

# %%
LogisticRegression().get_params()
# Out:
# {'C': 1.0,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 100,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
params = {
    'penalty': ['l1', 'l2'],
    'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
    'solver': ['liblinear', 'saga'],
    'class_weight': [None, 'balanced'],
    'max_iter': [100, 200, 300]  
}

c_lgr = LogisticRegression(random_state=42)

# %%
grid_c_lgr_= GridSearchCV(c_lgr, param_grid=params, cv=5, return_train_score=True)

# %%
take_grid = grid_c_lgr_.fit(X_train_resampled_sc, y_train_resampled)

# %%
print("La meilleur combinaison d'estimateur est: " + str(take_grid.best_params_)+"\n"
      "pour un score de: " + str(take_grid.best_score_))
# Out:
# La meilleur combinaison d'estimateur est: {'C': 1, 'class_weight': None, 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear'}
# pour un score de: 0.6848057449481867

# %% [markdown]
# On constate que le `GridSearch` n'améliore pas le modèle, il reste pareil

# %% [markdown]
# ##### IV.1.4 - Learning curve

# %%
train_sizes, train_scores, test_scores = learning_curve(estimator=c_lgr, 
                                                        X=X_train_resampled_sc, 
                                                        y=y_train_resampled,
                                                        cv=5, 
                                                        train_sizes=np.linspace(0.1, 1.0, 5),
                                                        random_state=42
                                                       )

#
# Trop de fluctuation dans le modèle, on calcule la moyenne des métriques
#
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)
#
# Plot the learning curve
#
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Accuracy')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes, test_mean, color='green', marker='+', markersize=5, linestyle='--', label='Validation Accuracy')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.title('Learning Curve')
plt.xlabel('Training Data Size')
plt.ylabel('Model accuracy')
plt.grid()
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# * La courbe bleue représente la précision d'entraînement, diminuant avec l'augmentation de la taille des données, indiquant une possible réduction du surapprentissage.
# * La courbe verte pointillée représente la précision de validation, augmentant avec la taille des données, montrant une amélioration de la généralisation du modèle.
# * Au début, il y a un grand écart entre la précision d'entraînement et de validation, suggérant un surapprentissage, mais cet écart diminue à mesure que la taille des données augmente, indiquant une meilleure généralisation du modèle.
#
# En résumé, l'ajout de données d'entraînement améliore la capacité du modèle à généraliser sur de nouvelles données, comme le montre l'augmentation de la précision de validation, et il y a une tendance vers une meilleure convergence entre la performance sur les données d'entraînement et de validation, ce qui est souhaitable dans la construction de modèles de machine learning.

# %% [markdown]
# ##### IV.1.5 - Matrice de confusion

# %%
take_grid.best_params_
# Out:
# {'C': 1,
#  'class_weight': None,
#  'max_iter': 100,
#  'penalty': 'l1',
#  'solver': 'liblinear'}

# %%
best_lgr = LogisticRegression(C=1, class_weight=None, max_iter=100, penalty='l1', solver='liblinear')

# %%
best_lgr.fit(X_train_resampled_sc, y_train_resampled)
# Out:
# LogisticRegression(C=1, penalty='l1', solver='liblinear')

# %%
print('Training score: ' + str(best_lgr.score(X_train_resampled_sc, y_train_resampled)), 
      '\n',
      'Test score: ' + str(best_lgr.score(X_test_sc, y_test))
     )
# Out:
# Training score: 0.6846946691787654
#  Test score: 0.6856731288638137

# %% [markdown]
# Les scores sont équivalents, le modèle semble stable : pas de sur/sous ajustement

# %%
# Créer le modèle de régression logistique avec les paramètres optimaux
modele_regression_logistique = LogisticRegression(C=1, class_weight=None, max_iter=100, penalty='l1', solver='liblinear')

# Entraîner le modèle avec vos données
modele_regression_logistique.fit(X_train_resampled_sc, y_train_resampled)

# Faire des prédictions avec le modèle entraîné
predictions = modele_regression_logistique.predict(X_test)

# %%
# Calculer la matrice de confusion en pourcentage
total = np.sum(matrice_confusion)
matrice_confusion_percent = (matrice_confusion / total) * 100

# Créer le graphique de la matrice de confusion en pourcentage
plt.figure(figsize=(8, 6))
sns.heatmap(matrice_confusion_percent, annot=True, fmt=".2f", cmap="Blues", cbar=False)
plt.xlabel("Prédictions")
plt.ylabel("Valeurs réelles")
plt.title("Matrice de confusion en pourcentage")
plt.show()

# %% [markdown]
# 71.98% des échantillons sans maladie cardiaque ont été correctement prédits comme n'ayant pas de maladie cardiaque, et 4.52% des échantillons avec maladie cardiaque ont été correctement prédits comme en ayant une. Le modèle prédit mal les gens ayant réellement une maladie cardiaque

# %%
# Prédire les étiquettes sur l'ensemble de test et d'entraînement
y_pred_train = best_lgr.predict(X_train_resampled_sc)
y_pred_test = best_lgr.predict(X_test_sc)

# Calculer le score F1 pour l'ensemble d'entraînement et de test
f1_train = f1_score(y_train_resampled, y_pred_train)
f1_test = f1_score(y_test, y_pred_test)

# Afficher les scores F1
print('F1 Score (Entraînement): {:.4f}'.format(f1_train))
print('F1 Score (Test): {:.4f}'.format(f1_test))
# Out:
# F1 Score (Entraînement): 0.6824
# F1 Score (Test): 0.2269

# %% [markdown]
# F1 Score plutôt faible

# %% [markdown]
# ##### IV.1.6 - Importance des variables

# %%
# Récupérer les coefficients du modèle
coefficients = best_lgr.coef_[0]

# Récupérer les noms des variables
feature_names = X_train_resampled_sc.columns

# Trier les indices par ordre décroissant des coefficients absolus
sorted_indices = np.argsort(np.abs(coefficients))[::-1]

# Tracer l'importance des variables
plt.figure(figsize=(10, 6))
plt.bar(range(len(coefficients)), coefficients[sorted_indices])
plt.xticks(range(len(coefficients)), np.array(feature_names)[sorted_indices], rotation=45, ha='right')
plt.xlabel('Variables')
plt.ylabel('Coefficient')
plt.title('Importance des Variables dans le Modèle de Régression Logistique')
plt.tight_layout()
plt.show()

# %% [markdown]
# * Avoir un santé excellente, très bonne ou bonne entraîne une baisse de la probabilité d'avoir une maladie cardiaque
# * Être blanc ou le fait d'être un homme augmente la probabilité d'avoir une maladie cardiaque

# %% [markdown]
# #### IV.2 - Modèle ré-échantilloné avec 8 variables

# %% [markdown]
# On refait l'analyse en réduisant le nombre de variables, on en choisit 6 arbitrairement car au dessus on constate que 6 variables semblent particulièrement importantes

# %%
# Séparer les caractéristiques (X) de la variable cible (y)
X = qualis.drop("HeartDisease", axis=1)
y = qualis["HeartDisease"]

# Appliquer le test du Chi2 pour sélectionner les caractéristiques les plus importantes
# Toutes les caractéristiques seront conservées par défaut, SelectKBest pour séléctionner K optimal
#k = 6  # Pour changer k
#chi2_selector = SelectKBest(chi2, k=k)
chi2_selector = SelectKBest(chi2, k=6)
X_kbest = chi2_selector.fit_transform(X, y)

# Afficher les noms des caractéristiques sélectionnées
selected_features = X.columns[chi2_selector.get_support()]
print("Caractéristiques sélectionnées:", selected_features.tolist())
# Out:
# Caractéristiques sélectionnées: ['Stroke', 'DiffWalking', 'KidneyDisease', 'Fair', 'Poor', 'Yes_diabetic']

# %%
# Liste des variables à conserver
selected_variables = ['HeartDisease', 'BMI', 'SleepTime',
                       'Stroke', 'DiffWalking', 'KidneyDisease', 'Fair', 'Poor', 'Yes_diabetic']

# Sélectionner les colonnes spécifiées dans un nouveau DataFrame
df_model_8 = df_without_outliers1[selected_variables].copy()

# %% [markdown]
# De plus, on retire les deux variables qui contenaient des outliers

# %% [markdown]
# On refait exactement la même chose pour le modèle à 8 variables

# %%
#Train and test
X_train_8 , X_test_8, y_train_8, y_test_8 = train_test_split(df_model_8.iloc[:,1:],
                                                     df_model_8.HeartDisease,
                                                     test_size=0.2)

# Appliquer l'échantillonnage stratifié uniquement sur l'ensemble d'entraînement
sampler = RandomUnderSampler(sampling_strategy='auto', random_state=42)
X_train_resampled_8, y_train_resampled_8 = sampler.fit_resample(X_train_8, y_train_8)

# Sélection des variables à scaler
selected_features = ["BMI", "SleepTime"]

# Création d'un scaler
scaler = StandardScaler()

# Calcul de la moyenne et de l'écart type sur X_train_resampled pour les variables sélectionnées
scaler.fit(X_train_resampled_8[selected_features])

# Transformation des variables sélectionnées dans X_train_resampled
X_train_resampled_8[selected_features] = scaler.transform(X_train_resampled_8[selected_features])

# Transformation des variables sélectionnées dans X_test
X_test_8[selected_features] = scaler.transform(X_test_8[selected_features])

# %%
X_train_resampled_sc_8 = X_train_resampled_8.copy()
X_test_sc_8 = X_test_8.copy()

# %% [markdown]
# | Bases                  | Description                              |
# |------------------------|------------------------------------------|
# | X_train_resampled_sc_8 | X train ré-échantillonné 2nd analyse    |
# | X_test_sc_8            | X test 2nd analyse                       |
# | y_train_resampled_8    | y train ré-échantillonné 2nd analyse    |
# | y_test_8               | y test 2nd analyse                       |

# %%
X_train_resampled_sc_8.head(5)
# Out:
#              BMI  SleepTime  Stroke  DiffWalking  KidneyDisease  Fair  Poor  \
# 289574  1.536253  -0.230273       0            0              0     0     0
# 240116  0.136544   1.054669       0            0              0     0     0
# 236615 -1.026291   1.054669       0            0              0     0     0
# 263805  0.588758  -1.515216       0            0              0     0     0
# 124181 -1.180105   1.054669       0            0              0     0     0
#
#         Yes_diabetic
# 289574             0
# 240116             0
# 236615             0
# 263805             0
# 124181             0

# %% [markdown]
# ##### IV.2.1 - Comparaisons

# %%
# Regression logistique
lgr = LogisticRegression(random_state=42)
lgr.fit(X_train_resampled_sc_8, y_train_resampled_8)

#Linear SVM
l_SVC = LinearSVC(random_state=42, max_iter=2000)
l_SVC.fit(X_train_resampled_sc_8, y_train_resampled_8)

#SVM avec kernel
svc = SVC(kernel='linear',random_state=42)
svc.fit(X_train_resampled_sc_8, y_train_resampled_8)

#SVM avec noyau RBF
rbf_svc = SVC(kernel='rbf', random_state=42)
rbf_svc.fit(X_train_resampled_sc_8, y_train_resampled_8)

#SGD poly
svc_poly = SVC(kernel='poly',random_state=0)
svc_poly.fit(X_train_resampled_sc_8, y_train_resampled_8)

#SGD classifier
sgdc_svm = SGDClassifier(loss='hinge' ,random_state=42)
sgdc_svm.fit(X_train_resampled_sc_8, y_train_resampled_8)

#Random Forest
rf_classifier = RandomForestClassifier(random_state=42)
rf_classifier.fit(X_train_resampled_sc_8, y_train_resampled_8)

#Gradient Boosting
gb_classifier = GradientBoostingClassifier(random_state=42)
gb_classifier.fit(X_train_resampled_sc_8, y_train_resampled_8)

#XGBoost
xgb_classifier = XGBClassifier(random_state=42)
xgb_classifier.fit(X_train_resampled_sc_8, y_train_resampled_8)

#K-Nearest Neighbors 
knn_classifier = KNeighborsClassifier()
knn_classifier.fit(X_train_resampled_sc_8, y_train_resampled_8)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ##### IV.2.2 - Choix du modèle

# %%
# Get cross_val_score for each function

cvs_lgr_8 = cross_val_score(lgr, X_train_resampled_sc_8, y_train_resampled_8, cv=5, scoring='accuracy')

cvs_lsvc_8 = cross_val_score(l_SVC, X_train_resampled_sc_8, y_train_resampled_8, cv=5, scoring='accuracy')

cvs_svc_8 = cross_val_score(svc, X_train_resampled_sc_8, y_train_resampled_8, cv=5, scoring='accuracy')

cvs_rbf_8 = cross_val_score(rbf_svc, X_train_resampled_sc_8, y_train_resampled_8, cv=5, scoring='accuracy')

cvs_poly_8 = cross_val_score(svc_poly, X_train_resampled_sc_8, y_train_resampled_8, cv=5, scoring='accuracy')

cvs_sgdc_8 = cross_val_score(sgdc_svm, X_train_resampled_sc_8, y_train_resampled_8, cv=5, scoring='accuracy')

cvs_rf_8 = cross_val_score(rf_classifier, X_train_resampled_sc_8, y_train_resampled_8, cv=5, scoring='accuracy')

cvs_gb_8 = cross_val_score(gb_classifier, X_train_resampled_sc_8, y_train_resampled_8, cv=5, scoring='accuracy')

cvs_xgb_8 = cross_val_score(xgb_classifier, X_train_resampled_sc_8, y_train_resampled_8, cv=5, scoring='accuracy')

cvs_knn_8 = cross_val_score(knn_classifier, X_train_resampled_sc_8, y_train_resampled_8, cv=5, scoring='accuracy')

# %%
#Get data output from cross_val_score
df_cross_8 = pd.DataFrame(np.transpose(np.c_[cvs_lgr_8,cvs_lsvc_8,cvs_svc_8,cvs_rbf_8,cvs_poly_8,cvs_sgdc_8,cvs_rf_8,cvs_gb_8,cvs_xgb_8,cvs_knn_8]), 
                        columns=['fold1','fold2','fold3','fold4','fold5'])
#Adding model label
df_cross_8['model'] = ['lgr','lsvc','svc','rbf', 'poly', 'sgdc', 'rf', 'gb', 'xgb', 'knn']

df_cross_8
# Out:
#       fold1     fold2     fold3     fold4     fold5 model
# 0  0.674470  0.683558  0.674656  0.663912  0.668871   lgr
# 1  0.674470  0.683558  0.674656  0.663636  0.668871  lsvc
# 2  0.659873  0.672817  0.659780  0.645730  0.668871   svc
# 3  0.674470  0.683558  0.674656  0.663912  0.668871   rbf
# 4  0.674470  0.683283  0.674931  0.662534  0.668044  poly
# 5  0.659873  0.675021  0.659780  0.645730  0.668871  sgdc
# 6  0.605067  0.629028  0.611570  0.614876  0.617631    rf
# 7  0.674194  0.683007  0.674380  0.662259  0.669421    gb
# 8  0.658221  0.667860  0.660606  0.654270  0.661433   xgb
# 9  0.645828  0.649132  0.647383  0.639118  0.646006   knn

# %%
#Regardons l'évolution des scores pour chaque fold
for row in range(df_cross_8.shape[0]):
    plt.plot( df_cross_8.iloc[row,0:4] ,label='Line '+str(df_cross_8.iloc[row,5]))

plt.legend()
plt.title("Evolution de l'accuracy en fonction des folds")
plt.show()

# %%
for i in range(10):

    mean_model = df_cross_8.iloc[:,0:5].mean(axis=1)[i]
    std_model = df_cross_8.iloc[:,0:5].std(axis=1)[i]
    
    print('Le modèle N° '+ str(i) + ' a une accuray de '  + str(mean_model) + ' et un std : ' + str(std_model))
# Out:
# Le modèle N° 0 a une accuray de 0.6730932215927584 et un std : 0.007348161163587091
# Le modèle N° 1 a une accuray de 0.6730381251740256 et un std : 0.007434736235101124
# Le modèle N° 2 a une accuray de 0.6614141768199003 et un std : 0.010448317169061899
# Le modèle N° 3 a une accuray de 0.6730932215927584 et un std : 0.007348161163587091
# Le modèle N° 4 a une accuray de 0.6726524654167928 et un std : 0.007828024310247863
# Le modèle N° 5 a une accuray de 0.6618548267785893 et un std : 0.011077015591023765
# Le modèle N° 6 a une accuray de 0.6156344851079585 et un std : 0.008833484418159284
# Le modèle N° 7 a une accuray de 0.6726524957645861 et un std : 0.007600203158259462
# Le modèle N° 8 a une accuray de 0.6604779018749626 et un std : 0.004976369285951104
# Le modèle N° 9 a une accuray de 0.645493390629967 et un std : 0.0038022018967980237

# %% [markdown]
# Le lgr est meilleur (de peu)

# %% [markdown]
# ##### IV.2.3 - Grid Search

# %%
LogisticRegression().get_params()
# Out:
# {'C': 1.0,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 100,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
params = {
    'penalty': ['l1', 'l2'],
    'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
    'solver': ['liblinear', 'saga'],
    'class_weight': [None, 'balanced'],
    'max_iter': [100, 200, 300]  
}

c_lgr_8 = LogisticRegression(random_state=42)

# %%
grid_c_lgr_8 = GridSearchCV(c_lgr_8, param_grid=params, cv=5, return_train_score=True)

# %%
take_grid = grid_c_lgr_8.fit(X_train_resampled_sc_8, y_train_resampled_8)
# Out:
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
print("La meilleur combinaison d'estimateur est: " + str(take_grid.best_params_)+"\n"
      "pour un score de: " + str(take_grid.best_score_))²
# Out:
# La meilleur combinaison d'estimateur est: {'C': 0.1, 'class_weight': None, 'max_iter': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# pour un score de: 0.6796361369304013

# %% [markdown]
# Le `Grid Search` améliore très légèrement

# %% [markdown]
# ##### IV.2.4 - Learning curve

# %%
train_sizes, train_scores, test_scores = learning_curve(estimator=lgr, 
                                                        X=X_train_resampled_sc_8, 
                                                        y=y_train_resampled_8,
                                                        cv=5, 
                                                        train_sizes=np.linspace(0.1, 1.0, 5),
                                                        random_state=42
                                                       )

#
# Trop de fluctuation dans le modèle, on calcule la moyenne des métriques
#
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)
#
# Plot the learning curve
#
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Accuracy')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes, test_mean, color='green', marker='+', markersize=5, linestyle='--', label='Validation Accuracy')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.title('Learning Curve')
plt.xlabel('Training Data Size')
plt.ylabel('Model accuracy')
plt.grid()
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# On obtient une learning curve similaire au cas 1

# %% [markdown]
# #### IV.2.5 - Matrice de confusion

# %%
take_grid.best_params_
# Out:
# {'C': 0.1,
#  'class_weight': None,
#  'max_iter': 100,
#  'penalty': 'l2',
#  'solver': 'liblinear'}

# %%
best_lgr_8 = LogisticRegression(C=0.1, class_weight=None, max_iter=100, penalty='l2', solver='liblinear')

# %%
best_lgr_8.fit(X_train_resampled_sc_8, y_train_resampled_8)
# Out:
# LogisticRegression(C=0.1, solver='liblinear')

# %%
print('Training score: ' + str(best_lgr_8.score(X_train_resampled_sc_8, y_train_resampled_8)), 
      '\n',
      'Test score: ' + str(best_lgr_8.score(X_test_sc_8, y_test_8))
     )
# Out:
# Training score: 0.6730938739532834
#  Test score: 0.7976712082107916

# %% [markdown]
# Encore une fois, le `GridSearch` n'améliore pas

# %%
# Prédire les étiquettes sur l'ensemble de test et d'entraînement
y_pred_train = best_lgr_8.predict(X_train_resampled_sc_8)
y_pred_test = best_lgr_8.predict(X_test_sc_8)

# Calculer le score F1 pour l'ensemble d'entraînement et de test
f1_train = f1_score(y_train_resampled_8, y_pred_train)
f1_test = f1_score(y_test_8, y_pred_test)

# Afficher les scores F1
print('F1 Score (Entraînement): {:.4f}'.format(f1_train))
print('F1 Score (Test): {:.4f}'.format(f1_test))

# %%
best_lgr_8
# Out:
# LogisticRegression(C=0.1, solver='liblinear')

# %%
# Définir la taille de la figure
plt.figure(figsize=(8, 6))

# Tracer la matrice de confusion
confusion_matrix_disp = plot_confusion_matrix(best_lgr_8, X_test_sc_8, y_test_8,
                                               cmap=plt.cm.Blues, normalize='all')

# Personnaliser les étiquettes
confusion_matrix_disp.ax_.set_title('Matrice de Confusion - Gradient Boosting')
confusion_matrix_disp.ax_.set_xlabel('Prédictions')
confusion_matrix_disp.ax_.set_ylabel('Vraies étiquettes')

# Afficher le graphique
plt.show()
# Out:
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# Encore une fois le modèle prédit mal les gens qui ont réellement une maladie cardiaque

# %%
# Prédire les étiquettes sur l'ensemble de test et d'entraînement
y_pred_train = best_lgr_8.predict(X_train_resampled_sc_8)
y_pred_test = best_lgr_8.predict(X_test_sc_8)

# Calculer le score F1 pour l'ensemble d'entraînement et de test
f1_train = f1_score(y_train_resampled_8, y_pred_train)
f1_test = f1_score(y_test_8, y_pred_test)

# Afficher les scores F1
print('F1 Score (Entraînement): {:.4f}'.format(f1_train))
print('F1 Score (Test): {:.4f}'.format(f1_test))
# Out:
# F1 Score (Entraînement): 0.6174
# F1 Score (Test): 0.2563

# %% [markdown]
# F1 Score plutôt faible sur les données test

# %% [markdown]
# #### IV.2.6 - Importance des variables

# %%
# Récupérer les coefficients du modèle
coefficients = best_lgr_8.coef_[0]

# Récupérer les noms des variables
feature_names = X_train_resampled_sc_8.columns

# Trier les indices par ordre décroissant des coefficients absolus
sorted_indices = np.argsort(np.abs(coefficients))[::-1]

# Tracer l'importance des variables
plt.figure(figsize=(10, 6))
plt.bar(range(len(coefficients)), coefficients[sorted_indices])
plt.xticks(range(len(coefficients)), np.array(feature_names)[sorted_indices], rotation=45, ha='right')
plt.xlabel('Variables')
plt.ylabel('Coefficient')
plt.title('Importance des Variables dans le Modèle de Régression Logistique')
plt.tight_layout()
plt.show()

# %% [markdown]
# Les variables présente ici augmentent la probabilité de faire une maladie cardiaque

# %% [markdown]
# #### IV.3 - Modèle ré-échantillonné avec 15 variables

# %% [markdown]
# On refait l'analyse avec la deuxième feature selection

# %%
#Train and test
X_train_15 , X_test_15, y_train_15, y_test_15 = train_test_split(df_model_15.iloc[:,1:],
                                                     df_model_15.HeartDisease,
                                                     test_size=0.2)

# Appliquer l'échantillonnage stratifié uniquement sur l'ensemble d'entraînement
sampler = RandomUnderSampler(sampling_strategy='auto', random_state=42)
X_train_resampled_15, y_train_resampled_15 = sampler.fit_resample(X_train_15, y_train_15)

# %%
# Sélection des variables à scaler
selected_features = ['BMI', 'SleepTime', 'PhysicalHealth', 'MentalHealth']

# Création d'un scaler
scaler = StandardScaler()

# Renommer les variables
X_train_resampled_sc_15 = X_train_resampled_15
X_test_sc_15 = X_test_15

# Calcul de la moyenne et de l'écart type sur X_train_resampled_sc_15 pour les variables sélectionnées
scaler.fit(X_train_resampled_sc_15[selected_features])

# Transformation des variables sélectionnées dans X_train_resampled_sc_15
X_train_resampled_sc_15[selected_features] = scaler.transform(X_train_resampled_sc_15[selected_features])

# Transformation des variables sélectionnées dans X_test_sc_15
X_test_sc_15[selected_features] = scaler.transform(X_test_sc_15[selected_features])

# %%
X_train_resampled_sc_15 = X_train_resampled_15.copy()
X_test_sc_15 = X_test_15.copy()

# %% [markdown]
# | Bases                  | Description                              |
# |------------------------|------------------------------------------|
# | X_train_resampled_sc_15 | X train ré-échantillonné 3e analyse    |
# | X_test_sc_15            | X test 3e analyse                       |
# | y_train_resampled_15    | y train ré-échantillonné 3e analyse    |
# | y_test_15              | y test 3e analyse                       |

# %%
X_train_resampled_sc_15.head(5)
# Out:
#              BMI  SleepTime  PhysicalHealth  MentalHealth  Smoking  \
# 272756 -0.550227   1.055975        2.542323      0.050588        0
# 51191  -0.340994  -0.236188       -0.402035     -0.411853        0
# 72729  -0.319456  -1.528351       -0.402035      0.050588        0
# 313789 -1.122540  -1.528351       -0.402035     -0.411853        1
# 88450  -1.122540   1.055975        4.505228     -0.411853        1
#
#         DiffWalking  Sex  PhysicalActivity  Asthma  Excellent  Good  VeryGood  \
# 272756            0    0                 1       0          0     0         0
# 51191             0    1                 1       0          0     0         1
# 72729             0    0                 1       0          1     0         0
# 313789            1    1                 1       0          0     0         1
# 88450             0    0                 1       0          0     0         1
#
#         White  No_diabetic  Yes_diabetic
# 272756      1            1             0
# 51191       1            1             0
# 72729       1            1             0
# 313789      0            1             0
# 88450       1            1             0

# %%
X_test_sc_15.head(5)
# Out:
#              BMI  SleepTime  PhysicalHealth  MentalHealth  Smoking  \
# 269705  0.311319  -1.528351       -0.402035      0.513029        0
# 202947 -0.645612  -0.236188        2.051597      4.212559        0
# 233464  0.492859   1.055975       -0.402035     -0.411853        1
# 36579  -0.454842   1.055975       -0.402035     -0.411853        1
# 198905 -0.565612   1.055975       -0.402035     -0.411853        0
#
#         DiffWalking  Sex  PhysicalActivity  Asthma  Excellent  Good  VeryGood  \
# 269705            1    0                 1       0          0     1         0
# 202947            0    0                 1       0          0     1         0
# 233464            0    1                 1       0          1     0         0
# 36579             0    1                 1       0          0     1         0
# 198905            0    1                 1       0          1     0         0
#
#         White  No_diabetic  Yes_diabetic
# 269705      1            0             0
# 202947      1            1             0
# 233464      0            1             0
# 36579       0            0             0
# 198905      1            1             0

# %% [markdown]
# ##### IV.3.1 - Comparaisons

# %%
# Regression logistique
lgr = LogisticRegression(random_state=42)
lgr.fit(X_train_resampled_sc_15, y_train_resampled_15)

#Linear SVM
l_SVC = LinearSVC(random_state=42, max_iter=2000)
l_SVC.fit(X_train_resampled_sc_15, y_train_resampled_15)

#SVM avec kernel
svc = SVC(kernel='linear',random_state=42)
svc.fit(X_train_resampled_sc_15, y_train_resampled_15)

#SVM avec noyau RBF
rbf_svc = SVC(kernel='rbf', random_state=42)
rbf_svc.fit(X_train_resampled_sc_15, y_train_resampled_15)

#SGD poly
svc_poly = SVC(kernel='poly',random_state=0)
svc_poly.fit(X_train_resampled_sc_15, y_train_resampled_15)

#SGD classifier
sgdc_svm = SGDClassifier(loss='hinge' ,random_state=42)
sgdc_svm.fit(X_train_resampled_sc_15, y_train_resampled_15)

#Random Forest
rf_classifier = RandomForestClassifier(random_state=42)
rf_classifier.fit(X_train_resampled_sc_15, y_train_resampled_15)

#Gradient Boosting
gb_classifier = GradientBoostingClassifier(random_state=42)
gb_classifier.fit(X_train_resampled_sc_15, y_train_resampled_15)

#XGBoost
xgb_classifier = XGBClassifier(random_state=42)
xgb_classifier.fit(X_train_resampled_sc_15, y_train_resampled_15)

#K-Nearest Neighbors 
knn_classifier = KNeighborsClassifier()
knn_classifier.fit(X_train_resampled_sc_15, y_train_resampled_15)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ##### IV.3.2 - Choix du modèle

# %%
# Get cross_val_score for each function

cvs_lgr_15 = cross_val_score(lgr, X_train_resampled_sc_15, y_train_resampled_15, cv=5, scoring='accuracy')

cvs_lsvc_15 = cross_val_score(l_SVC, X_train_resampled_sc_15, y_train_resampled_15, cv=5, scoring='accuracy')

cvs_svc_15 = cross_val_score(svc, X_train_resampled_sc_15, y_train_resampled_15, cv=5, scoring='accuracy')

cvs_rbf_15 = cross_val_score(rbf_svc, X_train_resampled_sc_15, y_train_resampled_15, cv=5, scoring='accuracy')

cvs_poly_15 = cross_val_score(svc_poly, X_train_resampled_sc_15, y_train_resampled_15, cv=5, scoring='accuracy')

cvs_sgdc_15 = cross_val_score(sgdc_svm, X_train_resampled_sc_15, y_train_resampled_15, cv=5, scoring='accuracy')

cvs_rf_15 = cross_val_score(rf_classifier, X_train_resampled_sc_15, y_train_resampled_15, cv=5, scoring='accuracy')

cvs_gb_15 = cross_val_score(gb_classifier, X_train_resampled_sc_15, y_train_resampled_15, cv=5, scoring='accuracy')

cvs_xgb_15 = cross_val_score(xgb_classifier, X_train_resampled_sc_15, y_train_resampled_15, cv=5, scoring='accuracy')

cvs_knn_15 = cross_val_score(knn_classifier, X_train_resampled_sc_15, y_train_resampled_15, cv=5, scoring='accuracy')

# %%
#Get data output from cross_val_score
df_cross_15 = pd.DataFrame(np.transpose(np.c_[cvs_lgr_15,cvs_lsvc_15,cvs_svc_15,cvs_rbf_15,cvs_poly_15,cvs_sgdc_15,cvs_rf_15,cvs_gb_15,cvs_xgb_15,cvs_knn_15]), 
                        columns=['fold1','fold2','fold3','fold4','fold5'])

#Adding model label
df_cross_15['model'] = ['lgr','lsvc','svc','rbf', 'poly', 'sgdc', 'rf', 'gb', 'xgb', 'knn']

# %%
df_cross_15
# Out:
#       fold1     fold2     fold3     fold4     fold5 model
# 0  0.717530  0.703683  0.700360  0.705899  0.713019   lgr
# 1  0.715591  0.705068  0.698698  0.707837  0.711357  lsvc
# 2  0.716699  0.700637  0.699252  0.703683  0.693352   svc
# 3  0.707283  0.693160  0.694268  0.707560  0.693906   rbf
# 4  0.708391  0.695929  0.691775  0.708391  0.695845  poly
# 5  0.701468  0.692329  0.698421  0.699806  0.697784  sgdc
# 6  0.652728  0.646081  0.639712  0.651620  0.640166    rf
# 7  0.714760  0.695929  0.698698  0.709222  0.706648    gb
# 8  0.685129  0.679036  0.685406  0.691221  0.692521   xgb
# 9  0.663251  0.659374  0.650235  0.658266  0.653463   knn

# %%
#Regardons l'évolution des scores pour chaque fold
for row in range(df_cross_15.shape[0]):
    plt.plot( df_cross_15.iloc[row,0:4] ,label='Line '+str(df_cross_15.iloc[row,5]))

plt.legend()
plt.title("Evolution de l'accuracy en fonction des folds")
plt.show()

# %%
for i in range(10):

    mean_model = df_cross_15.iloc[:,0:5].mean(axis=1)[i]
    std_model = df_cross_15.iloc[:,0:5].std(axis=1)[i]
    
    print('Le modèle N° '+ str(i) + ' a une accuray de '  + str(mean_model) + ' et un std : ' + str(std_model))
# Out:
# Le modèle N° 0 a une accuray de 0.7080982010185867 et un std : 0.007024645220497743
# Le modèle N° 1 a une accuray de 0.7077104047267083 et un std : 0.006395757629113259
# Le modèle N° 2 a une accuray de 0.7027246387039908 et un std : 0.008666987913562782
# Le modèle N° 3 a une accuray de 0.6992353312554513 et un std : 0.007484465861400054
# Le modèle N° 4 a une accuray de 0.7000662334464329 et un std : 0.007782712442087068
# Le modèle N° 5 a une accuray de 0.6979616606997241 et un std : 0.003451979973319105
# Le modèle N° 6 a une accuray de 0.6460614880202152 et un std : 0.006132044481974022
# Le modèle N° 7 a une accuray de 0.7050516005649098 et un std : 0.007710131568385035
# Le modèle N° 8 a une accuray de 0.6866625599986499 et un std : 0.005412782916595189
# Le modèle N° 9 a une accuray de 0.6569179430963101 et un std : 0.00511265454782625

# %% [markdown]
# Encore une fois, le meilleur modèle est le modèle lgr

# %% [markdown]
# ##### IV.3.3 - Grid Search

# %%
params = {
    'penalty': ['l1', 'l2'],
    'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
    'solver': ['liblinear', 'saga'],
    'class_weight': [None, 'balanced'],
    'max_iter': [100, 200, 300]  
}

c_lgr_15 = LogisticRegression(random_state=42)

# %%
grid_c_lgr_15 = GridSearchCV(c_lgr_15, param_grid=params, cv=5, return_train_score=True)

# %%
take_grid = grid_c_lgr_15.fit(X_train_resampled_sc_15, y_train_resampled_15)

# %%
print("La meilleur combinaison d'estimateur est: " + str(take_grid.best_params_)+"\n"
      "pour un score de: " + str(take_grid.best_score_))
# Out:
# La meilleur combinaison d'estimateur est: {'C': 1, 'class_weight': None, 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear'}
# pour un score de: 0.7082643446348531

# %% [markdown]
# Encore une fois, le `GridSearch` n'améliore pas

# %% [markdown]
# ##### IV.3.4 - Learning curve

# %%
train_sizes, train_scores, test_scores = learning_curve(estimator=c_lgr_15, 
                                                        X=X_train_resampled_sc_15, 
                                                        y=y_train_resampled_15,
                                                        cv=5, 
                                                        train_sizes=np.linspace(0.1, 1.0, 5),
                                                        random_state=42
                                                       )

#
# Trop de fluctuation dans le modèle, on calcule la moyenne des métriques
#
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)
#
# Plot the learning curve
#
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Accuracy')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes, test_mean, color='green', marker='+', markersize=5, linestyle='--', label='Validation Accuracy')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.title('Learning Curve')
plt.xlabel('Training Data Size')
plt.ylabel('Model accuracy')
plt.grid()
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# La learning curve est similaire aux autres cas

# %% [markdown]
# ##### IV.3.5 - Matrice de confusion

# %%
take_grid.best_params_
# Out:
# {'C': 1,
#  'class_weight': None,
#  'max_iter': 100,
#  'penalty': 'l1',
#  'solver': 'liblinear'}

# %%
best_lgr_15 = LogisticRegression(C=1, class_weight=None, max_iter=100, penalty='l1', solver='liblinear')

# %%
best_lgr_15.fit(X_train_resampled_sc_15, y_train_resampled_15)
# Out:
# LogisticRegression(C=1, penalty='l1', solver='liblinear')

# %%
print('Training score: ' + str(best_lgr_15.score(X_train_resampled_sc_15, y_train_resampled_15)), 
      '\n',
      'Test score: ' + str(best_lgr_15.score(X_test_sc_15, y_test_15))
     )
# Out:
# Training score: 0.7077655921125512
#  Test score: 0.7076105875997839

# %% [markdown]
# Le modèle ne semble pas être en sur-apprentissage, il semble être stable

# %%
# Définir la taille de la figure
plt.figure(figsize=(8, 6))

# Tracer la matrice de confusion
confusion_matrix_disp = plot_confusion_matrix(best_lgr_15, X_test_sc_15, y_test_15,
                                               cmap=plt.cm.Blues, normalize='all')

# Personnaliser les étiquettes
confusion_matrix_disp.ax_.set_title('Matrice de Confusion - Gradient Boosting')
confusion_matrix_disp.ax_.set_xlabel('Prédictions')
confusion_matrix_disp.ax_.set_ylabel('Vraies étiquettes')

# Afficher le graphique
plt.show()
# Out:
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# Le modèle prédit mal les cas de réelle maladie cardiaque

# %%
# Prédire les étiquettes sur l'ensemble de test et d'entraînement
y_pred_train = best_lgr_15.predict(X_train_resampled_sc_15)
y_pred_test = best_lgr_15.predict(X_test_sc_15)

# Calculer le score F1 pour l'ensemble d'entraînement et de test
f1_train = f1_score(y_train_resampled_15, y_pred_train)
f1_test = f1_score(y_test_15, y_pred_test)

# Afficher les scores F1
print('F1 Score (Entraînement): {:.4f}'.format(f1_train))
print('F1 Score (Test): {:.4f}'.format(f1_test))
# Out:
# F1 Score (Entraînement): 0.7038
# F1 Score (Test): 0.2390

# %% [markdown]
# Encore une fois, le F1 score sur les données test est faible

# %% [markdown]
# ##### IV.3.6 - Importance des variables

# %%
# Récupérer les coefficients du modèle
coefficients = best_lgr_15.coef_[0]

# Récupérer les noms des variables
feature_names = X_train_resampled_sc_15.columns

# Trier les indices par ordre décroissant des coefficients absolus
sorted_indices = np.argsort(np.abs(coefficients))[::-1]

# Tracer l'importance des variables
plt.figure(figsize=(10, 6))
plt.bar(range(len(coefficients)), coefficients[sorted_indices])
plt.xticks(range(len(coefficients)), np.array(feature_names)[sorted_indices], rotation=45, ha='right')
plt.xlabel('Variables')
plt.ylabel('Coefficient')
plt.title('Importance des Variables dans le Modèle de Régression Logistique')
plt.tight_layout()
plt.show()

# %% [markdown]
# Le fait d'être en excellente santé ou très bonne diminue la prba de faire un arrêt cardiaque, au contraire le fait d'être blanc ou juste en bonne santé l'augmente

# %% [markdown]
# #### IV.4 - Modèle ré-échantillonné avec 9 variables

# %% [markdown]
# On modifie le threshold afin d'obtenir moins de variables

# %%
# Supprimer les caractéristiques avec une variance inférieure à un seuil
selector = VarianceThreshold(threshold=0.15)
X_selected = selector.fit_transform(qualis.drop("HeartDisease", axis=1), qualis["HeartDisease"])

# Récupérer les noms des caractéristiques sélectionnées
selected_feature_names = qualis.drop("HeartDisease", axis=1).columns[selector.get_support()]

# Afficher les noms des caractéristiques sélectionnées
print("Caractéristiques sélectionnées:", selected_feature_names.tolist())
# Out:
# Caractéristiques sélectionnées: ['Smoking', 'Sex', 'PhysicalActivity', 'Excellent', 'Good', 'VeryGood', 'White']

# %%
# Liste des variables à conserver
selected_variables = ['HeartDisease', 'BMI', 'SleepTime',
                       'Smoking', 'Sex', 'PhysicalActivity', 'Excellent', 'Good', 'VeryGood', 'White']

# Sélectionner les colonnes spécifiées dans un nouveau DataFrame
df_model_10 = df_without_outliers1[selected_variables].copy()

# %% [markdown]
# On supprime également les variables ayant des outliers

# %%
#Train and test
X_train_10 , X_test_10, y_train_10, y_test_10 = train_test_split(df_model_10.iloc[:,1:],
                                                     df_model_10.HeartDisease,
                                                     test_size=0.2)

# Appliquer l'échantillonnage stratifié uniquement sur l'ensemble d'entraînement
sampler = RandomUnderSampler(sampling_strategy='auto', random_state=42)
X_train_resampled_10, y_train_resampled_10 = sampler.fit_resample(X_train_10, y_train_10)

# Sélection des variables à scaler
selected_features = ["BMI", "SleepTime"]

# Création d'un scaler
scaler = StandardScaler()

# Calcul de la moyenne et de l'écart type sur X_train_resampled pour les variables sélectionnées
scaler.fit(X_train_resampled[selected_features])

# Transformation des variables sélectionnées dans X_train_resampled
X_train_resampled_10[selected_features] = scaler.transform(X_train_resampled_10[selected_features])

# Transformation des variables sélectionnées dans X_test
X_test_10[selected_features] = scaler.transform(X_test_10[selected_features])

# %% [markdown]
# Je sais pas compter, on a 9 variables en tout

# %%
X_train_resampled_sc_10 = X_train_resampled_10.copy()
X_test_sc_10 = X_test_10.copy()

# %% [markdown]
# | Bases                  | Description                              |
# |------------------------|------------------------------------------|
# | X_train_resampled_sc_10 | X train ré-échantillonné 4e analyse    |
# | X_test_sc_10           | X test 4e analyse                       |
# | y_train_resampled_10    | y train ré-échantillonné 4e analyse    |
# | y_test_10               | y test 4e analyse                       |

# %% [markdown]
# ##### IV.4.1 - Comparaisons

# %%
# Regression logistique
lgr = LogisticRegression(random_state=42)
lgr.fit(X_train_resampled_sc_10, y_train_resampled_10)

#Linear SVM
l_SVC = LinearSVC(random_state=42, max_iter=2000)
l_SVC.fit(X_train_resampled_sc_10, y_train_resampled_10)

#SVM avec kernel
svc = SVC(kernel='linear',random_state=42)
svc.fit(X_train_resampled_sc_10, y_train_resampled_10)

#SVM avec noyau RBF
rbf_svc = SVC(kernel='rbf', random_state=42)
rbf_svc.fit(X_train_resampled_sc_10, y_train_resampled_10)

#SGD poly
svc_poly = SVC(kernel='poly',random_state=0)
svc_poly.fit(X_train_resampled_sc_10, y_train_resampled_10)

#SGD classifier
sgdc_svm = SGDClassifier(loss='hinge' ,random_state=42)
sgdc_svm.fit(X_train_resampled_sc_10, y_train_resampled_10)

#Random Forest
rf_classifier = RandomForestClassifier(random_state=42)
rf_classifier.fit(X_train_resampled_sc_10, y_train_resampled_10)

#Gradient Boosting
gb_classifier = GradientBoostingClassifier(random_state=42)
gb_classifier.fit(X_train_resampled_sc_10, y_train_resampled_10)

#XGBoost
xgb_classifier = XGBClassifier(random_state=42)
xgb_classifier.fit(X_train_resampled_sc_10, y_train_resampled_10)

#K-Nearest Neighbors 
knn_classifier = KNeighborsClassifier()
knn_classifier.fit(X_train_resampled_sc_10, y_train_resampled_10)
# Out:
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# KNeighborsClassifier()

# %% [markdown]
# ##### IV.4.2 - Choix du modèle

# %%
# Get cross_val_score for each function

cvs_lgr_10 = cross_val_score(lgr, X_train_resampled_sc_10, y_train_resampled_10, cv=5, scoring='accuracy')

cvs_lsvc_10 = cross_val_score(l_SVC, X_train_resampled_sc_10, y_train_resampled_10, cv=5, scoring='accuracy')

cvs_svc_10 = cross_val_score(svc, X_train_resampled_sc_10, y_train_resampled_10, cv=5, scoring='accuracy')

cvs_rbf_10 = cross_val_score(rbf_svc, X_train_resampled_sc_10, y_train_resampled_10, cv=5, scoring='accuracy')

cvs_poly_10 = cross_val_score(svc_poly, X_train_resampled_sc_10, y_train_resampled_10, cv=5, scoring='accuracy')

cvs_sgdc_10 = cross_val_score(sgdc_svm, X_train_resampled_sc_10, y_train_resampled_10, cv=5, scoring='accuracy')

cvs_rf_10 = cross_val_score(rf_classifier, X_train_resampled_sc_10, y_train_resampled_10, cv=5, scoring='accuracy')

cvs_gb_10 = cross_val_score(gb_classifier, X_train_resampled_sc_10, y_train_resampled_10, cv=5, scoring='accuracy')

cvs_xgb_10 = cross_val_score(xgb_classifier, X_train_resampled_sc_10, y_train_resampled_10, cv=5, scoring='accuracy')

cvs_knn_10 = cross_val_score(knn_classifier, X_train_resampled_sc_10, y_train_resampled_10, cv=5, scoring='accuracy')
# Out:
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
#Get data output from cross_val_score
df_cross_10 = pd.DataFrame(np.transpose(np.c_[cvs_lgr_10,cvs_lsvc_10,cvs_svc_10,cvs_rbf_10,cvs_poly_10,cvs_sgdc_10,cvs_rf_10,cvs_gb_10,cvs_xgb_10,cvs_knn_10]), 
                        columns=['fold1','fold2','fold3','fold4','fold5'])
#Adding model label
df_cross_10['model'] = ['lgr','lsvc','svc','rbf', 'poly', 'sgdc', 'rf', 'gb', 'xgb', 'knn']

# %%
df_cross_10
# Out:
#       fold1     fold2     fold3     fold4     fold5 model
# 0  0.676365  0.686617  0.678769  0.678492  0.672672   lgr
# 1  0.655860  0.650873  0.671286  0.677661  0.642184  lsvc
# 2  0.662510  0.668052  0.649667  0.655765  0.654933   svc
# 3  0.662510  0.668052  0.649667  0.655765  0.654933   rbf
# 4  0.663619  0.668606  0.649667  0.655765  0.654933  poly
# 5  0.500139  0.512330  0.679324  0.667960  0.636918  sgdc
# 6  0.601829  0.617346  0.605322  0.598670  0.604490    rf
# 7  0.676642  0.679135  0.680432  0.679878  0.683204    gb
# 8  0.666390  0.663342  0.658814  0.673226  0.670177   xgb
# 9  0.632308  0.647271  0.631652  0.634424  0.628326   knn

# %%
#Regardons l'évolution des scores pour chaque fold
for row in range(df_cross_10.shape[0]):
    plt.plot( df_cross_10.iloc[row,0:4] ,label='Line '+str(df_cross_10.iloc[row,5]))

plt.legend()
plt.title("Evolution de l'accuracy en fonction des folds")
plt.show()

# %%
for i in range(10):

    mean_model = df_cross_10.iloc[:,0:5].mean(axis=1)[i]
    std_model = df_cross_10.iloc[:,0:5].std(axis=1)[i]
    
    print('Le modèle N° '+ str(i) + ' a une accuray de '  + str(mean_model) + ' et un std : ' + str(std_model))
# Out:
# Le modèle N° 0 a une accuray de 0.6785829832907261 et un std : 0.005109982837512481
# Le modèle N° 1 a une accuray de 0.6595727974962815 et un std : 0.014630575584469301
# Le modèle N° 2 a une accuray de 0.658185667268144 et un std : 0.007159728593312504
# Le modèle N° 3 a une accuray de 0.658185667268144 et un std : 0.007159728593312504
# Le modèle N° 4 a une accuray de 0.6585181693462819 et un std : 0.0075258134866261215
# Le modèle N° 5 a une accuray de 0.599334120353219 et un std : 0.08650120715377614
# Le modèle N° 6 a une accuray de 0.6055310878998611 et un std : 0.007097457088948643
# Le modèle N° 7 a une accuray de 0.6798583272048998 et un std : 0.0023660291087843396
# Le modèle N° 8 a une accuray de 0.6663897044774121 et un std : 0.005651758186747714
# Le modèle N° 9 a une accuray de 0.6347960322155931 et un std : 0.007309135668183556

# %% [markdown]
# Pour une fois le meilleur modèle est un gradient boosting

# %% [markdown]
# ##### IV.4.3 - Grid Search

# %%
GradientBoostingClassifier().get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'friedman_mse',
#  'init': None,
#  'learning_rate': 0.1,
#  'loss': 'deviance',
#  'max_depth': 3,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_iter_no_change': None,
#  'random_state': None,
#  'subsample': 1.0,
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %%
params = {
    'n_estimators': [50, 100],
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 4],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}


c_gb_10 = GradientBoostingClassifier(random_state=42)

# %%
grid_c_gb_10 = GridSearchCV(c_gb_10, param_grid=params, cv=5, return_train_score=True)

# %%
take_grid = grid_c_gb_10.fit(X_train_resampled_sc_10, y_train_resampled_10)

# %%
print("La meilleur combinaison d'estimateur est: " + str(take_grid.best_params_)+"\n"
      "pour un score de: " + str(take_grid.best_score_))
# Out:
# La meilleur combinaison d'estimateur est: {'learning_rate': 0.1, 'max_depth': 4, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# pour un score de: 0.6822415198760919

# %% [markdown]
# Cette fois-ci le `OneHotEncoder` améliore le score

# %% [markdown]
# ##### IV.4.3 - Learning curve

# %%
train_sizes, train_scores, test_scores = learning_curve(estimator=c_gb_10, 
                                                        X=X_train_resampled_sc_10, 
                                                        y=y_train_resampled_10,
                                                        cv=5, 
                                                        train_sizes=np.linspace(0.1, 1.0, 5),
                                                        random_state=42
                                                       )

#
# Trop de fluctuation dans le modèle, on calcule la moyenne des métriques
#
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)
#
# Plot the learning curve
#
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Accuracy')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes, test_mean, color='green', marker='+', markersize=5, linestyle='--', label='Validation Accuracy')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.title('Learning Curve')
plt.xlabel('Training Data Size')
plt.ylabel('Model accuracy')
plt.grid()
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# La learning curve est similaire encore une fois

# %% [markdown]
# ##### IV.4.4 - Matrice de confusion

# %%
take_grid.best_params_
# Out:
# {'learning_rate': 0.1,
#  'max_depth': 4,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'n_estimators': 100}

# %%
best_gb_10 = GradientBoostingClassifier(learning_rate=0.1,
                                        max_depth=4,
                                        min_samples_leaf=2,
                                        min_samples_split=2,
                                        n_estimators=100)

# %%
best_gb_10.fit(X_train_resampled_sc_10, y_train_resampled_10)
# Out:
# GradientBoostingClassifier(max_depth=4, min_samples_leaf=2)

# %%
# Définir la taille de la figure
plt.figure(figsize=(8, 6))

# Tracer la matrice de confusion
confusion_matrix_disp = plot_confusion_matrix(best_gb_10, X_test_sc_10, y_test_10,
                                               cmap=plt.cm.Blues, normalize='all')

# Personnaliser les étiquettes
confusion_matrix_disp.ax_.set_title('Matrice de Confusion - Gradient Boosting')
confusion_matrix_disp.ax_.set_xlabel('Prédictions')
confusion_matrix_disp.ax_.set_ylabel('Vraies étiquettes')

# Afficher le graphique
plt.show()
# Out:
# C:\Users\Chataigner\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# Le modèle classe mal les individus ayant une réelle maladie cardiaque

# %%
print('Training score: ' + str(best_gb_10.score(X_train_resampled_sc_10, y_train_resampled_10)), 
      '\n',
      'Test score: ' + str(best_gb_10.score(X_test_sc_10, y_test_10))
     )
# Out:
# Training score: 0.6988693049551048
#  Test score: 0.672678710761659

# %% [markdown]
# Le modèle semble stable

# %%
# Prédire les étiquettes sur l'ensemble de test et d'entraînement
y_pred_train = best_gb_10.predict(X_train_resampled_sc_10)
y_pred_test = best_gb_10.predict(X_test_sc_10)

# Calculer le score F1 pour l'ensemble d'entraînement et de test
f1_train = f1_score(y_train_resampled_10, y_pred_train)
f1_test = f1_score(y_test_10, y_pred_test)

# Afficher les scores F1
print('F1 Score (Entraînement): {:.4f}'.format(f1_train))
print('F1 Score (Test): {:.4f}'.format(f1_test))
# Out:
# F1 Score (Entraînement): 0.7029
# F1 Score (Test): 0.2282

# %% [markdown]
# ##### IV.4.6 - Importance des variables

# %%
# Get feature importances
feature_importances = best_gb_10.feature_importances_

# Get actual feature names from your DataFrame (replace df with your DataFrame)
feature_names = X_train_resampled_sc_10.columns

# Sort indices based on feature importance
indices = np.argsort(feature_importances)[::-1]

# Plot feature importances
plt.figure(figsize=(10, 6))
plt.bar(range(len(feature_names)), feature_importances[indices], align="center")
plt.xticks(range(len(feature_names)), np.array(feature_names)[indices], rotation=45)
plt.xlabel("Feature")
plt.ylabel("Importance")
plt.title("Feature Importance of GradientBoostingClassifier")
plt.show()

# %% [markdown]
# Les deux variables les plus importantes sont le fait d'être en excellente santé ou en très bonne santé

# %% [markdown]
# ### V - Réseau de neurones

# %% [markdown]
# #### V.1 - Premier modèle 14 variables

# %% [markdown]
# ##### V.1.1 - Modèle RN

# %%
#Clear session and set seed
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

# %%
#Initialisation du modèle
reg_model = keras.models.Sequential()
#Shape input, number of columns
reg_model.add(keras.layers.Input(shape=X_train.shape[1]))#input layer
reg_model.add(keras.layers.Dense(100, activation='relu'))#Hidden layer, 100 neurones
reg_model.add(keras.layers.Dense(1))#Output layer

#Compil model parameter
reg_model.compile(loss=keras.losses.mean_squared_error, 
                  optimizer=keras.optimizers.Adam(learning_rate=0.01)
                 )
#Fit model

# %%
history = reg_model.fit(X_train_resampled_sc, y_train_resampled, batch_size=2, epochs=30, validation_split=0.2)
# Out:
# Epoch 1/30
# 7230/7230 [==============================] - 33s 5ms/step - loss: 0.1955 - val_loss: 0.2302
# Epoch 2/30
# 7230/7230 [==============================] - 32s 4ms/step - loss: 0.1900 - val_loss: 0.2714
# Epoch 3/30
# 7230/7230 [==============================] - 29s 4ms/step - loss: 0.1902 - val_loss: 0.3132
# Epoch 4/30
# 7230/7230 [==============================] - 31s 4ms/step - loss: 0.1895 - val_loss: 0.4247
# Epoch 5/30
# 7230/7230 [==============================] - 32s 4ms/step - loss: 0.1892 - val_loss: 0.2964
# Epoch 6/30
# 7230/7230 [==============================] - 30s 4ms/step - loss: 0.1893 - val_loss: 0.3573
# Epoch 7/30
# 7230/7230 [==============================] - 27s 4ms/step - loss: 0.1895 - val_loss: 0.4170
# Epoch 8/30
# 7230/7230 [==============================] - 28s 4ms/step - loss: 0.1892 - val_loss: 0.2498
# Epoch 9/30
# 7230/7230 [==============================] - 31s 4ms/step - loss: 0.1888 - val_loss: 0.3292
# Epoch 10/30
# 7230/7230 [==============================] - 30s 4ms/step - loss: 0.1889 - val_loss: 0.3075
# Epoch 11/30
# 7230/7230 [==============================] - 33s 5ms/step - loss: 0.1890 - val_loss: 0.2080
# Epoch 12/30
# 7230/7230 [==============================] - 33s 5ms/step - loss: 0.1888 - val_loss: 0.3004
# Epoch 13/30
# 7230/7230 [==============================] - 33s 5ms/step - loss: 0.1885 - val_loss: 0.2269
# Epoch 14/30
# 7230/7230 [==============================] - 33s 5ms/step - loss: 0.1886 - val_loss: 0.3153
# Epoch 15/30
# 7230/7230 [==============================] - 40s 6ms/step - loss: 0.1893 - val_loss: 0.3313
# Epoch 16/30
# 7230/7230 [==============================] - 42s 6ms/step - loss: 0.1888 - val_loss: 0.2194
# Epoch 17/30
# 7230/7230 [==============================] - 37s 5ms/step - loss: 0.1895 - val_loss: 0.2797
# Epoch 18/30
# 7230/7230 [==============================] - 40s 6ms/step - loss: 0.1894 - val_loss: 0.3325
# Epoch 19/30
# 7230/7230 [==============================] - 31s 4ms/step - loss: 0.1892 - val_loss: 0.2662
# Epoch 20/30
# 7230/7230 [==============================] - 28s 4ms/step - loss: 0.1884 - val_loss: 0.3552
# Epoch 21/30
# 7230/7230 [==============================] - 30s 4ms/step - loss: 0.1892 - val_loss: 0.2202
# Epoch 22/30
# 7230/7230 [==============================] - 32s 4ms/step - loss: 0.1891 - val_loss: 0.2293
# Epoch 23/30
# 7230/7230 [==============================] - 29s 4ms/step - loss: 0.1884 - val_loss: 0.2444
# Epoch 24/30
# 7230/7230 [==============================] - 32s 4ms/step - loss: 0.1888 - val_loss: 0.3731
# Epoch 25/30
# 7230/7230 [==============================] - 28s 4ms/step - loss: 0.1893 - val_loss: 0.2830
# Epoch 26/30
# 7230/7230 [==============================] - 28s 4ms/step - loss: 0.1890 - val_loss: 0.2541
# Epoch 27/30
# 7230/7230 [==============================] - 30s 4ms/step - loss: 0.1885 - val_loss: 0.3923
# Epoch 28/30
# 7230/7230 [==============================] - 31s 4ms/step - loss: 0.1884 - val_loss: 0.2594
# Epoch 29/30
# 7230/7230 [==============================] - 32s 4ms/step - loss: 0.1890 - val_loss: 0.3142
# Epoch 30/30
# 7230/7230 [==============================] - 32s 4ms/step - loss: 0.1891 - val_loss: 0.2767

# %%
# Supposons que history.history est votre dictionnaire de données

# Convertir les données en DataFrame et tracer le graphique
df = pd.DataFrame(history.history)
df.plot(figsize=(8, 5))
plt.grid(True)

# Déterminer les limites de l'axe y pour être plus centré autour des valeurs inférieures à 5
plt.gca().set_ylim(0, 1) 

# Afficher le graphique
plt.show()

# %% [markdown]
#  La loss mesure la divergence des prédictions du modèle par rapport aux valeurs réelles sur l'ensemble d'entraînement, tandis que la val_loss évalue cette divergence sur un ensemble de validation distinct. La tendance à l'augmentation de la val_loss vers la fin des époques suggère un possible sur-entraînement, où le modèle devient trop spécifique aux données d'entraînement et perd sa capacité à généraliser correctement. L'écart croissant entre la loss et la val_loss renforce cette hypothèse

# %% [markdown]
# ##### V.1.2 - Grid Search

# %%
# Define a function that creates your Keras model
def create_model(optimizer='adam', activation='relu'):
    model = keras.models.Sequential()
    model.add(keras.layers.Input(shape=X_train.shape[1]))
    model.add(keras.layers.Dense(100, activation=activation))
    model.add(keras.layers.Dense(1))
    model.compile(loss=keras.losses.mean_squared_error, optimizer=optimizer)
    return model

# Create a KerasRegressor based on your model
model = KerasRegressor(build_fn=create_model, verbose=0)

# Define the hyperparameters grid to search
param_grid = {
    'batch_size': [4, 8],
    'epochs': [20, 30],
    'optimizer': ['adam'],
    'activation': ['relu']
}

# Perform grid search
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=2)
grid_search_result = grid_search.fit(X_train_resampled_sc, y_train_resampled)

# Print the best parameters found
print("Best Parameters: ", grid_search_result.best_params_)
# Out:
# C:\Users\Chataigner\AppData\Local\Temp\ipykernel_8880\3009530116.py:14: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasRegressor(build_fn=create_model, verbose=0)
# Best Parameters:  {'activation': 'relu', 'batch_size': 8, 'epochs': 20, 'optimizer': 'adam'}

# %% [markdown]
# On fait un `Grid Search` directement sur le réseau de neurones

# %%
# Prédire les étiquettes sur les données de test
y_pred = best_model.predict(X_test_sc)

# Convertir les prédictions en classes binaires (0 ou 1)
y_pred_binary = (y_pred > 0.5).astype(int)

# Calculer la matrice de confusion
conf_matrix = confusion_matrix(y_test, y_pred_binary)

# Calculer le nombre total d'échantillons dans les données de test
total_samples = len(y_test)

# Calculer la matrice de confusion en pourcentage
conf_matrix_percent = conf_matrix / total_samples * 100

print("Matrice de confusion en %:")
print(conf_matrix_percent)

# Calculer l'accuracy
accuracy = accuracy_score(y_test, y_pred_binary)
print("Accuracy:", accuracy)

# Calculer le F1 score
f1 = f1_score(y_test, y_pred_binary)
print("F1 Score:", f1)

# Créer une figure et un axe
plt.figure(figsize=(8, 6))

# Créer un heatmap pour la matrice de confusion
sns.heatmap(conf_matrix_percent, annot=True, fmt=".2f", cmap="Blues", cbar=False)

# Ajouter des titres et des étiquettes
plt.title('Matrice de confusion en %')
plt.xlabel('Prédiction')
plt.ylabel('Vraie étiquette')
plt.xticks([0.5, 1.5], ['Classe 0', 'Classe 1'])
plt.yticks([0.5, 1.5], ['Classe 0', 'Classe 1'], rotation=0)

# Afficher le graphique
plt.show()
# Out:
# 1042/1042 [==============================] - 3s 3ms/step
# Matrice de confusion en %:
# [[68.99945982 24.22123522]
#  [ 2.12172139  4.65758358]]
# Accuracy: 0.7365704339475422
# F1 Score: 0.2612354822420468

# %% [markdown]
# Rebelote, il classe bien les gens qui n'ont pas de maladie cardiaque mais classe mal ceux qui en ont réellement

# %% [markdown]
# #### V.2 - Deuxième modèle 8 variables

# %% [markdown]
# ###### V.2.1 - Modèle RN

# %%
#Clear session and set seed
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

#Initialisation du modèle
reg_model = keras.models.Sequential()
#Shape input, number of columns
reg_model.add(keras.layers.Input(shape=X_train_8.shape[1]))#input layer
reg_model.add(keras.layers.Dense(100, activation='relu'))#Hidden layer, 100 neurones
reg_model.add(keras.layers.Dense(1))#Output layer

#Compil model parameter
reg_model.compile(loss=keras.losses.mean_squared_error, 
                  optimizer=keras.optimizers.Adam(learning_rate=0.01)
                 )
#Fit model

history = reg_model.fit(X_train_resampled_sc_8, y_train_resampled_8, batch_size=2, epochs=30, validation_split=0.2)
# Out:
# Epoch 1/30
# 7198/7198 [==============================] - 33s 4ms/step - loss: 0.2097 - val_loss: 0.3288
# Epoch 2/30
# 7198/7198 [==============================] - 31s 4ms/step - loss: 0.2049 - val_loss: 0.2754
# Epoch 3/30
# 7198/7198 [==============================] - 29s 4ms/step - loss: 0.2047 - val_loss: 0.2493
# Epoch 4/30
# 7198/7198 [==============================] - 32s 4ms/step - loss: 0.2051 - val_loss: 0.3799
# Epoch 5/30
# 7198/7198 [==============================] - 26s 4ms/step - loss: 0.2057 - val_loss: 0.3303
# Epoch 6/30
# 7198/7198 [==============================] - 29s 4ms/step - loss: 0.2056 - val_loss: 0.3250
# Epoch 7/30
# 7198/7198 [==============================] - 31s 4ms/step - loss: 0.2059 - val_loss: 0.3364
# Epoch 8/30
# 7198/7198 [==============================] - 29s 4ms/step - loss: 0.2059 - val_loss: 0.3040
# Epoch 9/30
# 7198/7198 [==============================] - 32s 4ms/step - loss: 0.2053 - val_loss: 0.3137
# Epoch 10/30
# 7198/7198 [==============================] - 31s 4ms/step - loss: 0.2053 - val_loss: 0.3304
# Epoch 11/30
# 7198/7198 [==============================] - 32s 4ms/step - loss: 0.2061 - val_loss: 0.3592
# Epoch 12/30
# 7198/7198 [==============================] - 32s 4ms/step - loss: 0.2056 - val_loss: 0.4114
# Epoch 13/30
# 7198/7198 [==============================] - 32s 4ms/step - loss: 0.2057 - val_loss: 0.4275
# Epoch 14/30
# 7198/7198 [==============================] - 33s 5ms/step - loss: 0.2056 - val_loss: 0.3695
# Epoch 15/30
# 7198/7198 [==============================] - 32s 4ms/step - loss: 0.2055 - val_loss: 0.4341
# Epoch 16/30
# 7198/7198 [==============================] - 31s 4ms/step - loss: 0.2057 - val_loss: 0.3863
# Epoch 17/30
# 7198/7198 [==============================] - 32s 4ms/step - loss: 0.2056 - val_loss: 0.3361
# Epoch 18/30
# 7198/7198 [==============================] - 32s 4ms/step - loss: 0.2056 - val_loss: 0.3655
# Epoch 19/30
# 7198/7198 [==============================] - 32s 4ms/step - loss: 0.2055 - val_loss: 0.3601
# Epoch 20/30
# 7198/7198 [==============================] - 33s 5ms/step - loss: 0.2055 - val_loss: 0.4594
# Epoch 21/30
# 7198/7198 [==============================] - 32s 4ms/step - loss: 0.2058 - val_loss: 0.3666
# Epoch 22/30
# 7198/7198 [==============================] - 32s 4ms/step - loss: 0.2058 - val_loss: 0.3050
# Epoch 23/30
# 7198/7198 [==============================] - 31s 4ms/step - loss: 0.2061 - val_loss: 0.3123
# Epoch 24/30
# 7198/7198 [==============================] - 31s 4ms/step - loss: 0.2055 - val_loss: 0.3362
# Epoch 25/30
# 7198/7198 [==============================] - 31s 4ms/step - loss: 0.2053 - val_loss: 0.3650
# Epoch 26/30
# 7198/7198 [==============================] - 29s 4ms/step - loss: 0.2057 - val_loss: 0.4204
# Epoch 27/30
# 7198/7198 [==============================] - 31s 4ms/step - loss: 0.2063 - val_loss: 0.4230
# Epoch 28/30
# 7198/7198 [==============================] - 30s 4ms/step - loss: 0.2049 - val_loss: 0.3495
# Epoch 29/30
# 7198/7198 [==============================] - 30s 4ms/step - loss: 0.2060 - val_loss: 0.3029
# Epoch 30/30
# 7198/7198 [==============================] - 31s 4ms/step - loss: 0.2055 - val_loss: 0.3276

# %%
# Supposons que history.history est votre dictionnaire de données

# Convertir les données en DataFrame et tracer le graphique
df = pd.DataFrame(history.history)
df.plot(figsize=(8, 5))
plt.grid(True)

# Déterminer les limites de l'axe y pour être plus centré autour des valeurs inférieures à 5
plt.gca().set_ylim(0, 1) 

# Afficher le graphique
plt.show()

# %% [markdown]
# ##### V.2.2 - Grid Search

# %%
# Define a function that creates your Keras model
def create_model(optimizer='adam', activation='relu'):
    model = keras.models.Sequential()
    model.add(keras.layers.Input(shape=X_train_8.shape[1]))
    model.add(keras.layers.Dense(100, activation=activation))
    model.add(keras.layers.Dense(1))
    model.compile(loss=keras.losses.mean_squared_error, optimizer=optimizer)
    return model

# Create a KerasRegressor based on your model
model = KerasRegressor(build_fn=create_model, verbose=0)

# Define the hyperparameters grid to search
param_grid = {
    'batch_size': [4, 8],
    'epochs': [20, 30],
    'optimizer': ['adam'],
    'activation': ['relu']
}

# Perform grid search
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=2)
grid_search_result = grid_search.fit(X_train_resampled_sc_8, y_train_resampled_8)

# Print the best parameters found
print("Best Parameters: ", grid_search_result.best_params_)
# Out:
# C:\Users\Chataigner\AppData\Local\Temp\ipykernel_8880\574039108.py:11: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasRegressor(build_fn=create_model, verbose=0)
# Best Parameters:  {'activation': 'relu', 'batch_size': 8, 'epochs': 30, 'optimizer': 'adam'}

# %%
# Obtenir le meilleur modèle de la recherche sur grille
best_model = grid_search_result.best_estimator_

# Prédire les étiquettes sur les données de test
y_pred = best_model.predict(X_test_sc_8)

# Convertir les prédictions en classes binaires (0 ou 1)
y_pred_binary = (y_pred > 0.5).astype(int)

# Calculer la matrice de confusion
conf_matrix = confusion_matrix(y_test_8, y_pred_binary)

# Calculer l'accuracy
accuracy = accuracy_score(y_test_8, y_pred_binary)

# Calculer le F1 score
f1 = f1_score(y_test_8, y_pred_binary)

# Afficher les résultats
print("Matrice de confusion:")
print(conf_matrix)
print("Accuracy:", accuracy)
print("F1 Score:", f1)
# Out:
# Matrice de confusion:
# [[25398  5625]
#  [ 1115  1184]]
# Accuracy: 0.79773122861773
# F1 Score: 0.25999121651295565

# %%
# Calculer le nombre total d'échantillons dans les données de test
total_samples = len(y_test_8)

# Calculer la matrice de confusion en pourcentage
conf_matrix_percent = conf_matrix / total_samples * 100

# Créer une figure et un axe
plt.figure(figsize=(8, 6))

# Créer un heatmap pour la matrice de confusion en pourcentage
sns.heatmap(conf_matrix_percent, annot=True, fmt=".2f", cmap="Blues", cbar=False)

# Ajouter des titres et des étiquettes
plt.title('Matrice de confusion en %')
plt.xlabel('Prédiction')
plt.ylabel('Vraie étiquette')
plt.xticks([0.5, 1.5], ['Classe 0', 'Classe 1'])
plt.yticks([0.5, 1.5], ['Classe 0', 'Classe 1'], rotation=0)

# Afficher le graphique
plt.show()

# %% [markdown]
# #### V.3 - Premier modèle 15 variables

# %% [markdown]
# ##### V.3.1 - Modèle RN

# %%
#Clear session and set seed
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

#Initialisation du modèle
reg_model = keras.models.Sequential()
#Shape input, number of columns
reg_model.add(keras.layers.Input(shape=X_train_15.shape[1]))#input layer
reg_model.add(keras.layers.Dense(100, activation='relu'))#Hidden layer, 100 neurones
reg_model.add(keras.layers.Dense(1))#Output layer

#Compil model parameter
reg_model.compile(loss=keras.losses.mean_squared_error, 
                  optimizer=keras.optimizers.Adam(learning_rate=0.01)
                 )
#Fit model

history = reg_model.fit(X_train_resampled_sc_15, y_train_resampled_15, batch_size=2, epochs=30, validation_split=0.2)
# Out:
# Epoch 1/30
# 7212/7212 [==============================] - 10s 1ms/step - loss: 0.2029 - val_loss: 0.3909
# Epoch 2/30
# 7212/7212 [==============================] - 9s 1ms/step - loss: 0.1938 - val_loss: 0.3068
# Epoch 3/30
# 7212/7212 [==============================] - 9s 1ms/step - loss: 0.1933 - val_loss: 0.2771
# Epoch 4/30
# 7212/7212 [==============================] - 9s 1ms/step - loss: 0.1933 - val_loss: 0.2814
# Epoch 5/30
# 7212/7212 [==============================] - 9s 1ms/step - loss: 0.1935 - val_loss: 0.2249
# Epoch 6/30
# 7212/7212 [==============================] - 10s 1ms/step - loss: 0.1930 - val_loss: 0.2461
# Epoch 7/30
# 7212/7212 [==============================] - 10s 1ms/step - loss: 0.1938 - val_loss: 0.2924
# Epoch 8/30
# 7212/7212 [==============================] - 10s 1ms/step - loss: 0.1937 - val_loss: 0.3432
# Epoch 9/30
# 7212/7212 [==============================] - 9s 1ms/step - loss: 0.1936 - val_loss: 0.2285
# Epoch 10/30
# 7212/7212 [==============================] - 9s 1ms/step - loss: 0.1935 - val_loss: 0.2879
# Epoch 11/30
# 7212/7212 [==============================] - 9s 1ms/step - loss: 0.1931 - val_loss: 0.3534
# Epoch 12/30
# 7212/7212 [==============================] - 9s 1ms/step - loss: 0.1936 - val_loss: 0.2974
# Epoch 13/30
# 7212/7212 [==============================] - 9s 1ms/step - loss: 0.1928 - val_loss: 0.2962
# Epoch 14/30
# 7212/7212 [==============================] - 9s 1ms/step - loss: 0.1937 - val_loss: 0.3278
# Epoch 15/30
# 7212/7212 [==============================] - 10s 1ms/step - loss: 0.1935 - val_loss: 0.2387
# Epoch 16/30
# 7212/7212 [==============================] - 9s 1ms/step - loss: 0.1934 - val_loss: 0.3569
# Epoch 17/30
# 7212/7212 [==============================] - 9s 1ms/step - loss: 0.1932 - val_loss: 0.2547
# Epoch 18/30
# 7212/7212 [==============================] - 11s 2ms/step - loss: 0.1927 - val_loss: 0.1996
# Epoch 19/30
# 7212/7212 [==============================] - 10s 1ms/step - loss: 0.1936 - val_loss: 0.2962
# Epoch 20/30
# 7212/7212 [==============================] - 9s 1ms/step - loss: 0.1932 - val_loss: 0.2046
# Epoch 21/30
# 7212/7212 [==============================] - 9s 1ms/step - loss: 0.1927 - val_loss: 0.2729
# Epoch 22/30
# 7212/7212 [==============================] - 13s 2ms/step - loss: 0.1929 - val_loss: 0.2839
# Epoch 23/30
# 7212/7212 [==============================] - 13s 2ms/step - loss: 0.1933 - val_loss: 0.3572
# Epoch 24/30
# 7212/7212 [==============================] - 10s 1ms/step - loss: 0.1932 - val_loss: 0.2671
# Epoch 25/30
# 7212/7212 [==============================] - 11s 2ms/step - loss: 0.1934 - val_loss: 0.3292
# Epoch 26/30
# 7212/7212 [==============================] - 10s 1ms/step - loss: 0.1934 - val_loss: 0.4491
# Epoch 27/30
# 7212/7212 [==============================] - 9s 1ms/step - loss: 0.1940 - val_loss: 0.3451
# Epoch 28/30
# 7212/7212 [==============================] - 9s 1ms/step - loss: 0.1933 - val_loss: 0.3430
# Epoch 29/30
# 7212/7212 [==============================] - 9s 1ms/step - loss: 0.1932 - val_loss: 0.2325
# Epoch 30/30
# 7212/7212 [==============================] - 11s 2ms/step - loss: 0.1929 - val_loss: 0.2308

# %%
# Supposons que history.history est votre dictionnaire de données

# Convertir les données en DataFrame et tracer le graphique
df = pd.DataFrame(history.history)
df.plot(figsize=(8, 5))
plt.grid(True)

# Déterminer les limites de l'axe y pour être plus centré autour des valeurs inférieures à 5
plt.gca().set_ylim(0, 1) 

# Afficher le graphique
plt.show()

# %%
# Perte finale sur les données d'entraînement et de validation
final_train_loss = history.history['loss'][-1]
final_val_loss = history.history['val_loss'][-1]

print("Perte finale sur les données d'entraînement (MSE) :", final_train_loss)
print("Perte finale sur les données de validation (MSE) :", final_val_loss)
# Out:
# Perte finale sur les données d'entraînement (MSE) : 0.2052239030599594
# Perte finale sur les données de validation (MSE) : 0.18988138437271118

# %% [markdown]
# ##### V.3.2 - Grid Search

# %%
# Define a function that creates your Keras model
def create_model(optimizer='adam', activation='relu'):
    model = keras.models.Sequential()
    model.add(keras.layers.Input(shape=X_train_15.shape[1]))
    model.add(keras.layers.Dense(100, activation=activation))
    model.add(keras.layers.Dense(1))
    model.compile(loss=keras.losses.mean_squared_error, optimizer=optimizer)
    return model

# Create a KerasRegressor based on your model
model = KerasRegressor(build_fn=create_model, verbose=0)

# Define the hyperparameters grid to search
param_grid = {
    'batch_size': [4, 8],
    'epochs': [20, 30],
    'optimizer': ['adam'],
    'activation': ['relu']
}

# Perform grid search
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=2)
grid_search_result = grid_search.fit(X_train_resampled_sc_15, y_train_resampled_15)

# Print the best parameters found
print("Best Parameters: ", grid_search_result.best_params_)
# Out:
# C:\Users\Chataigner\AppData\Local\Temp\ipykernel_25588\1350824216.py:11: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasRegressor(build_fn=create_model, verbose=0)
# Best Parameters:  {'activation': 'relu', 'batch_size': 4, 'epochs': 30, 'optimizer': 'adam'}

# %%
# Obtenir le meilleur modèle de la recherche sur grille
best_model = grid_search_result.best_estimator_

# Prédire les étiquettes sur les données de test
y_pred = best_model.predict(X_test_sc_15)

# Convertir les prédictions en classes binaires (0 ou 1)
y_pred_binary = (y_pred > 0.5).astype(int)

# Calculer la matrice de confusion
conf_matrix = confusion_matrix(y_test_15, y_pred_binary)

# Calculer l'accuracy
accuracy = accuracy_score(y_test_15, y_pred_binary)

# Calculer le F1 score
f1 = f1_score(y_test_15, y_pred_binary)

# Afficher les résultats
print("Matrice de confusion:")
print(conf_matrix)
print("Accuracy:", accuracy)
print("F1 Score:", f1)
# Out:
# Matrice de confusion:
# [[21888  9152]
#  [  703  1579]]
# Accuracy: 0.7042494448112359
# F1 Score: 0.2426803965265504

# %%
# Calculer le nombre total d'échantillons dans les données de test
total_samples = len(y_test_15)

# Calculer la matrice de confusion en pourcentage
conf_matrix_percent = conf_matrix / total_samples * 100

# Créer une figure et un axe
plt.figure(figsize=(8, 6))

# Créer un heatmap pour la matrice de confusion en pourcentage
sns.heatmap(conf_matrix_percent, annot=True, fmt=".2f", cmap="Blues", cbar=False)

# Ajouter des titres et des étiquettes
plt.title('Matrice de confusion en %')
plt.xlabel('Prédiction')
plt.ylabel('Vraie étiquette')
plt.xticks([0.5, 1.5], ['Classe 0', 'Classe 1'])
plt.yticks([0.5, 1.5], ['Classe 0', 'Classe 1'], rotation=0)

# Afficher le graphique
plt.show()

# %% [markdown]
# #### V.4 - Premier modèle 9 variables

# %% [markdown]
# ##### V.4.1 - Modèle RN

# %%
#Clear session and set seed
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

#Initialisation du modèle
reg_model = keras.models.Sequential()
#Shape input, number of columns
reg_model.add(keras.layers.Input(shape=X_train_10.shape[1]))#input layer
reg_model.add(keras.layers.Dense(100, activation='relu'))#Hidden layer, 100 neurones
reg_model.add(keras.layers.Dense(1))#Output layer

#Compil model parameter²
reg_model.compile(loss=keras.losses.mean_squared_error, 
                  optimizer=keras.optimizers.Adam(learning_rate=0.01)
                 )
#Fit model

history = reg_model.fit(X_train_resampled_sc_10, y_train_resampled_10, batch_size=2, epochs=30, validation_split=0.2)
# Out:
# Epoch 1/30
# 7192/7192 [==============================] - 9s 1ms/step - loss: 0.2297 - val_loss: 0.2585
# Epoch 2/30
# 7192/7192 [==============================] - 9s 1ms/step - loss: 0.2062 - val_loss: 0.1879
# Epoch 3/30
# 7192/7192 [==============================] - 9s 1ms/step - loss: 0.2063 - val_loss: 0.2969
# Epoch 4/30
# 7192/7192 [==============================] - 9s 1ms/step - loss: 0.2054 - val_loss: 0.2460
# Epoch 5/30
# 7192/7192 [==============================] - 9s 1ms/step - loss: 0.2047 - val_loss: 0.2999
# Epoch 6/30
# 7192/7192 [==============================] - 10s 1ms/step - loss: 0.2048 - val_loss: 0.3230
# Epoch 7/30
# 7192/7192 [==============================] - 10s 1ms/step - loss: 0.2059 - val_loss: 0.2616
# Epoch 8/30
# 7192/7192 [==============================] - 9s 1ms/step - loss: 0.2051 - val_loss: 0.4353
# Epoch 9/30
# 7192/7192 [==============================] - 9s 1ms/step - loss: 0.2044 - val_loss: 0.1956
# Epoch 10/30
# 7192/7192 [==============================] - 9s 1ms/step - loss: 0.2054 - val_loss: 0.5386
# Epoch 11/30
# 7192/7192 [==============================] - 9s 1ms/step - loss: 0.2057 - val_loss: 0.1997
# Epoch 12/30
# 7192/7192 [==============================] - 9s 1ms/step - loss: 0.2047 - val_loss: 0.3135
# Epoch 13/30
# 7192/7192 [==============================] - 9s 1ms/step - loss: 0.2049 - val_loss: 0.3831
# Epoch 14/30
# 7192/7192 [==============================] - 9s 1ms/step - loss: 0.2054 - val_loss: 0.5264
# Epoch 15/30
# 7192/7192 [==============================] - 9s 1ms/step - loss: 0.2054 - val_loss: 0.2561
# Epoch 16/30
# 7192/7192 [==============================] - 12s 2ms/step - loss: 0.2044 - val_loss: 0.3615
# Epoch 17/30
# 7192/7192 [==============================] - 14s 2ms/step - loss: 0.2054 - val_loss: 0.2937
# Epoch 18/30
# 7192/7192 [==============================] - 12s 2ms/step - loss: 0.2058 - val_loss: 0.3830
# Epoch 19/30
# 7192/7192 [==============================] - 9s 1ms/step - loss: 0.2058 - val_loss: 0.3756
# Epoch 20/30
# 7192/7192 [==============================] - 9s 1ms/step - loss: 0.2060 - val_loss: 0.3060
# Epoch 21/30
# 7192/7192 [==============================] - 9s 1ms/step - loss: 0.2048 - val_loss: 0.5651
# Epoch 22/30
# 7192/7192 [==============================] - 9s 1ms/step - loss: 0.2053 - val_loss: 0.4334
# Epoch 23/30
# 7192/7192 [==============================] - 9s 1ms/step - loss: 0.2061 - val_loss: 0.3669
# Epoch 24/30
# 7192/7192 [==============================] - 9s 1ms/step - loss: 0.2059 - val_loss: 0.4736
# Epoch 25/30
# 7192/7192 [==============================] - 9s 1ms/step - loss: 0.2042 - val_loss: 0.4183
# Epoch 26/30
# 7192/7192 [==============================] - 9s 1ms/step - loss: 0.2073 - val_loss: 0.3331
# Epoch 27/30
# 7192/7192 [==============================] - 9s 1ms/step - loss: 0.2036 - val_loss: 0.4551
# Epoch 28/30
# 7192/7192 [==============================] - 9s 1ms/step - loss: 0.2063 - val_loss: 0.3845
# Epoch 29/30
# 7192/7192 [==============================] - 9s 1ms/step - loss: 0.2046 - val_loss: 0.2716
# Epoch 30/30
# 7192/7192 [==============================] - 9s 1ms/step - loss: 0.2052 - val_loss: 0.1899

# %%
# Convertir les données en DataFrame et tracer le graphique
df = pd.DataFrame(history.history)
df.plot(figsize=(8, 5), color=['blue', 'green'])  # Spécifiez les couleurs que vous souhaitez pour chaque courbe
plt.grid(True)

# Déterminer les limites de l'axe y pour être plus centré autour des valeurs inférieures à 5
plt.gca().set_ylim(0, 1) 

# Afficher le graphique
plt.show()

# %%
#On change couleurs pcq sur l'autre on voyait pas trop

# %% [markdown]
# ##### V.4.2 - Grid Search

# %%
# Define a function that creates your Keras model
def create_model(optimizer='adam', activation='relu'):
    model = keras.models.Sequential()
    model.add(keras.layers.Input(shape=X_train_10.shape[1]))
    model.add(keras.layers.Dense(100, activation=activation))
    model.add(keras.layers.Dense(1))
    model.compile(loss=keras.losses.mean_squared_error, optimizer=optimizer)
    return model

# Create a KerasRegressor based on your model
model = KerasRegressor(build_fn=create_model, verbose=0)

# Define the hyperparameters grid to search
param_grid = {
    'batch_size': [4, 8],
    'epochs': [20, 30],
    'optimizer': ['adam'],
    'activation': ['relu']
}

# Perform grid search
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=2)
grid_search_result = grid_search.fit(X_train_resampled_sc_10, y_train_resampled_10)

# Print the best parameters found
print("Best Parameters: ", grid_search_result.best_params_)
# Out:
# C:\Users\Chataigner\AppData\Local\Temp\ipykernel_25588\3350158401.py:11: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasRegressor(build_fn=create_model, verbose=0)
# Best Parameters:  {'activation': 'relu', 'batch_size': 4, 'epochs': 20, 'optimizer': 'adam'}

# %%
# Obtenir le meilleur modèle de la recherche sur grille
best_model = grid_search_result.best_estimator_

# Prédire les étiquettes sur les données de test
y_pred = best_model.predict(X_test_sc_10)

# Convertir les prédictions en classes binaires (0 ou 1)
y_pred_binary = (y_pred > 0.5).astype(int)

# Calculer la matrice de confusion
conf_matrix = confusion_matrix(y_test_10, y_pred_binary)

# Calculer l'accuracy
accuracy = accuracy_score(y_test_10, y_pred_binary)

# Calculer le F1 score
f1 = f1_score(y_test_10, y_pred_binary)

# Afficher les résultats
print("Matrice de confusion:")
print(conf_matrix)
print("Accuracy:", accuracy)
print("F1 Score:", f1)
# Out:
# Matrice de confusion:
# [[20427 10588]
#  [  684  1623]]
# Accuracy: 0.6617249864954085
# F1 Score: 0.22358451577352254

# %%
# Calculer le nombre total d'échantillons dans les données de test
total_samples = len(y_test_15)

# Calculer la matrice de confusion en pourcentage
conf_matrix_percent = conf_matrix / total_samples * 100

# Créer une figure et un axe
plt.figure(figsize=(8, 6))

# Créer un heatmap pour la matrice de confusion en pourcentage
sns.heatmap(conf_matrix_percent, annot=True, fmt=".2f", cmap="Blues", cbar=False)

# Ajouter des titres et des étiquettes
plt.title('Matrice de confusion en %')
plt.xlabel('Prédiction')
plt.ylabel('Vraie étiquette')
plt.xticks([0.5, 1.5], ['Classe 0', 'Classe 1'])
plt.yticks([0.5, 1.5], ['Classe 0', 'Classe 1'], rotation=0)

# Afficher le graphique
plt.show()

# %% [markdown]
# Nous nous sommes en parti inspiré des codes disponibles ici :
# * https://github.com/Roulitoo/cours_iae/blob/master/01_SVM/td/code/01_SVM_TD_correction.ipynb
# * https://github.com/Roulitoo/cours_iae/blob/master/02_ANN/td/td_ann_02_correction_q3.ipynb
